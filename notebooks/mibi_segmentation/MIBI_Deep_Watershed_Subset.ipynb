# %%
import os
import errno
import numpy as np 
import deepcell
from deepcell_toolbox.processing import phase_preprocess

# %%
# create folder for this set of experiments
experiment_folder = "20200827_data_subset"
MODEL_DIR = os.path.join("/data/models", experiment_folder)
NPZ_DIR = "/data/npz_data/"
LOG_DIR = '/data/logs'

if not os.path.isdir(MODEL_DIR):
    os.makedirs(MODEL_DIR)

# %%
from deepcell.utils.data_utils import get_data
from skimage.segmentation import relabel_sequential

npz_name = "20200827_multiplex_COH_normalized_512x512"

train_dict = np.load(NPZ_DIR + npz_name + "_train.npz")
val_dict = np.load(NPZ_DIR + npz_name + "_val.npz")

X_train, y_train = train_dict['X'], train_dict['y']
train_tissue, train_platform = train_dict['tissue_list'], train_dict['platform_list']
X_val, y_val = val_dict['X'], val_dict['y']
val_tissue, val_platform = val_dict['tissue_list'], val_dict['platform_list']

# %%
k=128
X_train = phase_preprocess(X_train, k)
X_val = phase_preprocess(X_val, k)

# %% [markdown]
# ## For each batch

# %%
from deepcell.model_zoo.panopticnet import PanopticNet

new_model = PanopticNet(
    backbone='resnet50',
    input_shape=(256, 256, 2),
    norm_method=None,
    num_semantic_heads=4,
    num_semantic_classes=[1, 1, 2, 3], # inner distance, outer distance, fgbg, pixelwise
    location=True,  # should always be true
    include_top=True)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0828 05:33:04.030283 140284843030336 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
print(np.unique(train_tissue), np.unique(train_platform))
# Out:
# ['breast' 'gi' 'immune' 'pancreas' 'skin'] ['codex' 'cycif' 'if' 'imc' 'mibi' 'vectra']

# %%
subset_type = ['pancreas', 'gi', 'breast']
subset_idx_train = np.isin(train_tissue, subset_type)
subset_idx_val = np.isin(val_tissue, subset_type)
print(np.sum(subset_idx_train), np.sum(subset_idx_val))
# Out:
# 1299 162

# %%
X_train_subset, y_train_subset = X_train[subset_idx_train], y_train[subset_idx_train]

# %%
X_val_subset, y_val_subset = X_val[subset_idx_val], y_val[subset_idx_val]

# %%
from tensorflow.keras.optimizers import SGD, Adam
from deepcell.utils.train_utils import rate_scheduler

# model_name = npz_name + '_subset_' + subset_type

model_name = npz_name + '_subset_' + 'all_tissue'

n_epoch = 35  # Number of training epochs

optimizer = Adam(lr=1e-4, clipnorm=0.001)
lr_sched = rate_scheduler(lr=1e-4, decay=0.99)

batch_size = 8

min_objects = 0  # throw out images with fewer than this many objects
seed=0
model_name
# Out:
# '20200827_multiplex_COH_normalized_512x512_subset_all_tissue'

# %%
from deepcell import image_generators
from deepcell.utils import train_utils


# use augmentation for training but not validation
datagen = image_generators.CroppingDataGenerator(
    rotation_range=180,
    shear_range=0,
    zoom_range=(0.75, 1.25),
    horizontal_flip=True,
    vertical_flip=True,
    crop_size=(256, 256))

datagen_val = image_generators.CroppingDataGenerator(
    rotation_range=0,
    shear_range=0,
    zoom_range=0,
    horizontal_flip=0,
    vertical_flip=0,
    crop_size=(256, 256))
    
train_data = datagen.flow(
    {'X': X_train_subset, 'y': y_train_subset},
    seed=seed,
    transforms=['inner-distance', 'watershed-cont', 'fgbg', 'pixelwise'],
    transforms_kwargs={'watershed-cont': {'erosion_width': 1}, 'pixelwise':{'dilation_radius': 1}, 
                      'inner-distance': {'erosion_width': 1, 'alpha': 'auto'}},
    min_objects=min_objects,
    batch_size=batch_size)

val_data = datagen_val.flow(
    {'X': X_val_subset, 'y': y_val_subset},
    seed=seed,
    transforms=['inner-distance', 'watershed-cont', 'fgbg', 'pixelwise'],
    transforms_kwargs={'watershed-cont': {'erosion_width': 1}, 'pixelwise':{'dilation_radius': 1},
                      'inner-distance': {'erosion_width': 1, 'alpha': 'auto'}},
    min_objects=min_objects,
    batch_size=batch_size)

# %%
from matplotlib import pyplot as plt

inputs, outputs = train_data.next()

img = inputs[0]
inner_distance = outputs[0]
outer_distance = outputs[1]
fgbg = outputs[2]
pixelwise = outputs[3]

fig, axes = plt.subplots(1, 5, figsize=(30, 30))

axes[0].imshow(img[:, :, 0])
axes[0].set_title('DNA')

axes[1].imshow(img[:, :, 1])
axes[1].set_title('Membrane')

axes[2].imshow(inner_distance[0, ..., 0])
axes[2].set_title('Inner Distance')

axes[3].imshow(outer_distance[0, ..., 0])
axes[3].set_title('Outer Distance')

axes[4].imshow(pixelwise[0, ..., 1])
axes[4].set_title('Pixelwise Interior')

plt.show()

# %%
# Create a dictionary of losses for each semantic head
from tensorflow.python.keras.losses import MSE
from deepcell import losses


def semantic_loss(n_classes):
    def _semantic_loss(y_pred, y_true):
        if n_classes > 1:
            return 0.01 * losses.weighted_categorical_crossentropy(
                y_pred, y_true, n_classes=n_classes)
        return MSE(y_pred, y_true)
    return _semantic_loss


loss = {}

# Give losses for all of the semantic heads
for layer in new_model.layers:
    if layer.name.startswith('semantic_'):
        n_classes = layer.output_shape[-1]
        loss[layer.name] = semantic_loss(n_classes)

# %%
new_model.compile(loss=loss, optimizer=optimizer)

# %%
from deepcell.utils.train_utils import get_callbacks
from deepcell.utils.train_utils import count_gpus


model_path = os.path.join(MODEL_DIR, '{}.h5'.format(model_name))
loss_path = os.path.join(MODEL_DIR, '{}.npz'.format(model_name))

num_gpus = count_gpus()

print('Training on', num_gpus, 'GPUs.')

train_callbacks = get_callbacks(
    model_path,
    lr_sched=lr_sched,
    tensorboard_log_dir=LOG_DIR,
    save_weights_only=num_gpus >= 2,
    monitor='val_loss',
    verbose=1)

loss_history = new_model.fit_generator(
    train_data,
    steps_per_epoch=60,
    epochs=n_epoch,
    validation_data=val_data,
    validation_steps=val_data.y.shape[0] // batch_size,
    callbacks=train_callbacks)
# Out:
# Training on 1 GPUs.
# Epoch 1/35
# W0828 05:44:30.457978 140284843030336 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
#  1/60 [..............................] - ETA: 39:30 - loss: 1.9158 - semantic_0_loss: 1.3814 - semantic_1_loss: 0.5119 - semantic_2_loss: 0.0090 - semantic_3_loss: 0.0136
# W0828 05:45:10.732306 140284843030336 callbacks.py:257] Method (on_train_batch_end) is slow compared to the batch update (0.370683). Check your callbacks.
# 59/60 [============================>.] - ETA: 0s - loss: 0.2933 - semantic_0_loss: 0.1825 - semantic_1_loss: 0.0963 - semantic_2_loss: 0.0050 - semantic_3_loss: 0.0095
# Epoch 00001: val_loss improved from inf to 0.34251, saving model to /data/models/20200827_data_subset/20200827_multiplex_COH_normalized_512x512_subset_all_tissue.h5
# 60/60 [==============================] - 116s 2s/step - loss: 0.2897 - semantic_0_loss: 0.1800 - semantic_1_loss: 0.0954 - semantic_2_loss: 0.0050 - semantic_3_loss: 0.0095 - val_loss: 0.3425 - val_semantic_0_loss: 0.0564 - val_semantic_1_loss: 0.1018 - val_semantic_2_loss: 0.0783 - val_semantic_3_loss: 0.1061
# Epoch 2/35
# 59/60 [============================>.] - ETA: 0s - loss: 0.0677 - semantic_0_loss: 0.0226 - semantic_1_loss: 0.0345 - semantic_2_loss: 0.0033 - semantic_3_loss: 0.0073- ETA: 9s - loss: 0.0781 - semantic_0_loss: 0.0268 - semantic_1_loss: 0.0400 - se
# Epoch 00002: val_loss did not improve from 0.34251
# 60/60 [==============================] - 17s 286ms/step - loss: 0.0675 - semantic_0_loss: 0.0226 - semantic_1_loss: 0.0344 - semantic_2_loss: 0.0033 - semantic_3_loss: 0.0073 - val_loss: 1.6571 - val_semantic_0_loss: 1.3749 - val_semantic_1_loss: 0.0995 - val_semantic_2_loss: 0.0783 - val_semantic_3_loss: 0.1044
# Epoch 3/35
# 59/60 [============================>.] - ETA: 0s - loss: 0.0570 - semantic_0_loss: 0.0189 - semantic_1_loss: 0.0285 - semantic_2_loss: 0.0029 - semantic_3_loss: 0.0067
# Epoch 00003: val_loss improved from 0.34251 to 0.32964, saving model to /data/models/20200827_data_subset/20200827_multiplex_COH_normalized_512x512_subset_all_tissue.h5
# 60/60 [==============================] - 22s 373ms/step - loss: 0.0571 - semantic_0_loss: 0.0190 - semantic_1_loss: 0.0285 - semantic_2_loss: 0.0029 - semantic_3_loss: 0.0067 - val_loss: 0.3296 - val_semantic_0_loss: 0.0566 - val_semantic_1_loss: 0.1011 - val_semantic_2_loss: 0.0739 - val_semantic_3_loss: 0.0980
# Epoch 4/35
# 59/60 [============================>.] - ETA: 0s - loss: 0.0501 - semantic_0_loss: 0.0168 - semantic_1_loss: 0.0247 - semantic_2_loss: 0.0025 - semantic_3_loss: 0.0062
# Epoch 00004: val_loss did not improve from 0.32964
# 60/60 [==============================] - 19s 309ms/step - loss: 0.0500 - semantic_0_loss: 0.0167 - semantic_1_loss: 0.0246 - semantic_2_loss: 0.0025 - semantic_3_loss: 0.0062 - val_loss: 0.3371 - val_semantic_0_loss: 0.0581 - val_semantic_1_loss: 0.1046 - val_semantic_2_loss: 0.0722 - val_semantic_3_loss: 0.1023
# Epoch 5/35
# 59/60 [============================>.] - ETA: 0s - loss: 0.0521 - semantic_0_loss: 0.0176 - semantic_1_loss: 0.0256 - semantic_2_loss: 0.0026 - semantic_3_loss: 0.0063
# Epoch 00005: val_loss did not improve from 0.32964
# 60/60 [==============================] - 19s 314ms/step - loss: 0.0520 - semantic_0_loss: 0.0176 - semantic_1_loss: 0.0255 - semantic_2_loss: 0.0026 - semantic_3_loss: 0.0063 - val_loss: 0.3304 - val_semantic_0_loss: 0.0577 - val_semantic_1_loss: 0.1029 - val_semantic_2_loss: 0.0761 - val_semantic_3_loss: 0.0937
# Epoch 6/35
# 59/60 [============================>.] - ETA: 0s - loss: 0.
saving model to /data/models/20200827_data_subset/20200827_multiplex_COH_normalized_512x512_subset_all_tissue.h5
# 60/60 [==============================] - 22s 363ms/step - loss: 0.0397 - semantic_0_loss: 0.0135 - semantic_1_loss: 0.0188 - semantic_2_loss: 0.0021 - semantic_3_loss: 0.0053 - val_loss: 0.0431 - val_semantic_0_loss: 0.0143 - val_semantic_1_loss: 0.0210 - val_semantic_2_loss: 0.0023 - val_semantic_3_loss: 0.0054
# Epoch 18/35
# 59/60 [============================>.] - ETA: 0s - loss: 0.0392 - semantic_0_loss: 0.0133 - semantic_1_loss: 0.0186 - semantic_2_loss: 0.0021 - semantic_3_loss: 0.0052
# Epoch 00018: val_loss improved from 0.04307 to 0.04087, saving model to /data/models/20200827_data_subset/20200827_multiplex_COH_normalized_512x512_subset_all_tissue.h5
# 60/60 [==============================] - 22s 363ms/step - loss: 0.0391 - semantic_0_loss: 0.0133 - semantic_1_loss: 0.0185 - semantic_2_loss: 0.0021 - semantic_3_loss: 0.0052 - val_loss: 0.0409 - val_semantic_0_loss: 0.0136 - val_semantic_1_loss: 0.0195 - val_semantic_2_loss: 0.0023 - val_semantic_3_loss: 0.0054
# Epoch 19/35
# 59/60 [============================>.] - ETA: 0s - loss: 0.0393 - semantic_0_loss: 0.0133 - semantic_1_loss: 0.0186 - semantic_2_loss: 0.0021 - semantic_3_loss: 0.0053
# Epoch 00019: val_loss improved from 0.04087 to 0.04027, saving model to /data/models/20200827_data_subset/20200827_multiplex_COH_normalized_512x512_subset_all_tissue.h5
# 60/60 [==============================] - 21s 358ms/step - loss: 0.0392 - semantic_0_loss: 0.0133 - semantic_1_loss: 0.0186 - semantic_2_loss: 0.0021 - semantic_3_loss: 0.0052 - val_loss: 0.0403 - val_semantic_0_loss: 0.0136 - val_semantic_1_loss: 0.0193 - val_semantic_2_loss: 0.0022 - val_semantic_3_loss: 0.0052
# Epoch 20/35
# 59/60 [============================>.] - ETA: 0s - loss: 0.0384 - semantic_0_loss: 0.0131 - semantic_1_loss: 0.0182 - semantic_2_loss: 0.0020 - semantic_3_loss: 0.0051
# Epoch 00020: val_loss improved from 0.04027 to 0.03865, saving model to /data/models/20200827_data_subset/20200827_multiplex_COH_normalized_512x512_subset_all_tissue.h5
# 60/60 [==============================] - 23s 382ms/step - loss: 0.0385 - semantic_0_loss: 0.0131 - semantic_1_loss: 0.0183 - semantic_2_loss: 0.0020 - semantic_3_loss: 0.0051 - val_loss: 0.0387 - val_semantic_0_loss: 0.0131 - val_semantic_1_loss: 0.0183 - val_semantic_2_loss: 0.0022 - val_semantic_3_loss: 0.0051
# Epoch 21/35
# 59/60 [============================>.] - ETA: 0s - loss: 0.0400 - semantic_0_loss: 0.0136 - semantic_1_loss: 0.0191 - semantic_2_loss: 0.0022 - semantic_3_loss: 0.0052
# Epoch 00021: val_loss improved from 0.03865 to 0.03726, saving model to /data/models/20200827_data_subset/20200827_multiplex_COH_normalized_512x512_subset_all_tissue.h5
# 60/60 [==============================] - 22s 362ms/step - loss: 0.0399 - semantic_0_loss: 0.0135 - semantic_1_loss: 0.0190 - semantic_2_loss: 0.0021 - semantic_3_loss: 0.0052 - val_loss: 0.0373 - val_semantic_0_loss: 0.0127 - val_semantic_1_loss: 0.0174 - val_semantic_2_loss: 0.0021 - val_semantic_3_loss: 0.0050
# Epoch 22/35
# 59/60 [============================>.] - ETA: 0s - loss: 0.0391 - semantic_0_loss: 0.0133 - semantic_1_loss: 0.0185 - semantic_2_loss: 0.0021 - semantic_3_loss: 0.0052
# Epoch 00022: val_loss did not improve from 0.03726
# 60/60 [==============================] - 19s 311ms/step - loss: 0.0388 - semantic_0_loss: 0.0132 - semantic_1_loss: 0.0183 - semantic_2_loss: 0.0021 - semantic_3_loss: 0.0052 - val_loss: 0.0380 - val_semantic_0_loss: 0.0127 - val_semantic_1_loss: 0.0174 - val_semantic_2_loss: 0.0022 - val_semantic_3_loss: 0.0057
# Epoch 23/35
# 59/60 [============================>.] - ETA: 0s - loss: 0.0383 - semantic_0_loss: 0.0129 - semantic_1_loss: 0.0181 - semantic_2_loss: 0.0021 - semantic_3_loss: 0.0052
# Epoch 00023: val_loss improved from 0.03726 to 0.03662, saving model to /data/models/20200827_data_subset/20200827_multiplex_COH_normalized_512x512_subset_all_tissue.h5
# 60/60 [==============================] - 22s 366ms/step - loss: 0.0384 - semantic_0_loss: 0.0130 - semantic_1_loss: 0.0182 - semantic_2_loss: 0.0021 - semantic_3_loss: 0.0052 - val_loss: 0.0366 - val_semantic_0_loss: 0.0126 - val_semantic_1_loss: 0.0171 - val_semantic_2_loss: 0.0020 - val_semantic_3_loss: 0.0049
# Epoch 24/35
# 59/60 [============================>.] - ETA: 0s - loss: 0.0359 - semantic_0_loss: 0.0122 - semantic_1_loss: 0.0168 - semantic_2_loss: 0.0020 - semantic_3_loss: 0.0050
# Epoch 00024: val_loss improved from 0.03662 to 0.03605, saving model to /data/models/20200827_data_subset/20200827_multiplex_COH_normalized_512x512_subset_all_tissue.h5
# 60/60 [==============================] - 22s 361ms/step - loss: 0.0359 - semantic_0_loss: 0.0122 - semantic_1_loss: 0.0168 - semantic_2_loss: 0.0019 - semantic_3_loss: 0.0050 - val_loss: 0.0361 - val_semantic_0_loss: 0.0121 - val_semantic_1_loss: 0.0171 - val_semantic_2_loss: 0.0020 - val_semantic_3_loss: 0.0049
# Epoch 25/35
# 59/60 [============================>.] - ETA: 0s - loss: 0.0385 - semantic_0_loss: 0.0131 - semantic_1_loss: 0.0182 - semantic_2_loss: 0.0021 - semantic_3_loss: 0.0051
# Epoch 00025: val_loss did not improve from 0.03605
# 60/60 [==============================] - 18s 301ms/step - loss: 0.0384 - semantic_0_loss: 0.0131 - semantic_1_loss: 0.0182 - semantic_2_loss: 0.0021 - semantic_3_loss: 0.0051 - val_loss: 0.0370 - val_semantic_0_loss: 0.0125 - val_semantic_1_loss: 0.0174 - val_semantic_2_loss: 0.0021 - val_semantic_3_loss: 0.0050
# Epoch 26/35
# 59/60 [============================>.] - ETA: 0s - loss: 0.0367 - semantic_0_loss: 0.0124 - semantic_1_loss: 0.0172 - semantic_2_loss: 0.0020 - semantic_3_loss: 0.0050
# Epoch 00026: val_loss did not improve from 0.03605
# 60/60 [==============================] - 19s 313ms/step - loss: 0.0367 - semantic_0_loss: 0.0125 - semantic_1_loss: 0.0173 - semantic_2_loss: 0.0020 - semantic_3_loss: 0.0050 - val_loss: 0.0378 - val_semantic_0_loss: 0.0128 - val_semantic_1_loss: 0.0178 - val_semantic_2_loss: 0.0021 - val_semantic_3_loss: 0.0050
# Epoch 27/35
# 59/60 [============================>.] - ETA: 0s - loss: 0.0380 - semantic_0_loss: 0.0128 - semantic_1_loss: 0.0180 - semantic_2_loss: 0.0021 - semantic_3_loss: 0.0051
# Epoch 00027: val_loss improved from 0.03605 to 0.03543, saving model to /data/models/20200827_data_subset/20200827_multiplex_COH_normalized_512x512_subset_all_tissue.h5
# 60/60 [==============================] - 22s 370ms/step - loss: 0.0380 - semantic_0_loss: 0.0128 - semantic_1_loss: 0.0180 - semantic_2_loss: 0.0021 - semantic_3_loss: 0.0051 - val_loss: 0.0354 - val_semantic_0_loss: 0.0121 - val_semantic_1_loss: 0.0164 - val_semantic_2_loss: 0.0020 - val_semantic_3_loss: 0.0049
# Epoch 28/35
# 59/60 [============================>.] - ETA: 0s - loss: 0.0365 - semantic_0_loss: 0.0123 - semantic_1_loss: 0.0172 - semantic_2_loss: 0.0020 - semantic_3_loss: 0.0050
# Epoch 00028: val_loss improved from 0.03543 to 0.03376, saving model to /data/models/20200827_data_subset/20200827_multiplex_COH_normalized_512x512_subset_all_tissue.h5
# 60/60 [==============================] - 22s 363ms/step - loss: 0.0364 - semantic_0_loss: 0.0123 - semantic_1_loss: 0.0171 - semantic_2_loss: 0.0020 - semantic_3_loss: 0.0050 - val_loss: 0.0338 - val_semantic_0_loss: 0.0114 - val_semantic_1_loss: 0.0156 - val_semantic_2_loss: 0.0020 - val_semantic_3_loss: 0.0048
# Epoch 29/35
# 59/60 [============================>.] - ETA: 0s - loss: 0.0399 - semantic_0_loss: 0.0135 - semantic_1_loss: 0.0193 - semantic_2_loss: 0.0021 - semantic_3_loss: 0.0051
# Epoch 00029: val_loss did not improve from 0.03376
# 60/60 [==============================] - 18s 306ms/step - loss: 0.0397 - semantic_0_loss: 0.0134 - semantic_1_loss: 0.0192 - semantic_2_loss: 0.0020 - semantic_3_loss: 0.0051 - val_loss: 0.0400 - val_semantic_0_loss: 0.0150 - val_semantic_1_loss: 0.0179 - val_semantic_2_loss: 0.0021 - val_semantic_3_loss: 0.0050
# Epoch 30/35
# 59/60 [============================>.] - ETA: 0s - loss: 0.0387 - semantic_0_loss: 0.0131 - semantic_1_loss: 0.0185 - semantic_2_loss: 0.0020 - semantic_3_loss: 0.0051
# Epoch 00030: val_loss did not improve from 0.03376
# 60/60 [==============================] - 19s 309ms/step - loss: 0.0388 - semantic_0_loss: 0.0131 - semantic_1_loss: 0.0185 - semantic_2_loss: 0.0021 - semantic_3_loss: 0.0051 - val_loss: 0.0368 - val_semantic_0_loss: 0.0126 - val_semantic_1_loss: 0.0172 - val_semantic_2_loss: 0.0021 - val_semantic_3_loss: 0.0050
# Epoch 31/35
# 59/60 [============================>.] - ETA: 0s - loss: 0.0379 - semantic_0_loss: 0.0128 - semantic_1_loss: 0.0181 - semantic_2_loss: 0.0020 - semantic_3_loss: 0.0050
# Epoch 00031: val_loss did not improve from 0.03376
# 60/60 [==============================] - 18s 305ms/step - loss: 0.0380 - semantic_0_loss: 0.0128 - semantic_1_loss: 0.0181 - semantic_2_loss: 0.0020 - semantic_3_loss: 0.0050 - val_loss: 0.0365 - val_semantic_0_loss: 0.0125 - val_semantic_1_loss: 0.0171 - val_semantic_2_loss: 0.0021 - val_semantic_3_loss: 0.0049
# Epoch 32/35
# 59/60 [============================>.] - ETA: 0s - loss: 0.0365 - semantic_0_loss: 0.0122 - semantic_1_loss: 0.0173 - semantic_2_loss: 0.0020 - semantic_3_loss: 0.0050
# Epoch 00032: val_loss did not improve from 0.03376
# 60/60 [==============================] - 19s 310ms/step - loss: 0.0362 - semantic_0_loss: 0.0121 - semantic_1_loss: 0.0172 - semantic_2_loss: 0.0020 - semantic_3_loss: 0.0050 - val_loss: 0.0354 - val_semantic_0_loss: 0.0119 - val_semantic_1_loss: 0.0165 - val_semantic_2_loss: 0.0021 - val_semantic_3_loss: 0.0049
# Epoch 33/35
# 59/60 [============================>.] - ETA: 0s - loss: 0.0384 - semantic_0_loss: 0.0130 - semantic_1_loss: 0.0181 - semantic_2_loss: 0.0021 - semantic_3_loss: 0.0051
# Epoch 00033: val_loss did not improve from 0.03376
# 60/60 [==============================] - 19s 310ms/step - loss: 0.0383 - semantic_0_loss: 0.0129 - semantic_1_loss: 0.0181 - semantic_2_loss: 0.0021 - semantic_3_loss: 0.0051 - val_loss: 0.0345 - val_semantic_0_loss: 0.0117 - val_semantic_1_loss: 0.0161 - val_semantic_2_loss: 0.0019 - val_semantic_3_loss: 0.0048
# Epoch 34/35
# 59/60 [============================>.] - ETA: 0s - loss: 0.0358 - semantic_0_loss: 0.0120 - semantic_1_loss: 0.0169 - semantic_2_loss: 0.0020 - semantic_3_loss: 0.0050
# Epoch 00034: val_loss did not improve from 0.03376
# 60/60 [==============================] - 18s 308ms/step - loss: 0.0355 - semantic_0_loss: 0.0119 - semantic_1_loss: 0.0167 - semantic_2_loss: 0.0019 - semantic_3_loss: 0.0050 - val_loss: 0.0343 - val_semantic_0_loss: 0.0116 - val_semantic_1_loss: 0.0160 - val_semantic_2_loss: 0.0019 - val_semantic_3_loss: 0.0047
# Epoch 35/35
# 59/60 [============================>.] - ETA: 0s - loss: 0.0368 - semantic_0_loss: 0.0124 - semantic_1_loss: 0.0174 - semantic_2_loss: 0.0020 - semantic_3_loss: 0.0050
# Epoch 00035: val_loss did not improve from 0.03376
# 60/60 [==============================] - 19s 308ms/step - loss: 0.0366 - semantic_0_loss: 0.0124 - semantic_1_loss: 0.0173 - semantic_2_loss: 0.0020 - semantic_3_loss: 0.0050 - val_loss: 0.0359 - val_semantic_0_loss: 0.0123 - val_semantic_1_loss: 0.0166 - val_semantic_2_loss: 0.0021 - val_semantic_3_loss: 0.0049

# %%
new_model.load_weights(os.path.join(MODEL_DIR, model_name + '.h5'))

# %%
test_dict = np.load(NPZ_DIR + '20200819_multiplex_normalized_512x512_test.npz')
X_test = test_dict['X']
y_test = test_dict['y']
X_test = phase_preprocess(X_test, 128)

# %%
from deepcell_toolbox.utils import tile_image, untile_image
from deepcell.applications import MultiplexSegmentation
app = MultiplexSegmentation(use_pretrained_weights=False)
tiled_data, tile_info = tile_image(X_test, model_input_shape=(256, 256), stride_ratio=1)

# %%
model_output = new_model.predict(tiled_data)

# %%
inner_distance, outer_distance, fgbg, pixelwise = app._untile_output(model_output, tile_info)

# %%
from deepcell_toolbox.deep_watershed import deep_watershed_mibi
labeled_images = deep_watershed_mibi({'inner-distance': inner_distance,
                                     'pixelwise-interior': pixelwise[:, :, :, 1:2]}, 
                                     maxima_threshold=0.02, maxima_model_smooth=0,
                                    interior_threshold=0.3,
                                    radius=5,
                                    small_objects_threshold=10,
                                     fill_holes_threshold=10)

# %%
from skimage.exposure import rescale_intensity
from skimage.segmentation import find_boundaries
import copy
def make_color_overlay(input_data):
    """Create a color overlay from 2 channel image data
    
    Args:
        input_data: stack of input images
    
    Returns:
        numpy.array: color-adjusted stack of overlays in RGB mode
    """
    RGB_data = np.zeros(input_data.shape[:3] + (3, ), dtype='float32')
    
    # rescale channels to aid plotting
    for img in range(input_data.shape[0]):
        for channel in range(input_data.shape[-1]):
            # get histogram for non-zero pixels
            percentiles = np.percentile(input_data[img, :, :, channel][input_data[img, :, :, channel] > 0],
                                            [5, 95])
            rescaled_intensity = rescale_intensity(input_data[img, :, :, channel],
                                                       in_range=(percentiles[0], percentiles[1]),
                                                       out_range='float32')
            RGB_data[img, :, :, channel + 1] = rescaled_intensity
        
    # create a blank array for red channel
    return RGB_data

def make_outline_overlay(RGB_data, predictions):
    boundaries = np.zeros_like(predictions)
    overlay_data = copy.copy(RGB_data)
    
    for img in range(predictions.shape[0]):
        boundary = find_boundaries(predictions[img], connectivity=1, mode='inner')
        boundaries[img, boundary > 0] = 1

    overlay_data[boundaries > 0, :] = 1
    
    return overlay_data

# %%
RGB_data = make_color_overlay(X_test[:, :, :, :])
true_overlay = make_outline_overlay(RGB_data, y_test[:, :, :, 0])

# %%
predicted_overlay = make_outline_overlay(RGB_data, labeled_images[..., 0])

# %%
import matplotlib.pyplot as plt
cmap = plt.get_cmap('viridis')
cmap.set_bad('black')
index = [27]
fig, axes = plt.subplots(2,3,figsize=(30,20))

axes = axes.flatten()
axes[0].imshow(outer_distance[index[0],..., 0])
axes[1].imshow(inner_distance[index[0],...,0], cmap='jet')
axes[2].imshow(pixelwise[index[0],...,1], cmap='jet')
axes[3].imshow(predicted_overlay[index[0], ...], cmap=cmap)
axes[4].imshow(true_overlay[index[0], ...], cmap=cmap)

axes[0].set_title('Outer Distance', fontsize=24)
axes[1].set_title('Inner distance', fontsize=24)
axes[2].set_title('Pixelwise Border', fontsize=24)
axes[3].set_title('Predicted Overlay', fontsize=24)
axes[4].set_title('True Overlay', fontsize=24)
# axes[5].set_title('Ground Truth Mask', fontsize=24)

for ax in axes.flatten():
    ax.set_axis_off()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. In future versions, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = copy.copy(mpl.cm.get_cmap("viridis"))
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
len(np.unique(true[true == 5]))
# Out:
# 0
