# %% [markdown]
# This notebook is part of the `deepcell-tf` documentation: https://deepcell.readthedocs.io/.

# %% [markdown]
# # Training a segmentation model
#
# `deepcell-tf` leverages [Jupyter Notebooks](https://jupyter.org) in order to train models. Example notebooks are available for most model architectures in the [notebooks folder](https://github.com/vanvalenlab/deepcell-tf/tree/master/notebooks). Most notebooks are structured similarly to this example and thus this notebook serves as a core reference for the deepcell approach to model training.

# %%
import os
import errno

import pandas as pd
import numpy as np

import deepcell

from matplotlib import pyplot as plt

from sklearn.model_selection import train_test_split
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# /usr/local/lib/python3.6/dist-packages/deepcell/utils/__init__.py:49: UserWarning: To use `compute_overlap`, the C extensions must be built using `python setup.py build_ext --inplace`
#   warnings.warn('To use `compute_overlap`, the C extensions must be built '

# %% [markdown]
# ## Load the data
#
# ### Download the data from `deepcell.datasets`
#
# `deepcell.datasets` provides access to a set of annotated live-cell imaging datasets which can be used for training cell segmentation and tracking models.
# All dataset objects share the `load_data()` method, which allows the user to specify the name of the file (`path`), the fraction of data reserved for testing (`test_size`) and a `seed` which is used to generate the random train-test split.
# Metadata associated with the dataset can be accessed through the `metadata` attribute.

# %%
# Download the data (saves to ~/.keras/datasets)
filename = 'mousebrain.npz'
test_size = 0.1 # % of data saved as test
seed = 0 # seed for random train-test split

(X_train, y_train), (X_test, y_test) = deepcell.datasets.mousebrain.load_data(
    filename, test_size=test_size, seed=seed)

# %% [markdown]
# The `PanopticNet` models require square inputs. Reshape the data to meet the model requirements.

# %%
print(X_train.shape)
# Out:
# (198, 15, 256, 256, 1)

# %%
from deepcell.utils.data_utils import reshape_movie

size = 256

X_train, y_train = reshape_movie(X_train, y_train, reshape_size=size)
X_test, y_test = reshape_movie(X_test, y_test, reshape_size=size)
print('X.shape: {}\ny.shape: {}'.format(X_train.shape, y_train.shape))
# Out:
# Reshaped feature data from (198, 15, 256, 256, 1) to (198, 15, 256, 256, 1)
# Reshaped training data from (198, 15, 256, 256, 1) to (198, 15, 256, 256, 1)
# Reshaped feature data from (22, 15, 256, 256, 1) to (22, 15, 256, 256, 1)
# Reshaped training data from (22, 15, 256, 256, 1) to (22, 15, 256, 256, 1)
# X.shape: (198, 15, 256, 256, 1)
# y.shape: (198, 15, 256, 256, 1)

# %% [markdown]
# ## Set up filepath constants

# %%
# change DATA_DIR if you are not using `deepcell.datasets`
DATA_DIR = os.path.expanduser(os.path.join('~', '.keras', 'datasets'))

# DATA_FILE should be a npz file, preferably from `make_training_data`
DATA_FILE = os.path.join(DATA_DIR, filename)

# confirm the data file is available
assert os.path.isfile(DATA_FILE)

# %%
# Set up other required filepaths

# If the data file is in a subdirectory, mirror it in MODEL_DIR and LOG_DIR
PREFIX = os.path.relpath(os.path.dirname(DATA_FILE), DATA_DIR)

ROOT_DIR = '/data'  # TODO: Change this! Usually a mounted volume
MODEL_DIR = os.path.abspath(os.path.join(ROOT_DIR, 'models', PREFIX))
LOG_DIR = os.path.abspath(os.path.join(ROOT_DIR, 'logs', PREFIX))

# create directories if they do not exist
for d in (MODEL_DIR, LOG_DIR):
    try:
        os.makedirs(d)
    except OSError as exc:  # Guard against race condition
        if exc.errno != errno.EEXIST:
            raise

# %% [markdown]
# ## Create the PanopticNet Model
#
# Here we instantiate a `PanopticNet` model from `deepcell.model_zoo` using 3 semantic heads:
# inner distance (1 class),
# outer distance (1 class),
# foreground/background distance (2 classes)

# %%
frames_per_batch = 5
temporal_mode = 'gru'

# %%
from deepcell.model_zoo.panopticnet import PanopticNet

model = PanopticNet(
    backbone='resnet50',
    input_shape=X_train.shape[2:],
    frames_per_batch=frames_per_batch, 
    norm_method='std',
    num_semantic_heads=3,
    temporal_mode=temporal_mode,
    num_semantic_classes=[1, 1, 2], # inner distance, outer distance, fgbg
    location=True,  # should always be true
    include_top=True)
# Out:
# conv name is:  conv_mtf_P3
# conv name is:  conv_mtf_P4
# conv name is:  conv_mtf_P5
# conv name is:  conv_mtf_P6
# conv name is:  conv_mtf_P7

# %% [markdown]
# ## Prepare for training
#
# ### Set up training parameters.
#
# There are a number of tunable hyper parameters necessary for training deep learning models:
#
# **model_name**: Incorporated into any files generated during the training process.
#
# **backbone**: The majority of DeepCell models support a variety backbone choices specified in the "backbone" parameter. Backbones are provided through [keras_applications](https://github.com/keras-team/keras-applications) and can be instantiated with weights that are pretrained on ImageNet.
#
# **n_epoch**: The number of complete passes through the training dataset.
#
# **lr**: The learning rate determines the speed at which the model learns. Specifically it controls the relative size of the updates to model values after each batch.
#
# **optimizer**: The TensorFlow module [tf.keras.optimizers](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers) offers optimizers with a variety of algorithm implementations. DeepCell typically uses the Adam or the SGD optimizers.
#
# **lr_sched**: A learning rate scheduler allows the learning rate to adapt over the course of model training. Typically a larger learning rate is preferred during the start of the training process, while a small learning rate allows for fine-tuning during the end of training.
#
# **batch_size**: The batch size determines the number of samples that are processed before the model is updated. The value must be greater than one and less than or equal to the number of samples in the training dataset.

# %%
from tensorflow.keras.optimizers import SGD, Adam
from deepcell.utils.train_utils import rate_scheduler

model_name = 'mousebrain3D_5x256x256_constant'
model_path = os.path.join(MODEL_DIR, '{}.h5'.format(model_name))
loss_path = os.path.join(MODEL_DIR, '{}.npz'.format(model_name))

fill_mode = 'constant'
cval = 0

n_epoch = 30  # Number of training epochs
test_size = .20  # % of data saved as test
norm_method = 'whole_image'  # data normalization

optimizer = Adam(lr=1e-5, clipnorm=0.001)
lr_sched = rate_scheduler(lr=1e-5, decay=0.99)

batch_size = 1

min_objects = 2  # throw out images with fewer than this many objects

# %% [markdown]
# ### Create the DataGenerators
#
# The `SemanticDataGenerator` can output any number of transformations for each image. These transformations are passed to `generator.flow()` as a list of transform names.
#
# Here we use `"inner-distance"`, `"outer-distance"` and `"fgbg"` to correspond to the inner distance, outer distance, and foreground background semantic heads, respectively. Keyword arguments may also be passed to each transform as a `dict` of transform names to `kwargs`.

# %%
from deepcell import image_generators
from deepcell.utils import train_utils

transforms = ['inner-distance', 'outer-distance', 'fgbg']
transforms_kwargs = {'outer-distance': {'erosion_width': 0}}



# use augmentation for training but not validation
datagen = image_generators.SemanticMovieGenerator(
    rotation_range=180,
    shear_range=0,
    zoom_range=(0.75, 1.25),
    fill_mode=fill_mode,
    cval=cval,
    horizontal_flip=True,
    vertical_flip=True)

datagen_val = image_generators.SemanticMovieGenerator(
    rotation_range=0,
    shear_range=0,
    zoom_range=0,
    fill_mode=fill_mode,
    cval=cval,
    horizontal_flip=0,
    vertical_flip=0)
    
train_data = datagen.flow(
    {'X': X_train, 'y': y_train},
    seed=seed,
    transforms=transforms,
    frames_per_batch=frames_per_batch,
    transforms_kwargs=transforms_kwargs,
    min_objects=min_objects,
    batch_size=batch_size)

val_data = datagen_val.flow(
    {'X': X_test, 'y': y_test},
    seed=seed,
    frames_per_batch=frames_per_batch,
    transforms=transforms,
    transforms_kwargs=transforms_kwargs,
    min_objects=min_objects,
    batch_size=batch_size)

# %% [markdown]
# Visualize the data generator output.

# %%
from matplotlib import pyplot as plt

inputs, outputs = train_data.next()

img = inputs[0]
inner_distance = outputs[0]
outer_distance = outputs[1]
fgbg = outputs[2]

fig, axes = plt.subplots(1, 4, figsize=(15, 15))

slice=1

axes[0].imshow(img[slice, ..., 0], cmap='jet')
axes[0].set_title('Source Image')

axes[1].imshow(inner_distance[0, slice, ..., 0])
axes[1].set_title('Inner Distance')

axes[2].imshow(outer_distance[0, slice, ..., 0])
axes[2].set_title('Outer Distance')

axes[3].imshow(fgbg[0, slice, ..., 0])
axes[3].set_title('Foreground/Background')

plt.show()

# %% [markdown]
# ### Create a loss function for each semantic head
#
# Each semantic head is trained with it's own loss function. Mean Square Error is used for regression-based heads, whereas `weighted_categorical_crossentropy` is used for classification heads.
#
# The losses are saved as a dictionary and passed to `model.compile`.

# %%
# Create a dictionary of losses for each semantic head
from tensorflow.python.keras.losses import MSE
from deepcell import losses


def semantic_loss(n_classes):
    def _semantic_loss(y_pred, y_true):
        if n_classes > 1:
            return 0.01 * losses.weighted_categorical_crossentropy(
                y_pred, y_true, n_classes=n_classes)
        return MSE(y_pred, y_true)
    return _semantic_loss


loss = {}

# Give losses for all of the semantic heads
for layer in model.layers:
    if layer.name.startswith('semantic_'):
        n_classes = layer.output_shape[-1]
        loss[layer.name] = semantic_loss(n_classes)

# %%
model.compile(loss=loss, optimizer=optimizer)

# %% [markdown]
# ## Train the model
#
# Call `fit_generator` on the compiled model, along with a default set of callbacks.

# %%
from deepcell.utils.train_utils import get_callbacks
from deepcell.utils.train_utils import count_gpus


num_gpus = count_gpus()

print('Training on', num_gpus, 'GPUs.')

train_callbacks = get_callbacks(
    model_path,
    lr_sched=lr_sched,
    tensorboard_log_dir=LOG_DIR,
    save_weights_only=num_gpus >= 2,
    monitor='val_loss',
    verbose=1)

loss_history = model.fit_generator(
    train_data,
    steps_per_epoch=train_data.y.shape[0] // batch_size,
    epochs=n_epoch,
    validation_data=val_data,
    validation_steps=val_data.y.shape[0] // batch_size,
    callbacks=train_callbacks)
# Out:
# Training on 1 GPUs.
# Epoch 1/30
# 197/198 [============================>.] - ETA: 0s - loss: 0.0815 - semantic_0_loss: 0.0356 - semantic_1_loss: 0.0414 - semantic_2_loss: 0.0046Epoch 1/30
#  22/198 [==>...........................] - ETA: 1:51 - loss: 0.0245 - semantic_0_loss: 0.0045 - semantic_1_loss: 0.0169 - semantic_2_loss: 0.0031
# Epoch 00001: val_loss improved from inf to 0.02449, saving model to /data/models/mousebrain3D_5x256x256_constant.h5
# 198/198 [==============================] - 255s 1s/step - loss: 0.0812 - semantic_0_loss: 0.0354 - semantic_1_loss: 0.0412 - semantic_2_loss: 0.0046 - val_loss: 0.0245 - val_semantic_0_loss: 0.0045 - val_semantic_1_loss: 0.0169 - val_semantic_2_loss: 0.0031
# Epoch 2/30
# 197/198 [============================>.] - ETA: 0s - loss: 0.0141 - semantic_0_loss: 0.0028 - semantic_1_loss: 0.0089 - semantic_2_loss: 0.0025Epoch 1/30
#  22/198 [==>...........................] - ETA: 26s - loss: 0.0165 - semantic_0_loss: 0.0033 - semantic_1_loss: 0.0107 - semantic_2_loss: 0.0024
# Epoch 00002: val_loss improved from 0.02449 to 0.01645, saving model to /data/models/mousebrain3D_5x256x256_constant.h5
# 198/198 [==============================] - 90s 456ms/step - loss: 0.0141 - semantic_0_loss: 0.0027 - semantic_1_loss: 0.0088 - semantic_2_loss: 0.0025 - val_loss: 0.0165 - val_semantic_0_loss: 0.0033 - val_semantic_1_loss: 0.0107 - val_semantic_2_loss: 0.0024
# Epoch 3/30
# 197/198 [============================>.] - ETA: 0s - loss: 0.0113 - semantic_0_loss: 0.0022 - semantic_1_loss: 0.0070 - semantic_2_loss: 0.0021Epoch 1/30
#  22/198 [==>...........................] - ETA: 26s - loss: 0.0130 - semantic_0_loss: 0.0030 - semantic_1_loss: 0.0078 - semantic_2_loss: 0.0022
# Epoch 00003: val_loss improved from 0.01645 to 0.01303, saving model to /data/models/mousebrain3D_5x256x256_constant.h5
# 198/198 [==============================] - 90s 456ms/step - loss: 0.0113 - semantic_0_loss: 0.0022 - semantic_1_loss: 0.0070 - semantic_2_loss: 0.0021 - val_loss: 0.0130 - val_semantic_0_loss: 0.0030 - val_semantic_1_loss: 0.0078 - val_semantic_2_loss: 0.0022
# Epoch 4/30
# 197/198 [============================>.] - ETA: 0s - loss: 0.0102 - semantic_0_loss: 0.0020 - semantic_1_loss: 0.0063 - semantic_2_loss: 0.0019Epoch 1/30
#  22/198 [==>...........................] - ETA: 26s - loss: 0.0125 - semantic_0_loss: 0.0029 - semantic_1_loss: 0.0075 - semantic_2_loss: 0.0021
# Epoch 00004: val_loss improved from 0.01303 to 0.01246, saving model to /data/models/mousebrain3D_5x256x256_constant.h5
# 198/198 [==============================] - 90s 456ms/step - loss: 0.0102 - semantic_0_loss: 0.0020 - semantic_1_loss: 0.0063 - semantic_2_loss: 0.0019 - val_loss: 0.0125 - val_semantic_0_loss: 0.0029 - val_semantic_1_loss: 0.0075 - val_semantic_2_loss: 0.0021
# Epoch 5/30
# 197/198 [============================>.] - ETA: 0s - loss: 0.0098 - semantic_0_loss: 0.0019 - semantic_1_loss: 0.0061 - semantic_2_loss: 0.0018Epoch 1/30
#  22/198 [==>...........................] - ETA: 26s - loss: 0.0126 - semantic_0_loss: 0.0028 - semantic_1_loss: 0.0077 - semantic_2_loss: 0.0021
# Epoch 00005: val_loss did not improve from 0.01246
# 198/198 [==============================] - 88s 447ms/step - loss: 0.0098 - semantic_0_loss: 0.0019 - semantic_1_loss: 0.0061 - semantic_2_loss: 0.0018 - val_loss: 0.0126 - val_semantic_0_loss: 0.0028 - val_semantic_1_loss: 0.0077 - val_semantic_2_loss: 0.0021
# Epoch 6/30
# 197/198 [============================>.] - ETA: 0s - loss: 0.0089 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0056 - semantic_2_loss: 0.0017Epoch 1/30
#  22/198 [==>...........................] - ETA: 26s - loss: 0.0111 - semantic_0_loss: 0.0024 - semantic_1_loss: 0.0066 - semantic_2_loss: 0.0020
# Epoch 00006: val_loss improved from 0.01246 to 0.01105, saving model to /data/models/mousebrain3D_5x256x256_constant.h5
# 198/198 [==============================] - 90s 456ms/step - loss: 0.0089 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0056 - semantic_2_loss: 0.0017 - val_loss: 0.0111 - val_semantic_0_loss: 0.0024 - val_semantic_1_loss: 0.0066 - val_semantic_2_loss: 0.0020
# Epoch 7/30
# 197/198 [============================>.] - ETA: 0s - loss: 0.0086 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0054 - semantic_2_loss: 0.0016Epoch 1/30
#  22/198 [==>...........................] - ETA: 26s - loss: 0.0110 - semantic_0_loss: 0.0025 - semantic_1_loss: 0.0066 - semantic_2_loss: 0.0019
# Epoch 00007: val_loss improved from 0.01105 to 0.01098, saving model to /data/models/mousebrain3D_5x256x256_constant.h5
# 198/198 [==============================] - 90s 456ms/step - loss: 0.0086 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0054 - semantic_2_loss: 0.0016 - val_loss: 0.0110 - val_semantic_0_loss: 0.0025 - val_semantic_1_loss: 0.0066 - val_semantic_2_loss: 0.0019
# Epoch 8/30
# 197/198 [============================>.] - ETA: 0s - loss: 0.0083 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0051 - semantic_2_loss: 0.0016Epoch 1/30
#  22/198 [==>...........................] - ETA: 26s - loss: 0.0108 - semantic_0_loss: 0.0024 - semantic_1_loss: 0.0065 - semantic_2_loss: 0.0018
# Epoch 00008: val_loss improved from 0.01098 to 0.01081, saving model to /data/models/mousebrain3D_5x256x256_constant.h5
# 198/198 [==============================] - 90s 456ms/step - loss: 0.0083 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0051 - semantic_2_loss: 0.0016 - val_loss: 0.0108 - val_semantic_0_loss: 0.0024 - val_semantic_1_loss: 0.0065 - val_semantic_2_loss: 0.0018
# Epoch 9/30
# 197/198 [============================>.] - ETA: 0s - loss: 0.0079 - semantic_0_loss: 0.0014 - semantic_1_loss: 0.0050 - semantic_2_loss: 0.0015Epoch 1/30
#  22/198 [==>...........................] - ETA: 26s - loss: 0.0107 - semantic_0_loss: 0.0024 - semantic_1_loss: 0.0064 - semantic_2_loss: 0.0018
# Epoch 00009: val_loss improved from 0.01081 to 0.01069, saving model to /data/models/mousebrain3D_5x256x256_constant.h5
# 198/198 [==============================] - 90s 456ms/step - loss: 0.0079 - semantic_0_loss: 0.0014 - semantic_1_loss: 0.0049 - semantic_2_loss: 0.0015 - val_loss: 0.0107 - val_semantic_0_loss: 0.0024 - val_semantic_1_loss: 0.0064 - val_semantic_2_loss: 0.0018
# Epoch 10/30
# 197/198 [============================>.] - ETA: 0s - loss: 0.0078 - semantic_0_loss: 0.0014 - semantic_1_loss: 0.0050 - semantic_2_loss: 0.0014Epoch 1/30
#  22/198 [==>...........................] - ETA: 26s - loss: 0.0105 - semantic_0_loss: 0.0024 - semantic_1_loss: 0.0064 - semantic_2_loss: 0.0018
# Epoch 00012: val_loss improved from 0.01065 to 0.01053, saving model to /data/models/mousebrain3D_5x256x256_constant.h5
# 198/198 [==============================] - 90s 456ms/step - loss: 0.0078 - semantic_0_loss: 0.0014 - semantic_1_loss: 0.0050 - semantic_2_loss: 0.0014 - val_loss: 0.0105 - val_semantic_0_loss: 0.0024 - val_semantic_1_loss: 0.0064 - val_semantic_2_loss: 0.0018
# Epoch 13/30
# 197/198 [============================>.] - ETA: 0s - loss: 0.0076 - semantic_0_loss: 0.0013 - semantic_1_loss: 0.0048 - semantic_2_loss: 0.0014Epoch 1/30
#  22/198 [==>...........................] - ETA: 26s - loss: 0.0112 - semantic_0_loss: 0.0023 - semantic_1_loss: 0.0068 - semantic_2_loss: 0.0020
# Epoch 00013: val_loss did not improve from 0.01053
# 198/198 [==============================] - 88s 446ms/step - loss: 0.0076 - semantic_0_loss: 0.0014 - semantic_1_loss: 0.0048 - semantic_2_loss: 0.0014 - val_loss: 0.0112 - val_semantic_0_loss: 0.0023 - val_semantic_1_loss: 0.0068 - val_semantic_2_loss: 0.0020
# Epoch 14/30
# 197/198 [============================>.] - ETA: 0s - loss: 0.0071 - semantic_0_loss: 0.0013 - semantic_1_loss: 0.0045 - semantic_2_loss: 0.0013Epoch 1/30
#  22/198 [==>...........................] - ETA: 26s - loss: 0.0108 - semantic_0_loss: 0.0023 - semantic_1_loss: 0.0067 - semantic_2_loss: 0.0018
# Epoch 00014: val_loss did not improve from 0.01053
# 198/198 [==============================] - 88s 446ms/step - loss: 0.0071 - semantic_0_loss: 0.0013 - semantic_1_loss: 0.0045 - semantic_2_loss: 0.0013 - val_loss: 0.0108 - val_semantic_0_loss: 0.0023 - val_semantic_1_loss: 0.0067 - val_semantic_2_loss: 0.0018
# Epoch 15/30
# 197/198 [============================>.] - ETA: 0s - loss: 0.0072 - semantic_0_loss: 0.0013 - semantic_1_loss: 0.0045 - semantic_2_loss: 0.0014Epoch 1/30
#  22/198 [==>...........................] - ETA: 26s - loss: 0.0115 - semantic_0_loss: 0.0024 - semantic_1_loss: 0.0073 - semantic_2_loss: 0.0018
# Epoch 00015: val_loss did not improve from 0.01053
# 198/198 [==============================] - 88s 447ms/step - loss: 0.0072 - semantic_0_loss: 0.0013 - semantic_1_loss: 0.0045 - semantic_2_loss: 0.0014 - val_loss: 0.0115 - val_semantic_0_loss: 0.0024 - val_semantic_1_loss: 0.0073 - val_semantic_2_loss: 0.0018
# Epoch 16/30
# 197/198 [============================>.] - ETA: 0s - loss: 0.0073 - semantic_0_loss: 0.0013 - semantic_1_loss: 0.0046 - semantic_2_loss: 0.0014Epoch 1/30
#  22/198 [==>...........................] - ETA: 26s - loss: 0.0097 - semantic_0_loss: 0.0023 - semantic_1_loss: 0.0059 - semantic_2_loss: 0.0016
# Epoch 00016: val_loss improved from 0.01053 to 0.00971, saving model to /data/models/mousebrain3D_5x256x256_constant.h5
# 198/198 [==============================] - 90s 457ms/step - loss: 0.0073 - semantic_0_loss: 0.0013 - semantic_1_loss: 0.0046 - semantic_2_loss: 0.0014 - val_loss: 0.0097 - val_semantic_0_loss: 0.0023 - val_semantic_1_loss: 0.0059 - val_semantic_2_loss: 0.0016
# Epoch 17/30
# 197/198 [============================>.] - ETA: 0s - loss: 0.0073 - semantic_0_loss: 0.0013 - semantic_1_loss: 0.0046 - semantic_2_loss: 0.0014Epoch 1/30
#  22/198 [==>...........................] - ETA: 26s - loss: 0.0105 - semantic_0_loss: 0.0024 - semantic_1_loss: 0.0065 - semantic_2_loss: 0.0016
# Epoch 00017: val_loss did not improve from 0.00971
# 198/198 [==============================] - 88s 446ms/step - loss: 0.0073 - semantic_0_loss: 0.0013 - semantic_1_loss: 0.0046 - semantic_2_loss: 0.0014 - val_loss: 0.0105 - val_semantic_0_loss: 0.0024 - val_semantic_1_loss: 0.0065 - val_semantic_2_loss: 0.0016
# Epoch 18/30
# 197/198 [============================>.] - ETA: 0s - loss: 0.0070 - semantic_0_loss: 0.0012 - semantic_1_loss: 0.0044 - semantic_2_loss: 0.0014Epoch 1/30
#  22/198 [==>...........................] - ETA: 26s - loss: 0.0098 - semantic_0_loss: 0.0023 - semantic_1_loss: 0.0059 - semantic_2_loss: 0.0016
# Epoch 00018: val_loss did not improve from 0.00971
# 198/198 [==============================] - 88s 447ms/step - loss: 0.0069 - semantic_0_loss: 0.0012 - semantic_1_loss: 0.0044 - semantic_2_loss: 0.0014 - val_loss: 0.0098 - val_semantic_0_loss: 0.0023 - val_semantic_1_loss: 0.0059 - val_semantic_2_loss: 0.0016
# Epoch 19/30
# 197/198 [============================>.] - ETA: 0s - loss: 0.0067 - semantic_0_loss: 0.0012 - semantic_1_loss: 0.0042 - semantic_2_loss: 0.0013Epoch 1/30
#  22/198 [==>...........................] - ETA: 26s - loss: 0.0112 - semantic_0_loss: 0.0024 - semantic_1_loss: 0.0071 - semantic_2_loss: 0.0017
# Epoch 00019: val_loss did not improve from 0.00971
# 198/198 [==============================] - 89s 447ms/step - loss: 0.0067 - semantic_0_loss: 0.0012 - semantic_1_loss: 0.0042 - semantic_2_loss: 0.0013 - val_loss: 0.0112 - val_semantic_0_loss: 0.0024 - val_semantic_1_loss: 0.0071 - val_semantic_2_loss: 0.0017
# Epoch 20/30
# 197/198 [============================>.] - ETA: 0s - loss: 0.0066 - semantic_0_loss: 0.0012 - semantic_1_loss: 0.0042 - semantic_2_loss: 0.0013Epoch 1/30
#  22/198 [==>...........................] - ETA: 26s - loss: 0.0102 - semantic_0_loss: 0.0023 - semantic_1_loss: 0.0063 - semantic_2_loss: 0.0016
# Epoch 00020: val_loss did not improve from 0.00971
# 198/198 [==============================] - 88s 447ms/step - loss: 0.0069 - semantic_0_loss: 0.0012 - semantic_1_loss: 0.0043 - semantic_2_loss: 0.0013 - val_loss: 0.0102 - val_semantic_0_loss: 0.0023 - val_semantic_1_loss: 0.0063 - val_semantic_2_loss: 0.0016
# Epoch 21/30
# 197/198 [============================>.] - ETA: 0s - loss: 0.0068 - semantic_0_loss: 0.0012 - semantic_1_loss: 0.0043 - semantic_2_loss: 0.0013Epoch 1/30
#  22/198 [==>...........................] - ETA: 26s - loss: 0.0117 - semantic_0_loss: 0.0025 - semantic_1_loss: 0.0075 - semantic_2_loss: 0.0017
# Epoch 00021: val_loss did not improve from 0.00971
# 198/198 [==============================] - 88s 445ms/step - loss: 0.0068 - semantic_0_loss: 0.0012 - semantic_1_loss: 0.0043 - semantic_2_loss: 0.0013 - val_loss: 0.0117 - val_semantic_0_loss: 0.0025 - val_semantic_1_loss: 0.0075 - val_semantic_2_loss: 0.0017
# Epoch 22/30
# 197/198 [============================>.] - ETA: 0s - loss: 0.0065 - semantic_0_loss: 0.0011 - semantic_1_loss: 0.0041 - semantic_2_loss: 0.0013Epoch 1/30
#  22/198 [==>...........................] - ETA: 25s - loss: 0.0102 - semantic_0_loss: 0.0022 - semantic_1_loss: 0.0064 - semantic_2_loss: 0.0016
# Epoch 00022: val_loss did not improve from 0.00971
# 198/198 [==============================] - 88s 446ms/step - loss: 0.0065 - semantic_0_loss: 0.0011 - semantic_1_loss: 0.0041 - semantic_2_loss: 0.0013 - val_loss: 0.0102 - val_semantic_0_loss: 0.0022 - val_semantic_1_loss: 0.0064 - val_semantic_2_loss: 0.0016
# Epoch 23/30
# 197/198 [============================>.] - ETA: 0s - loss: 0.0063 - semantic_0_loss: 0.0011 - semantic_1_loss: 0.0040 - semantic_2_loss: 0.0012Epoch 1/30
#  22/198 [==>...........................] - ETA: 26s - loss: 0.0099 - semantic_0_loss: 0.0023 - semantic_1_loss: 0.0060 - semantic_2_loss: 0.0015
# Epoch 00023: val_loss did not improve from 0.00971
# 198/198 [==============================] - 89s 447ms/step - loss: 0.0063 - semantic_0_loss: 0.0011 - semantic_1_loss: 0.0040 - semantic_2_loss: 0.0012 - val_loss: 0.0099 - val_semantic_0_loss: 0.0023 - val_semantic_1_loss: 0.0060 - val_semantic_2_loss: 0.0015
# Epoch 24/30
# 197/198 [============================>.] - ETA: 0s - loss: 0.0066 - semantic_0_loss: 0.0011 - semantic_1_loss: 0.0042 - semantic_2_loss: 0.0013Epoch 1/30
#  22/198 [==>...........................] - ETA: 26s - loss: 0.0108 - semantic_0_loss: 0.0023 - semantic_1_loss: 0.0067 - semantic_2_loss: 0.0018
# Epoch 00024: val_loss did not improve from 0.00971
# 198/198 [==============================] - 88s 446ms/step - loss: 0.0066 - semantic_0_loss: 0.0011 - semantic_1_loss: 0.0042 - semantic_2_loss: 0.0013 - val_loss: 0.0108 - val_semantic_0_loss: 0.0023 - val_semantic_1_loss: 0.0067 - val_semantic_2_loss: 0.0018
# Epoch 25/30
# 197/198 [============================>.] - ETA: 0s - loss: 0.0066 - semantic_0_loss: 0.0011 - semantic_1_loss: 0.0042 - semantic_2_loss: 0.0013Epoch 1/30
#  22/198 [==>...........................] - ETA: 25s - loss: 0.0101 - semantic_0_loss: 0.0024 - semantic_1_loss: 0.0061 - semantic_2_loss: 0.0016
# Epoch 00025: val_loss did not improve from 0.00971
# 198/198 [==============================] - 88s 446ms/step - loss: 0.0066 - semantic_0_loss: 0.0011 - semantic_1_loss: 0.0042 - semantic_2_loss: 0.0013 - val_loss: 0.0101 - val_semantic_0_loss: 0.0024 - val_semantic_1_loss: 0.0061 - val_semantic_2_loss: 0.0016
# Epoch 26/30
# 197/198 [============================>.] - ETA: 0s - loss: 0.0065 - semantic_0_loss: 0.0011 - semantic_1_loss: 0.0041 - semantic_2_loss: 0.0013Epoch 1/30
#  22/198 [==>...........................] - ETA: 26s - loss: 0.0098 - semantic_0_loss: 0.0023 - semantic_1_loss: 0.0060 - semantic_2_loss: 0.0016
# Epoch 00026: val_loss did not improve from 0.00971
# 198/198 [==============================] - 88s 447ms/step - loss: 0.0065 - semantic_0_loss: 0.0011 - semantic_1_loss: 0.0041 - semantic_2_loss: 0.0013 - val_loss: 0.0098 - val_semantic_0_loss: 0.0023 - val_semantic_1_loss: 0.0060 - val_semantic_2_loss: 0.0016
# Epoch 27/30
# 197/198 [============================>.] - ETA: 0s - loss: 0.0063 - semantic_0_loss: 0.0011 - semantic_1_loss: 0.0040 - semantic_2_loss: 0.0013Epoch 1/30
#  22/198 [==>...........................] - ETA: 26s - loss: 0.0114 - semantic_0_loss: 0.0026 - semantic_1_loss: 0.0069 - semantic_2_loss: 0.0019
# Epoch 00027: val_loss did not improve from 0.00971
# 198/198 [==============================] - 88s 447ms/step - loss: 0.0064 - semantic_0_loss: 0.0011 - semantic_1_loss: 0.0040 - semantic_2_loss: 0.0013 - val_loss: 0.0114 - val_semantic_0_loss: 0.0026 - val_semantic_1_loss: 0.0069 - val_semantic_2_loss: 0.0019
# Epoch 28/30
# 197/198 [============================>.] - ETA: 0s - loss: 0.0061 - semantic_0_loss: 0.0010 - semantic_1_loss: 0.0039 - semantic_2_loss: 0.0012Epoch 1/30
#  22/198 [==>...........................] - ETA: 26s - loss: 0.0106 - semantic_0_loss: 0.0023 - semantic_1_loss: 0.0067 - semantic_2_loss: 0.0016
# Epoch 00028: val_loss did not improve from 0.00971
# 198/198 [==============================] - 88s 447ms/step - loss: 0.0061 - semantic_0_loss: 0.0010 - semantic_1_loss: 0.0039 - semantic_2_loss: 0.0012 - val_loss: 0.0106 - val_semantic_0_loss: 0.0023 - val_semantic_1_loss: 0.0067 - val_semantic_2_loss: 0.0016
# Epoch 29/30
# 197/198 [============================>.] - ETA: 0s - loss: 0.0064 - semantic_0_loss: 0.0011 - semantic_1_loss: 0.0040 - semantic_2_loss: 0.0013Epoch 1/30
#  22/198 [==>...........................] - ETA: 26s - loss: 0.0102 - semantic_0_loss: 0.0023 - semantic_1_loss: 0.0064 - semantic_2_loss: 0.0016
# Epoch 00029: val_loss did not improve from 0.00971
# 198/198 [==============================] - 88s 446ms/step - loss: 0.0065 - semantic_0_loss: 0.0011 - semantic_1_loss: 0.0041 - semantic_2_loss: 0.0013 - val_loss: 0.0102 - val_semantic_0_loss: 0.0023 - val_semantic_1_loss: 0.0064 - val_semantic_2_loss: 0.0016
# Epoch 30/30
# 197/198 [============================>.] - ETA: 0s - loss: 0.0061 - semantic_0_loss: 0.0010 - semantic_1_loss: 0.0038 - semantic_2_loss: 0.0012Epoch 1/30
#  22/198 [==>...........................] - ETA: 26s - loss: 0.0105 - semantic_0_loss: 0.0023 - semantic_1_loss: 0.0066 - semantic_2_loss: 0.0017
# Epoch 00030: val_loss did not improve from 0.00971
# 198/198 [==============================] - 88s 447ms/step - loss: 0.0061 - semantic_0_loss: 0.0010 - semantic_1_loss: 0.0039 - semantic_2_loss: 0.0012 - val_loss: 0.0105 - val_semantic_0_loss: 0.0023 - val_semantic_1_loss: 0.0066 - val_semantic_2_loss: 0.0017

# %% [markdown]
# ## Predict on test data
#
# Use the trained model to predict on new data. First, create a new prediction model without the foreground background semantic head. While this head is very useful during training, the output is unused during prediction. By using `model.load_weights(path, by_name=True)`, the semantic head can be removed.

# %%
from deepcell.model_zoo.panopticnet import PanopticNet       

pred_frames_per_batch = frames_per_batch

prediction_model = PanopticNet(
    backbone='resnet50',
    input_shape=X_train.shape[2:],
    frames_per_batch=pred_frames_per_batch,
    norm_method='std',
    num_semantic_heads=2,
    temporal_mode=temporal_mode,
    num_semantic_classes=[1, 1], # inner distance, outer distance
    location=True,  # should always be true
    include_top=True)
# Out:
# conv name is:  conv_mtf_P3
# conv name is:  conv_mtf_P4
# conv name is:  conv_mtf_P5
# conv name is:  conv_mtf_P6
# conv name is:  conv_mtf_P7

# %%
prediction_model.load_weights(model_path, by_name=True)

# %%
# make predictions on testing data
from timeit import default_timer

f_mov = 0
l_mov = 4

start = default_timer()
test_images = prediction_model.predict(X_test[f_mov:l_mov, 0:pred_frames_per_batch, ...])
watershed_time = default_timer() - start

print('Watershed segmentation of shape', test_images[0].shape, 'in', watershed_time, 'seconds.')
# Out:
# Watershed segmentation of shape (4, 5, 256, 256, 1) in 11.73755706474185 seconds.

# %%
import time

from matplotlib import pyplot as plt
import numpy as np

from skimage.feature import peak_local_max
from skimage.morphology import remove_small_objects

from deepcell_toolbox.deep_watershed import deep_watershed_3D

masks = deep_watershed_3D(
    test_images,
    min_distance=10,
    detection_threshold=0.05,
    distance_threshold=0.05,
    exclude_border=False,
    small_objects_threshold=0)

# calculated in the postprocessing above, but useful for visualizing
inner_distance = test_images[0]
outer_distance = test_images[1]

fig, axes = plt.subplots(1, 5, figsize=(20, 20))

index = 2
slice = 4

coords = peak_local_max(
    np.squeeze(inner_distance[index]),
    min_distance=10,
    threshold_abs=0.1,
    exclude_border=False)

# raw image with centroid
axes[0].imshow(X_test[index+f_mov, slice, ..., 0])
axes[0].scatter(coords[..., 2], coords[..., 1],
                color='r', marker='.', s=10)

axes[1].imshow(inner_distance[index, slice, ..., 0], cmap='jet')
axes[2].imshow(outer_distance[index, slice, ..., 0], cmap='jet')
axes[3].imshow(masks[index, slice, ...], cmap='jet')
axes[4].imshow(np.squeeze(y_test[index+f_mov, slice, ...]), cmap='jet')

plt.show()

# %%
from deepcell_toolbox.metrics import Metrics
from skimage.morphology import watershed, remove_small_objects
from skimage.segmentation import clear_border
m = Metrics('DeepWatershed - Remove no pixels', seg=False)

y_true = np.expand_dims(np.squeeze(y_test[index+f_mov, slice, ...]), 0)
y_pred = np.expand_dims(masks[index, slice, ...], 0)

print(y_true.shape)

m.calc_object_stats(y_true, y_pred)
# Out:
# (1, 256, 256)
#
# ____________Object-based statistics____________
#
# Number of true cells:		 16
# Number of predicted cells:	 16
#
# Correct detections:  8	Recall: 50%
# Incorrect detections: 8	Precision: 50%
#
# Gained detections: 6	Perc Error: 42.85714285714285409767398959957063198089599609375%
# Missed detections: 7	Perc Error: 50%
# Merges: 0		Perc Error: 0%
# Splits: 1		Perc Error: 7.14285714285714323779075130005367100238800048828125%
# Catastrophes: 0		Perc Error: 0%
#
# Gained detections from splits: 1
# Missed detections from merges: 0
# True detections involved in catastrophes: 0
# Predicted detections involved in catastrophes: 0
#
# Average Pixel IOU (Jaccard Index): 0.63698463039765795823399230357608757913112640380859375

# %%
print('inner_distance shape = ', inner_distance[index].shape)
print('coords shape = ', coords.shape)
print('coords[..., 2].shape = ', coords[..., 0].shape)
# Out:
# inner_distance shape =  (14, 256, 256, 1)
# coords shape =  (96, 3)
# coords[..., 2].shape =  (96,)

# %%
from deepcell.utils.plot_utils import get_js_video
from IPython.display import HTML

index = 3


# Play movie of the predicted masks
vid_msk = np.expand_dims(masks, axis=1)
vid_msk = np.expand_dims(vid_msk, axis=-1)

HTML(get_js_video(vid_msk[index], batch=0, channel=0, interval=500))
# Out:
# (14, 256, 256)
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img265019e059c64a9d995fa4325f324aa0">
#   <div class="anim-controls">
#     <input id="_anim_slider265019e059c64a9d995fa4325f324aa0" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim265019e059c64a9d995fa4325f324aa0.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anim265019e059c64a9d995fa4325f324aa0.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anim265019e059c64a9d995fa4325f324aa0.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anim265019e059c64a9d995fa4325f324aa0.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anim265019e059c64a9d995fa4325f324aa0.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anim265019e059c64a9d995fa4325f324aa0.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anim265019e059c64a9d995fa4325f324aa0.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anim265019e059c64a9d995fa4325f324aa0.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anim265019e059c64a9d995fa4325f324aa0.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anim265019e059c64a9d995fa4325f324aa0.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_select265019e059c64a9d995fa4325f324aa0" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_265019e059c64a9d995fa4325f324aa0"
#              >
#       <label for="_anim_radio1_265019e059c64a9d995fa4325f324aa0">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_265019e059c64a9d995fa4325f324aa0"
#              checked>
#       <label for="_anim_radio2_265019e059c64a9d995fa4325f324aa0">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_265019e059c64a9d995fa4325f324aa0"
#              >
#       <label for="_anim_radio3_265019e059c64a9d995fa4325f324aa0">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img265019e059c64a9d995fa4325f324aa0";
#     var slider_id = "_anim_slider265019e059c64a9d995fa4325f324aa0";
#     var loop_select_id = "_anim_loop_select265019e059c64a9d995fa4325f324aa0";
#     var frames = new Array(14);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4yLjEsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+j8jraAAAfmklEQVR4nO3dfXRU5aHv8e82AZTyorGGxBkuISu8\
# BEKkEARPraWGqFgNCm2EioSDklvqC/Wl2qW9y81ZCKGtVk/h9Bj1aHwpHI6t5FYBrT1GCy2mAXKP\
# ApYUSU1CiCCgoIgJPvePpCPBhIRkZp69Z36ftbKY2bNffhlZ/Nx7ntmPY4wxiIiI+MwZtgOIiIh0\
# hwpMRER8SQUmIiK+pAITERFfUoGJiIgvqcBERMSXVGAiIuJLKjAREfElFZiIiPiSCkxERHxJBSYi\
# Ir6kAhMREV9SgYmIiC+pwERExJdUYCIi4ksqMBER8SUVmIiI+JIKTEREfEkFJiIivqQCExERX1KB\
# iYiIL6nARETEl1RgIiLiSyowERHxJRWYiIj4kgpMRER8SQUmIiK+pAITERFfUoGJiIgvqcBERMSX\
# VGAetH79ekaMGEFGRgbFxcW244

# %%
vid_gt = np.expand_dims(y_test, axis=1)

HTML(get_js_video(vid_gt[index], batch=0, channel=0, interval=500))
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgf5f136bfbc2b4c66965073fb807a7e3a">
#   <div class="anim-controls">
#     <input id="_anim_sliderf5f136bfbc2b4c66965073fb807a7e3a" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animf5f136bfbc2b4c66965073fb807a7e3a.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="animf5f136bfbc2b4c66965073fb807a7e3a.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="animf5f136bfbc2b4c66965073fb807a7e3a.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="animf5f136bfbc2b4c66965073fb807a7e3a.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="animf5f136bfbc2b4c66965073fb807a7e3a.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="animf5f136bfbc2b4c66965073fb807a7e3a.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="animf5f136bfbc2b4c66965073fb807a7e3a.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="animf5f136bfbc2b4c66965073fb807a7e3a.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="animf5f136bfbc2b4c66965073fb807a7e3a.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="animf5f136bfbc2b4c66965073fb807a7e3a.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_selectf5f136bfbc2b4c66965073fb807a7e3a" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_f5f136bfbc2b4c66965073fb807a7e3a"
#              >
#       <label for="_anim_radio1_f5f136bfbc2b4c66965073fb807a7e3a">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_f5f136bfbc2b4c66965073fb807a7e3a"
#              checked>
#       <label for="_anim_radio2_f5f136bfbc2b4c66965073fb807a7e3a">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_f5f136bfbc2b4c66965073fb807a7e3a"
#              >
#       <label for="_anim_radio3_f5f136bfbc2b4c66965073fb807a7e3a">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgf5f136bfbc2b4c66965073fb807a7e3a";
#     var slider_id = "_anim_sliderf5f136bfbc2b4c66965073fb807a7e3a";
#     var loop_select_id = "_anim_loop_selectf5f136bfbc2b4c66965073fb807a7e3a";
#     var frames = new Array(15);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4yLjEsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+j8jraAAAeT0lEQVR4nO3df3RW9YHn8feF4A/kh6VtQkg4hJwg\
# CYTIAgrdtf4YjFpmDKP0ILUOYbBmS9el/ugPu84ZH3eopO3Yo1OY1qjHxnFXyk5HMl0BbbulLZ7S\
# NNCsimWNSE5DiFF+FVCxgHf/CEZRQn49z3Ofm7xf5+T4PPf53ns/eY6HT+597nO/QRiGIZIkxcyQ\
# qANIktQXFpgkKZYsMElSLFlgkqRYssAkSbFkgUmSYskCkyTFkgUmSYolC0ySFEsWmCQpliwwSVIs\
# WWCSpFiywCRJsWSBSZJiyQKTJMWSBSZJiiULTJIUSxaYJCmWLDBJUixZYJKkWLLAJEmxZIFJkmLJ\
# ApMkxZIFJkmKJQtMkhRLFpgkKZYsMElSLFlgkqRYssAkSbFkgUmSYskCy0AbN25k8uTJFBUVUV1d\
# HXUcScpIQRiGYdQh9L4TJ05wwQ

# %%
vid_data = np.expand_dims(X_test, axis=1)

HTML(get_js_video(vid_data[index], batch=0, channel=0, interval=500))
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img087900df07cb4c8daa1db6e40b77d617">
#   <div class="anim-controls">
#     <input id="_anim_slider087900df07cb4c8daa1db6e40b77d617" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim087900df07cb4c8daa1db6e40b77d617.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anim087900df07cb4c8daa1db6e40b77d617.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anim087900df07cb4c8daa1db6e40b77d617.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anim087900df07cb4c8daa1db6e40b77d617.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anim087900df07cb4c8daa1db6e40b77d617.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anim087900df07cb4c8daa1db6e40b77d617.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anim087900df07cb4c8daa1db6e40b77d617.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anim087900df07cb4c8daa1db6e40b77d617.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anim087900df07cb4c8daa1db6e40b77d617.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anim087900df07cb4c8daa1db6e40b77d617.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_select087900df07cb4c8daa1db6e40b77d617" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_087900df07cb4c8daa1db6e40b77d617"
#              >
#       <label for="_anim_radio1_087900df07cb4c8daa1db6e40b77d617">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_087900df07cb4c8daa1db6e40b77d617"
#              checked>
#       <label for="_anim_radio2_087900df07cb4c8daa1db6e40b77d617">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_087900df07cb4c8daa1db6e40b77d617"
#              >
#       <label for="_anim_radio3_087900df07cb4c8daa1db6e40b77d617">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img087900df07cb4c8daa1db6e40b77d617";
#     var slider_id = "_anim_slider087900df07cb4c8daa1db6e40b77d617";
#     var loop_select_id = "_anim_loop_select087900df07cb4c8daa1db6e40b77d617";
#     var frames = new Array(15);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4yLjEsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+j8jraAAAgAElEQVR4nOy9bZBdV3ku+DQ6HdSN1DSS0Afdjhsi\
# hy8BSrBjzw0hZAwh5eGaISTmIylMORPlkpoKFTI/qPkz4U/izJ1U8gOqLqrigknVhLioCZ6hjPNx\
# C997yb2GcYxyMY5zJS6dUQtJRBaN1JYa+oieH3u/vZ/z9PuutU4bu49O1lN16uyz99prrf1x3me9\
# 7/vstSfW19fXUVFRUVFRcZ3hedvdgYqKioqKiq2gElhFRUVFxXWJSmAVFRUVFdclKoFVVFRUVFyX\
# qARWUVFRUXFdohJYRUVFRcV1iUpgFRUVFRXXJSqBVVRUVFRcl6gEVlFRUVFxXaISWEVFRUXFdYlK\
# YBUVFRUV1yUqgVVUVFRUXJeoBFZRUVFRcV2iElhFRUVFxXWJSmAVFRUVFdclKoFVVFRUVFyXqARW\
# UVFRUXFdohJYRUVFRcV1iUpgFR

# %%
vid_id = np.expand_dims(inner_distance, axis=1)

HTML(get_js_video(vid_id[index], batch=0, channel=0, interval=500))
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgf879fdc973374a6e8cb4186b2db65e8d">
#   <div class="anim-controls">
#     <input id="_anim_sliderf879fdc973374a6e8cb4186b2db65e8d" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animf879fdc973374a6e8cb4186b2db65e8d.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="animf879fdc973374a6e8cb4186b2db65e8d.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="animf879fdc973374a6e8cb4186b2db65e8d.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="animf879fdc973374a6e8cb4186b2db65e8d.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="animf879fdc973374a6e8cb4186b2db65e8d.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="animf879fdc973374a6e8cb4186b2db65e8d.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="animf879fdc973374a6e8cb4186b2db65e8d.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="animf879fdc973374a6e8cb4186b2db65e8d.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="animf879fdc973374a6e8cb4186b2db65e8d.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="animf879fdc973374a6e8cb4186b2db65e8d.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_selectf879fdc973374a6e8cb4186b2db65e8d" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_f879fdc973374a6e8cb4186b2db65e8d"
#              >
#       <label for="_anim_radio1_f879fdc973374a6e8cb4186b2db65e8d">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_f879fdc973374a6e8cb4186b2db65e8d"
#              checked>
#       <label for="_anim_radio2_f879fdc973374a6e8cb4186b2db65e8d">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_f879fdc973374a6e8cb4186b2db65e8d"
#              >
#       <label for="_anim_radio3_f879fdc973374a6e8cb4186b2db65e8d">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgf879fdc973374a6e8cb4186b2db65e8d";
#     var slider_id = "_anim_sliderf879fdc973374a6e8cb4186b2db65e8d";
#     var loop_select_id = "_anim_loop_selectf879fdc973374a6e8cb4186b2db65e8d";
#     var frames = new Array(14);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4yLjEsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+j8jraAAAgAElEQVR4nOzdf3Db9Z3v+6ei37LlKJaxHEsmClFI\
# YpzgJoGkQNtskxTKsmFbeoC2e6GXXXIOd3aW2x9zhpl7mNvOnGnTM7czvXvYua23tNDd7rJM71my\
# 7fCjzWnTU+AkuQZSEvIDO0TBP2IZyciRIkuyFN0/3t+vvk4afiWxJdnvx4yQLX0lvlLk70ufz/fz\
# eX9slUqlglJKKdVgFtV6B5RSSqlLoQGmlFKqIWmAKaWUakgaYEoppRqSBphSSqmGpAGmlFKqIWmA\
# KaWUakgaYEoppRqSBphSSqmGpAGmlFKqIWmAKaWUakgaYEoppRqSBphSSqmGpAGmlFKqIWmAKaWU\
# akgaYEoppRqSBphSSqmGpAGmlFKqIWmAKaWUakgaYEoppRqSBphSSqmGpAGmlFKqIWmAKaWUakga\
# YEoppRqSBphSSqmGpAGmlFKqIW

# %% [markdown]
# ## Evaluate results
#
# The `deepcell.metrics` package is used to measure advanced metrics for instance segmentation predictions.

# %%
#outputs = []

#for mov in range(outputs)

# %%
def stack_frames(input_array):
    output_list = []
    for mov in range(input_array.shape[0]):

# %%
from deepcell_toolbox.metrics import Metrics
from skimage.morphology import watershed, remove_small_objects
from skimage.segmentation import clear_border


outputs = prediction_model.predict(X_test[f_mov:l_mov, 0:pred_frames_per_batch, ...])

y_pred = []

for i in range(outputs[0].shape[0]):

    mask = deep_watershed_3D(
        [t[[i]] for t in outputs],
        min_distance=10,
        detection_threshold=0.1,
        distance_threshold=0.01,
        exclude_border=False,
        small_objects_threshold=0)

    y_pred.append(mask[0])

y_pred = np.stack(y_pred, axis=0)
#y_pred = np.expand_dims(y_pred, axis=-1)
y_true = np.squeeze(y_test[f_mov:l_mov, 0:pred_frames_per_batch, ...].copy())

print('y_pred shape is: ', y_pred.shape)
print('y_true shape is: ', y_true.shape)

#y_pred = np.where(y_true > 0, y_true, y_true)

print('Shape of y_pred is: ', y_pred.shape)
print('Shape of y_true is: ', y_true.shape)

print('DeepWatershed - Remove no pixels')
m = Metrics('DeepWatershed - Remove no pixels', seg=False)

m.calc_object_stats(y_true, y_pred)
print('\n')

for i in range(y_pred.shape[0]):
    y_pred[i] = remove_small_objects(y_pred[i].astype(int), min_size=100)
    y_true[i] = remove_small_objects(y_true[i].astype(int), min_size=100)

print('DeepWatershed - Remove objects < 100 pixels')
m = Metrics('DeepWatershed - Remove 100 pixels', seg=False)

m.calc_object_stats(y_true, y_pred)
print('\n')
# Out:
# y_pred shape is:  (4, 5, 256, 256)
# y_true shape is:  (4, 5, 256, 256)
# Shape of y_pred is:  (4, 5, 256, 256)
# Shape of y_true is:  (4, 5, 256, 256)
# DeepWatershed - Remove no pixels
#
# ____________Object-based statistics____________
#
# Number of true cells:		 45
# Number of predicted cells:	 43
#
# Correct detections:  4	Recall: 8.888888888888889283634853200055658817291259765625%
# Incorrect detections: 39	Precision: 9.3023255813953493742474165628664195537567138671875%
#
# Gained detections: 39	Perc Error: 48.75%
# Missed detections: 41	Perc Error: 51.25%
# Merges: 0		Perc Error: 0%
# Splits: 0		Perc Error: 0%
# Catastrophes: 0		Perc Error: 0%
#
# Gained detections from splits: 0
# Missed detections from merges: 0
# True detections involved in catastrophes: 0
# Predicted detections involved in catastrophes: 0
#
# Average Pixel IOU (Jaccard Index): 0.6661335079754786558936530127539299428462982177734375
#
#
#
# DeepWatershed - Remove objects < 100 pixels
#
# ____________Object-based statistics____________
#
# Number of true cells:		 45
# Number of predicted cells:	 41
#
# Correct detections:  4	Recall: 8.888888888888889283634853200055658817291259765625%
# Incorrect detections: 37	Precision: 9.7560975609756095394686781219206750392913818359375%
#
# Gained detections: 37	Perc Error: 47.43589743589743790153079316951334476470947265625%
# Missed detections: 41	Perc Error: 52.56410256410256209846920683048665523529052734375%
# Merges: 0		Perc Error: 0%
# Splits: 0		Perc Error: 0%
# Catastrophes: 0		Perc Error: 0%
#
# Gained detections from splits: 0
# Missed detections from merges: 0
# True detections involved in catastrophes: 0
# Predicted detections involved in catastrophes: 0
#
# Average Pixel IOU (Jaccard Index): 0.6662454170219309634859428115305490791797637939453125
