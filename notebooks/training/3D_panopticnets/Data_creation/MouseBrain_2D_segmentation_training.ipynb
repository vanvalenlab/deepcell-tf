# %% [markdown]
# This notebook is part of the `deepcell-tf` documentation: https://deepcell.readthedocs.io/.

# %% [markdown]
# # Training a segmentation model
#
# `deepcell-tf` leverages [Jupyter Notebooks](https://jupyter.org) in order to train models. Example notebooks are available for most model architectures in the [notebooks folder](https://github.com/vanvalenlab/deepcell-tf/tree/master/notebooks). Most notebooks are structured similarly to this example and thus this notebook serves as a core reference for the deepcell approach to model training.

# %%
import os
import errno

import numpy as np

import deepcell
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# /usr/local/lib/python3.6/dist-packages/deepcell/utils/__init__.py:49: UserWarning: To use `compute_overlap`, the C extensions must be built using `python setup.py build_ext --inplace`
#   warnings.warn('To use `compute_overlap`, the C extensions must be built '

# %% [markdown]
# ## Load the data
#
# ### Download the data from `deepcell.datasets`
#
# `deepcell.datasets` provides access to a set of annotated live-cell imaging datasets which can be used for training cell segmentation and tracking models.
# All dataset objects share the `load_data()` method, which allows the user to specify the name of the file (`path`), the fraction of data reserved for testing (`test_size`) and a `seed` which is used to generate the random train-test split.
# Metadata associated with the dataset can be accessed through the `metadata` attribute.

# %%
# Download the data (saves to ~/.keras/datasets)
filename = 'mousebrain.npz'
test_size = 0.1 # % of data saved as test
seed = 0 # seed for random train-test split

(X_train, y_train), (X_test, y_test) = deepcell.datasets.mousebrain.load_data(
    filename, test_size=test_size, seed=seed)

# %%
def stack(arr):
    ims = []
    for frame in range(0, 15):
        ims.append(arr[:, frame, ...])
        
    return np.concatenate(ims, 0)

# %%
X_train = stack(X_train)
y_train = stack(y_train)
X_test = stack(X_test)
y_test = stack(y_test)

# %%
print(y_train.shape)
# Out:
# (2970, 256, 256, 1)

# %%
X_train.dtype
# Out:
# dtype('float32')

# %%
print(X_train.shape[1:])
# Out:
# (256, 256, 1)

# %% [markdown]
# The `PanopticNet` models require square inputs. Reshape the data to meet the model requirements.

# %%
#from deepcell.utils.data_utils import reshape_matrix

#size = 128

#X_train, y_train = reshape_matrix(X_train, y_train, reshape_size=size)
#X_test, y_test = reshape_matrix(X_test, y_test, reshape_size=size)
#print('X.shape: {}\ny.shape: {}'.format(X_train.shape, y_train.shape))

# %% [markdown]
# ## Set up filepath constants

# %%
# change DATA_DIR if you are not using `deepcell.datasets`
DATA_DIR = os.path.expanduser(os.path.join('~', '.keras', 'datasets'))

# DATA_FILE should be a npz file, preferably from `make_training_data`
DATA_FILE = os.path.join(DATA_DIR, filename)

# confirm the data file is available
assert os.path.isfile(DATA_FILE)

# %%
# Set up other required filepaths

# If the data file is in a subdirectory, mirror it in MODEL_DIR and LOG_DIR
PREFIX = os.path.relpath(os.path.dirname(DATA_FILE), DATA_DIR)

ROOT_DIR = '/data'  # TODO: Change this! Usually a mounted volume
MODEL_DIR = os.path.abspath(os.path.join(ROOT_DIR, 'models', PREFIX))
LOG_DIR = os.path.abspath(os.path.join(ROOT_DIR, 'logs', PREFIX))

# create directories if they do not exist
for d in (MODEL_DIR, LOG_DIR):
    try:
        os.makedirs(d)
    except OSError as exc:  # Guard against race condition
        if exc.errno != errno.EEXIST:
            raise

# %% [markdown]
# ## Create the PanopticNet Model
#
# Here we instantiate a `PanopticNet` model from `deepcell.model_zoo` using 3 semantic heads:
# inner distance (1 class),
# outer distance (1 class),
# foreground/background distance (2 classes)

# %%
from deepcell.model_zoo.panopticnet import PanopticNet

model = PanopticNet(
    backbone='resnet50',
    input_shape=X_train.shape[1:],
    norm_method='std',
    num_semantic_heads=3,
    num_semantic_classes=[1, 1, 2], # inner distance, outer distance, fgbg
    location=True,  # should always be true
    include_top=True)

# %% [markdown]
# ## Prepare for training
#
# ### Set up training parameters.
#
# There are a number of tunable hyper parameters necessary for training deep learning models:
#
# **model_name**: Incorporated into any files generated during the training process.
#
# **backbone**: The majority of DeepCell models support a variety backbone choices specified in the "backbone" parameter. Backbones are provided through [keras_applications](https://github.com/keras-team/keras-applications) and can be instantiated with weights that are pretrained on ImageNet.
#
# **n_epoch**: The number of complete passes through the training dataset.
#
# **lr**: The learning rate determines the speed at which the model learns. Specifically it controls the relative size of the updates to model values after each batch.
#
# **optimizer**: The TensorFlow module [tf.keras.optimizers](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers) offers optimizers with a variety of algorithm implementations. DeepCell typically uses the Adam or the SGD optimizers.
#
# **lr_sched**: A learning rate scheduler allows the learning rate to adapt over the course of model training. Typically a larger learning rate is preferred during the start of the training process, while a small learning rate allows for fine-tuning during the end of training.
#
# **batch_size**: The batch size determines the number of samples that are processed before the model is updated. The value must be greater than one and less than or equal to the number of samples in the training dataset.

# %%
from tensorflow.keras.optimizers import SGD, Adam
from deepcell.utils.train_utils import rate_scheduler

model_name = 'mb2D_1x256x256_reflect'

n_epoch = 100  # Number of training epochs
test_size = .20  # % of data saved as test
norm_method = 'whole_image'  # data normalization

fill_mode = 'reflect'
cval = 0

optimizer = Adam(lr=1e-5, clipnorm=0.001)
lr_sched = rate_scheduler(lr=1e-5, decay=0.99)

batch_size = 10

min_objects = 2  # throw out images with fewer than this many objects

# %% [markdown]
# ### Create the DataGenerators
#
# The `SemanticDataGenerator` can output any number of transformations for each image. These transformations are passed to `generator.flow()` as a list of transform names.
#
# Here we use `"inner-distance"`, `"outer-distance"` and `"fgbg"` to correspond to the inner distance, outer distance, and foreground background semantic heads, respectively. Keyword arguments may also be passed to each transform as a `dict` of transform names to `kwargs`.

# %%
from deepcell import image_generators
from deepcell.utils import train_utils

transforms = ['inner-distance', 'outer-distance', 'fgbg']
transforms_kwargs = {'outer-distance': {'erosion_width': 0}}


# use augmentation for training but not validation
datagen = image_generators.SemanticDataGenerator(
    rotation_range=180,
    shear_range=0,
    zoom_range=(0.75, 1.25),
    fill_mode=fill_mode,
    horizontal_flip=True,
    vertical_flip=True)

datagen_val = image_generators.SemanticDataGenerator(
    rotation_range=0,
    shear_range=0,
    zoom_range=0,
    fill_mode=fill_mode,
    horizontal_flip=0,
    vertical_flip=0)
    
train_data = datagen.flow(
    {'X': X_train, 'y': y_train},
    seed=seed,
    transforms=transforms,
    transforms_kwargs=transforms_kwargs,
    min_objects=min_objects,
    batch_size=batch_size)

val_data = datagen_val.flow(
    {'X': X_test, 'y': y_test},
    seed=seed,
    transforms=transforms,
    transforms_kwargs=transforms_kwargs,
    min_objects=min_objects,
    batch_size=batch_size)
# Out:
# WARNING:tensorflow:Removing 57 of 2970 images with fewer than 2 objects.
# WARNING:tensorflow:Removing 2 of 330 images with fewer than 2 objects.

# %% [markdown]
# Visualize the data generator output.

# %%
from matplotlib import pyplot as plt

inputs, outputs = train_data.next()

img = inputs[0]
inner_distance = outputs[0]
outer_distance = outputs[1]
fgbg = outputs[2]

fig, axes = plt.subplots(1, 4, figsize=(15, 15))

axes[0].imshow(img[..., 0])
axes[0].set_title('Source Image')

axes[1].imshow(inner_distance[0, ..., 0])
axes[1].set_title('Inner Distance')

axes[2].imshow(outer_distance[0, ..., 0])
axes[2].set_title('Outer Distance')

axes[3].imshow(fgbg[0, ..., 0])
axes[3].set_title('Foreground/Background')

plt.show()

# %%
inputs[0].shape
# Out:
# (256, 256, 1)

# %% [markdown]
# ### Create a loss function for each semantic head
#
# Each semantic head is trained with it's own loss function. Mean Square Error is used for regression-based heads, whereas `weighted_categorical_crossentropy` is used for classification heads.
#
# The losses are saved as a dictionary and passed to `model.compile`.

# %%
# Create a dictionary of losses for each semantic head
from tensorflow.python.keras.losses import MSE
from deepcell import losses


def semantic_loss(n_classes):
    def _semantic_loss(y_pred, y_true):
        if n_classes > 1:
            return 0.01 * losses.weighted_categorical_crossentropy(
                y_pred, y_true, n_classes=n_classes)
        return MSE(y_pred, y_true)
    return _semantic_loss


loss = {}

# Give losses for all of the semantic heads
for layer in model.layers:
    if layer.name.startswith('semantic_'):
        n_classes = layer.output_shape[-1]
        loss[layer.name] = semantic_loss(n_classes)

# %%
model.compile(loss=loss, optimizer=optimizer)

# %% [markdown]
# ## Train the model
#
# Call `fit_generator` on the compiled model, along with a default set of callbacks.

# %%
from deepcell.utils.train_utils import get_callbacks
from deepcell.utils.train_utils import count_gpus


model_path = os.path.join(MODEL_DIR, '{}.h5'.format(model_name))
loss_path = os.path.join(MODEL_DIR, '{}.npz'.format(model_name))

num_gpus = count_gpus()

print('Training on', num_gpus, 'GPUs.')

train_callbacks = get_callbacks(
    model_path,
    lr_sched=lr_sched,
    tensorboard_log_dir=LOG_DIR,
    save_weights_only=num_gpus >= 2,
    monitor='val_loss',
    verbose=1)

loss_history = model.fit_generator(
    train_data,
    steps_per_epoch=train_data.y.shape[0] // batch_size,
    epochs=n_epoch,
    validation_data=val_data,
    validation_steps=val_data.y.shape[0] // batch_size,
    callbacks=train_callbacks)
# Out:
# Training on 1 GPUs.
# Epoch 1/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0099 - semantic_0_loss: 0.0019 - semantic_1_loss: 0.0060 - semantic_2_loss: 0.0019Epoch 1/100
#  32/291 [==>...........................] - ETA: 1:13 - loss: 0.0099 - semantic_0_loss: 0.0019 - semantic_1_loss: 0.0059 - semantic_2_loss: 0.0021
# Epoch 00001: val_loss improved from inf to 0.00992, saving model to /data/models/mb2D_1x256x256_reflect.h5
# 291/291 [==============================] - 153s 524ms/step - loss: 0.0099 - semantic_0_loss: 0.0019 - semantic_1_loss: 0.0060 - semantic_2_loss: 0.0019 - val_loss: 0.0099 - val_semantic_0_loss: 0.0019 - val_semantic_1_loss: 0.0059 - val_semantic_2_loss: 0.0021
# Epoch 2/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0096 - semantic_0_loss: 0.0019 - semantic_1_loss: 0.0059 - semantic_2_loss: 0.0019Epoch 1/100
#  32/291 [==>...........................] - ETA: 52s - loss: 0.0091 - semantic_0_loss: 0.0018 - semantic_1_loss: 0.0057 - semantic_2_loss: 0.0016
# Epoch 00003: val_loss improved from 0.00992 to 0.00911, saving model to /data/models/mb2D_1x256x256_reflect.h5
# 291/291 [==============================] - 133s 459ms/step - loss: 0.0096 - semantic_0_loss: 0.0019 - semantic_1_loss: 0.0059 - semantic_2_loss: 0.0019 - val_loss: 0.0091 - val_semantic_0_loss: 0.0018 - val_semantic_1_loss: 0.0057 - val_semantic_2_loss: 0.0016
# Epoch 4/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0094 - semantic_0_loss: 0.0018 - semantic_1_loss: 0.0058 - semantic_2_loss: 0.0018Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0092 - semantic_0_loss: 0.0018 - semantic_1_loss: 0.0059 - semantic_2_loss: 0.0015
# Epoch 00004: val_loss did not improve from 0.00911
# 291/291 [==============================] - 132s 453ms/step - loss: 0.0094 - semantic_0_loss: 0.0018 - semantic_1_loss: 0.0058 - semantic_2_loss: 0.0018 - val_loss: 0.0092 - val_semantic_0_loss: 0.0018 - val_semantic_1_loss: 0.0059 - val_semantic_2_loss: 0.0015
# Epoch 5/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0093 - semantic_0_loss: 0.0018 - semantic_1_loss: 0.0057 - semantic_2_loss: 0.0018Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0092 - semantic_0_loss: 0.0018 - semantic_1_loss: 0.0058 - semantic_2_loss: 0.0016
# Epoch 00005: val_loss did not improve from 0.00911
# 291/291 [==============================] - 132s 453ms/step - loss: 0.0093 - semantic_0_loss: 0.0018 - semantic_1_loss: 0.0057 - semantic_2_loss: 0.0018 - val_loss: 0.0092 - val_semantic_0_loss: 0.0018 - val_semantic_1_loss: 0.0058 - val_semantic_2_loss: 0.0016
# Epoch 6/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0092 - semantic_0_loss: 0.0018 - semantic_1_loss: 0.0056 - semantic_2_loss: 0.0018Epoch 1/100
#  32/291 [==>...........................] - ETA: 52s - loss: 0.0090 - semantic_0_loss: 0.0018 - semantic_1_loss: 0.0057 - semantic_2_loss: 0.0015
# Epoch 00006: val_loss improved from 0.00911 to 0.00896, saving model to /data/models/mb2D_1x256x256_reflect.h5
# 291/291 [==============================] - 139s 477ms/step - loss: 0.0092 - semantic_0_loss: 0.0018 - semantic_1_loss: 0.0056 - semantic_2_loss: 0.0018 - val_loss: 0.0090 - val_semantic_0_loss: 0.0018 - val_semantic_1_loss: 0.0057 - val_semantic_2_loss: 0.0015
# Epoch 7/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0092 - semantic_0_loss: 0.0018 - semantic_1_loss: 0.0057 - semantic_2_loss: 0.0018Epoch 1/100
#  32/291 [==>...........................] - ETA: 54s - loss: 0.0090 - semantic_0_loss: 0.0018 - semantic_1_loss: 0.0057 - semantic_2_loss: 0.0015
# Epoch 00007: val_loss did not improve from 0.00896
# 291/291 [==============================] - 132s 454ms/step - loss: 0.0092 - semantic_0_loss: 0.0018 - semantic_1_loss: 0.0057 - semantic_2_loss: 0.0018 - val_loss: 0.0090 - val_semantic_0_loss: 0.0018 - val_semantic_1_loss: 0.0057 - val_semantic_2_loss: 0.0015
# Epoch 8/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0092 - semantic_0_loss: 0.0018 - semantic_1_loss: 0.0057 - semantic_2_loss: 0.0018Epoch 1/100
#  32/291 [==>...........................] - ETA: 52s - loss: 0.0088 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0056 - semantic_2_loss: 0.0015
# Epoch 00008: val_loss improved from 0.00896 to 0.00883, saving model to /data/models/mb2D_1x256x256_reflect.h5
# 291/291 [==============================] - 133s 459ms/step - loss: 0.0092 - semantic_0_loss: 0.0018 - semantic_1_loss: 0.0057 - semantic_2_loss: 0.0018 - val_loss: 0.0088 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0056 - val_semantic_2_loss: 0.0015
# Epoch 9/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0091 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0056 - semantic_2_loss: 0.0017Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0088 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0056 - semantic_2_loss: 0.0015
# Epoch 00009: val_loss improved from 0.00883 to 0.00882, saving model to /data/models/mb2D_1x256x256_reflect.h5
# 291/291 [==============================] - 134s 459ms/step - loss: 0.0091 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0056 - semantic_2_loss: 0.0017 - val_loss: 0.0088 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0056 - val_semantic_2_loss: 0.0015
# Epoch 10/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0091 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0056 - semantic_2_loss: 0.0018Epoch 1/100
#  32/291 [==>...........................] - ETA: 52s - loss: 0.0089 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0056 - semantic_2_loss: 0.0015
# Epoch 00010: val_loss did not improve from 0.00882
# 291/291 [==============================] - 132s 453ms/step - loss: 0.0091 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0056 - semantic_2_loss: 0.0018 - val_loss: 0.0089 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0056 - val_semantic_2_loss: 0.0015
# Epoch 11/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0090 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0056 - semantic_2_loss: 0.0018Epoch 1/100
#  32/291 [==>...........................] - ETA: 52s - loss: 0.0089 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0056 - semantic_2_loss: 0.0015
# Epoch 00011: val_loss did not improve from 0.00882
# 291/291 [==============================] - 132s 453ms/step - loss: 0.0090 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0056 - semantic_2_loss: 0.0018 - val_loss: 0.0089 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0056 - val_semantic_2_loss: 0.0015
# Epoch 12/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0088 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0054 - semantic_2_loss: 0.0017Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0088 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0055 - semantic_2_loss: 0.0015
# Epoch 00012: val_loss improved from 0.00882 to 0.00877, saving model to /data/models/mb2D_1x256x256_reflect.h5
# 291/291 [==============================] - 134s 459ms/step - loss: 0.0088 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0054 - semantic_2_loss: 0.0017 - val_loss: 0.0088 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0055 - val_semantic_2_loss: 0.0015
# Epoch 13/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0090 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0056 - semantic_2_loss: 0.0017Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0089 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0056 - semantic_2_loss: 0.0015
# Epoch 00013: val_loss did not improve from 0.00877
# 291/291 [==============================] - 132s 454ms/step - loss: 0.0090 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0056 - semantic_2_loss: 0.0017 - val_loss: 0.0089 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0056 - val_semantic_2_loss: 0.0015
# Epoch 14/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0088 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0054 - semantic_2_loss: 0.0017Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0087 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0055 - semantic_2_loss: 0.0015
# Epoch 00014: val_loss improved from 0.00877 to 0.00867, saving model to /data/models/mb2D_1x256x256_reflect.h5
# 291/291 [==============================] - 133s 458ms/step - loss: 0.0088 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0054 - semantic_2_loss: 0.0017 - val_loss: 0.0087 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0055 - val_semantic_2_loss: 0.0015
# Epoch 15/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0088 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0054 - semantic_2_loss: 0.0017Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0088 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0056 - semantic_2_loss: 0.0015
# Epoch 00015: val_loss did not improve from 0.00867
# 291/291 [==============================] - 132s 454ms/step - loss: 0.0088 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0054 - semantic_2_loss: 0.0017 - val_loss: 0.0088 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0056 - val_semantic_2_loss: 0.0015
# Epoch 16/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0089 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0055 - semantic_2_loss: 0.0017Epoch 1/100
#  32/291 [==>...........................] - ETA: 52s - loss: 0.0087 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0055 - semantic_2_loss: 0.0015
# Epoch 00016: val_loss improved from 0.00867 to 0.00867, saving model to /data/models/mb2D_1x256x256_reflect.h5
# 291/291 [==============================] - 133s 458ms/step - loss: 0.0089 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0055 - semantic_2_loss: 0.0017 - val_loss: 0.0087 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0055 - val_semantic_2_loss: 0.0015
# Epoch 17/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0087 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0054 - semantic_2_loss: 0.0017Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0087 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0055 - semantic_2_loss: 0.0015
# Epoch 00017: val_loss did not improve from 0.00867
# 291/291 [==============================] - 132s 453ms/step - loss: 0.0087 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0054 - semantic_2_loss: 0.0017 - val_loss: 0.0087 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0055 - val_semantic_2_loss: 0.0015
# Epoch 18/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0088 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0054 - semantic_2_loss: 0.0017Epoch 1/100
#  32/291 [==>...........................] - ETA: 52s - loss: 0.0087 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0055 - semantic_2_loss: 0.0015
# Epoch 00018: val_loss did not improve from 0.00867
# 291/291 [==============================] - 132s 453ms/step - loss: 0.0088 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0054 - semantic_2_loss: 0.0017 - val_loss: 0.0087 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0055 - val_semantic_2_loss: 0.0015
# Epoch 19/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0087 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0053 - semantic_2_loss: 0.0017Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0086 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0054 - semantic_2_loss: 0.0015
# Epoch 00019: val_loss improved from 0.00867 to 0.00860, saving model to /data/models/mb2D_1x256x256_reflect.h5
# 291/291 [==============================] - 133s 459ms/step - loss: 0.0087 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0053 - semantic_2_loss: 0.0017 - val_loss: 0.0086 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0054 - val_semantic_2_loss: 0.0015
# Epoch 20/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0087 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0053 - semantic_2_loss: 0.0017Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0087 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0055 - semantic_2_loss: 0.0015
# Epoch 00020: val_loss did not improve from 0.00860
# 291/291 [==============================] - 132s 454ms/step - loss: 0.0087 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0053 - semantic_2_loss: 0.0017 - val_loss: 0.0087 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0055 - val_semantic_2_loss: 0.0015
# Epoch 21/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0087 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0054 - semantic_2_loss: 0.0017Epoch 1/100
#  32/291 [==>...........................] - ETA: 52s - loss: 0.0087 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0055 - semantic_2_loss: 0.0015
# Epoch 00021: val_loss did not improve from 0.00860
# 291/291 [==============================] - 132s 453ms/step - loss: 0.0087 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0054 - semantic_2_loss: 0.0017 - val_loss: 0.0087 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0055 - val_semantic_2_loss: 0.0015
# Epoch 22/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0086 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0053 - semantic_2_loss: 0.0017Epoch 1/100
#  32/291 [==>...........................] - ETA: 52s - loss: 0.0086 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0055 - semantic_2_loss: 0.0015
# Epoch 00022: val_loss did not improve from 0.00860
# 291/291 [==============================] - 132s 453ms/step - loss: 0.0086 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0053 - semantic_2_loss: 0.0017 - val_loss: 0.0086 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0055 - val_semantic_2_loss: 0.0015
# Epoch 23/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0086 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0053 - semantic_2_loss: 0.0017Epoch 1/100
#  32/291 [==>...........................] - ETA: 52s - loss: 0.0086 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0054 - semantic_2_loss: 0.0015
# Epoch 00023: val_loss improved from 0.00860 to 0.00857, saving model to /data/models/mb2D_1x256x256_reflect.h5
# 291/291 [==============================] - 134s 459ms/step - loss: 0.0086 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0053 - semantic_2_loss: 0.0017 - val_loss: 0.0086 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0054 - val_semantic_2_loss: 0.0015
# Epoch 24/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0086 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0053 - semantic_2_loss: 0.0017Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0087 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0055 - semantic_2_loss: 0.0015
# Epoch 00024: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 454ms/step - loss: 0.0086 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0053 - semantic_2_loss: 0.0017 - val_loss: 0.0087 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0055 - val_semantic_2_loss: 0.0015
# Epoch 25/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0085 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0052 - semantic_2_loss: 0.0016Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0089 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0056 - semantic_2_loss: 0.0015
# Epoch 00025: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 454ms/step - loss: 0.0085 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0052 - semantic_2_loss: 0.0016 - val_loss: 0.0089 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0056 - val_semantic_2_loss: 0.0015
# Epoch 26/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0086 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0053 - semantic_2_loss: 0.0016Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0086 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0054 - semantic_2_loss: 0.0015
# Epoch 00026: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 455ms/step - loss: 0.0086 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0053 - semantic_2_loss: 0.0016 - val_loss: 0.0086 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0054 - val_semantic_2_loss: 0.0015
# Epoch 27/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0084 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0052 - semantic_2_loss: 0.0016Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0087 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0056 - semantic_2_loss: 0.0015
# Epoch 00027: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 452ms/step - loss: 0.0084 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0052 - semantic_2_loss: 0.0016 - val_loss: 0.0087 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0056 - val_semantic_2_loss: 0.0015
# Epoch 28/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0083 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0051 - semantic_2_loss: 0.0016Epoch 1/100
#  32/291 [==>...........................] - ETA: 52s - loss: 0.0087 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0055 - semantic_2_loss: 0.0015
# Epoch 00028: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 453ms/step - loss: 0.0083 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0051 - semantic_2_loss: 0.0016 - val_loss: 0.0087 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0055 - val_semantic_2_loss: 0.0015
# Epoch 29/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0084 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0052 - semantic_2_loss: 0.0016Epoch 1/100
#  32/291 [==>...........................] - ETA: 52s - loss: 0.0087 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0055 - semantic_2_loss: 0.0015
# Epoch 00029: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 453ms/step - loss: 0.0084 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0052 - semantic_2_loss: 0.0016 - val_loss: 0.0087 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0055 - val_semantic_2_loss: 0.0015
# Epoch 30/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0085 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0052 - semantic_2_loss: 0.0017Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0087 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0055 - semantic_2_loss: 0.0015
# Epoch 00030: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 453ms/step - loss: 0.0084 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0052 - semantic_2_loss: 0.0016 - val_loss: 0.0087 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0055 - val_semantic_2_loss: 0.0015
# Epoch 31/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0085 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0052 - semantic_2_loss: 0.0016Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0087 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0055 - semantic_2_loss: 0.0015
# Epoch 00031: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 453ms/step - loss: 0.0084 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0052 - semantic_2_loss: 0.0016 - val_loss: 0.0087 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0055 - val_semantic_2_loss: 0.0015
# Epoch 32/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0082 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0050 - semantic_2_loss: 0.0016Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0086 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0055 - semantic_2_loss: 0.0015
# Epoch 00032: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 453ms/step - loss: 0.0082 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0050 - semantic_2_loss: 0.0016 - val_loss: 0.0086 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0055 - val_semantic_2_loss: 0.0015
# Epoch 33/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0083 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0051 - semantic_2_loss: 0.0016Epoch 1/100
#  32/291 [==>...........................] - ETA: 52s - loss: 0.0088 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0056 - semantic_2_loss: 0.0015
# Epoch 00033: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 453ms/step - loss: 0.0083 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0051 - semantic_2_loss: 0.0016 - val_loss: 0.0088 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0056 - val_semantic_2_loss: 0.0015
# Epoch 34/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0084 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0051 - semantic_2_loss: 0.0016Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0088 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0056 - semantic_2_loss: 0.0015
# Epoch 00034: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 453ms/step - loss: 0.0084 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0051 - semantic_2_loss: 0.0016 - val_loss: 0.0088 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0056 - val_semantic_2_loss: 0.0015
# Epoch 35/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0082 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0050 - semantic_2_loss: 0.0016Epoch 1/100
#  32/291 [==>...........................] - ETA: 52s - loss: 0.0088 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0056 - semantic_2_loss: 0.0015
# Epoch 00035: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 453ms/step - loss: 0.0082 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0050 - semantic_2_loss: 0.0016 - val_loss: 0.0088 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0056 - val_semantic_2_loss: 0.0015
# Epoch 36/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0082 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0051 - semantic_2_loss: 0.0016Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0087 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0056 - semantic_2_loss: 0.0015
# Epoch 00036: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 453ms/step - loss: 0.0082 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0051 - semantic_2_loss: 0.0016 - val_loss: 0.0087 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0056 - val_semantic_2_loss: 0.0015
# Epoch 37/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0083 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0051 - semantic_2_loss: 0.0016Epoch 1/100
#  32/291 [==>...........................] - ETA: 52s - loss: 0.0087 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0056 - semantic_2_loss: 0.0015
# Epoch 00037: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 454ms/step - loss: 0.0083 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0051 - semantic_2_loss: 0.0016 - val_loss: 0.0087 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0056 - val_semantic_2_loss: 0.0015
# Epoch 38/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0082 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0050 - semantic_2_loss: 0.0016Epoch 1/100
#  32/291 [==>...........................] - ETA: 52s - loss: 0.0088 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0056 - semantic_2_loss: 0.0015
# Epoch 00038: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 453ms/step - loss: 0.0082 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0050 - semantic_2_loss: 0.0016 - val_loss: 0.0088 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0056 - val_semantic_2_loss: 0.0015
# Epoch 39/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0083 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0051 - semantic_2_loss: 0.0016Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0087 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0055 - semantic_2_loss: 0.0015
# Epoch 00039: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 453ms/step - loss: 0.0083 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0051 - semantic_2_loss: 0.0016 - val_loss: 0.0087 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0055 - val_semantic_2_loss: 0.0015
# Epoch 40/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0081 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0049 - semantic_2_loss: 0.0015Epoch 1/100
#  32/291 [==>...........................] - ETA: 52s - loss: 0.0088 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0056 - semantic_2_loss: 0.0015
# Epoch 00040: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 454ms/step - loss: 0.0081 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0049 - semantic_2_loss: 0.0015 - val_loss: 0.0088 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0056 - val_semantic_2_loss: 0.0015
# Epoch 41/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0083 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0051 - semantic_2_loss: 0.0016Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0089 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0056 - semantic_2_loss: 0.0015
# Epoch 00041: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 453ms/step - loss: 0.0083 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0051 - semantic_2_loss: 0.0016 - val_loss: 0.0089 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0056 - val_semantic_2_loss: 0.0015
# Epoch 42/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0081 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0050 - semantic_2_loss: 0.0016Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0090 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0057 - semantic_2_loss: 0.0016
# Epoch 00042: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 453ms/step - loss: 0.0081 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0050 - semantic_2_loss: 0.0016 - val_loss: 0.0090 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0057 - val_semantic_2_loss: 0.0016
# Epoch 43/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0082 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0050 - semantic_2_loss: 0.0016Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0089 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0057 - semantic_2_loss: 0.0015
# Epoch 00043: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 453ms/step - loss: 0.0082 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0050 - semantic_2_loss: 0.0016 - val_loss: 0.0089 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0057 - val_semantic_2_loss: 0.0015
# Epoch 44/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0082 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0050 - semantic_2_loss: 0.0016Epoch 1/100
#  32/291 [==>...........................] - ETA: 52s - loss: 0.0087 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0055 - semantic_2_loss: 0.0015
# Epoch 00044: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 454ms/step - loss: 0.0082 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0050 - semantic_2_loss: 0.0016 - val_loss: 0.0087 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0055 - val_semantic_2_loss: 0.0015
# Epoch 45/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0081 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0050 - semantic_2_loss: 0.0016Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0088 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0056 - semantic_2_loss: 0.0015
# Epoch 00045: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 453ms/step - loss: 0.0081 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0050 - semantic_2_loss: 0.0016 - val_loss: 0.0088 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0056 - val_semantic_2_loss: 0.0015
# Epoch 46/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0080 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0049 - semantic_2_loss: 0.0015Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0088 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0056 - semantic_2_loss: 0.0015
# Epoch 00046: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 454ms/step - loss: 0.0080 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0049 - semantic_2_loss: 0.0015 - val_loss: 0.0088 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0056 - val_semantic_2_loss: 0.0015
# Epoch 47/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0081 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0049 - semantic_2_loss: 0.0016Epoch 1/100
#  32/291 [==>...........................] - ETA: 52s - loss: 0.0088 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0056 - semantic_2_loss: 0.0015
# Epoch 00047: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 453ms/step - loss: 0.0081 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0049 - semantic_2_loss: 0.0016 - val_loss: 0.0088 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0056 - val_semantic_2_loss: 0.0015
# Epoch 48/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0080 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0049 - semantic_2_loss: 0.0015Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0089 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0056 - semantic_2_loss: 0.0016
# Epoch 00048: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 453ms/step - loss: 0.0080 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0049 - semantic_2_loss: 0.0015 - val_loss: 0.0089 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0056 - val_semantic_2_loss: 0.0016
# Epoch 49/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0081 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0049 - semantic_2_loss: 0.0015Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0088 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0056 - semantic_2_loss: 0.0015
# Epoch 00049: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 454ms/step - loss: 0.0081 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0049 - semantic_2_loss: 0.0015 - val_loss: 0.0088 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0056 - val_semantic_2_loss: 0.0015
# Epoch 50/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0080 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0049 - semantic_2_loss: 0.0015Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0090 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0057 - semantic_2_loss: 0.0016
# Epoch 00050: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 452ms/step - loss: 0.0080 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0049 - semantic_2_loss: 0.0015 - val_loss: 0.0090 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0057 - val_semantic_2_loss: 0.0016
# Epoch 51/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0079 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0048 - semantic_2_loss: 0.0015Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0089 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0057 - semantic_2_loss: 0.0016
# Epoch 00051: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 453ms/step - loss: 0.0079 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0048 - semantic_2_loss: 0.0015 - val_loss: 0.0089 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0057 - val_semantic_2_loss: 0.0016
# Epoch 52/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0081 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0049 - semantic_2_loss: 0.0016Epoch 1/100
#  32/291 [==>...........................] - ETA: 52s - loss: 0.0089 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0056 - semantic_2_loss: 0.0016
# Epoch 00052: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 454ms/step - loss: 0.0081 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0049 - semantic_2_loss: 0.0016 - val_loss: 0.0089 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0056 - val_semantic_2_loss: 0.0016
# Epoch 53/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0079 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0048 - semantic_2_loss: 0.0015Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0089 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0056 - semantic_2_loss: 0.0015
# Epoch 00053: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 453ms/step - loss: 0.0079 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0048 - semantic_2_loss: 0.0015 - val_loss: 0.0089 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0056 - val_semantic_2_loss: 0.0015
# Epoch 54/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0079 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0048 - semantic_2_loss: 0.0015Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0088 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0056 - semantic_2_loss: 0.0015
# Epoch 00054: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 453ms/step - loss: 0.0079 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0048 - semantic_2_loss: 0.0015 - val_loss: 0.0088 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0056 - val_semantic_2_loss: 0.0015
# Epoch 55/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0079 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0049 - semantic_2_loss: 0.0015Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0089 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0056 - semantic_2_loss: 0.0016
# Epoch 00055: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 453ms/step - loss: 0.0079 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0049 - semantic_2_loss: 0.0015 - val_loss: 0.0089 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0056 - val_semantic_2_loss: 0.0016
# Epoch 56/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0080 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0049 - semantic_2_loss: 0.0015Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0088 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0056 - semantic_2_loss: 0.0015
# Epoch 00056: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 455ms/step - loss: 0.0080 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0049 - semantic_2_loss: 0.0015 - val_loss: 0.0088 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0056 - val_semantic_2_loss: 0.0015
# Epoch 57/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0079 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0049 - semantic_2_loss: 0.0015Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0089 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0056 - semantic_2_loss: 0.0015
# Epoch 00057: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 453ms/step - loss: 0.0079 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0049 - semantic_2_loss: 0.0015 - val_loss: 0.0089 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0056 - val_semantic_2_loss: 0.0015
# Epoch 58/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0079 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0048 - semantic_2_loss: 0.0015Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0089 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0056 - semantic_2_loss: 0.0016
# Epoch 00058: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 453ms/step - loss: 0.0079 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0048 - semantic_2_loss: 0.0015 - val_loss: 0.0089 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0056 - val_semantic_2_loss: 0.0016
# Epoch 59/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0078 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0047 - semantic_2_loss: 0.0015Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0089 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0056 - semantic_2_loss: 0.0016
# Epoch 00059: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 453ms/step - loss: 0.0078 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0048 - semantic_2_loss: 0.0015 - val_loss: 0.0089 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0056 - val_semantic_2_loss: 0.0016
# Epoch 60/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0079 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0048 - semantic_2_loss: 0.0015Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0089 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0057 - semantic_2_loss: 0.0015
# Epoch 00060: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 454ms/step - loss: 0.0079 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0048 - semantic_2_loss: 0.0015 - val_loss: 0.0089 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0057 - val_semantic_2_loss: 0.0015
# Epoch 61/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0080 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0049 - semantic_2_loss: 0.0015Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0089 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0056 - semantic_2_loss: 0.0016
# Epoch 00061: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 452ms/step - loss: 0.0080 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0049 - semantic_2_loss: 0.0015 - val_loss: 0.0089 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0056 - val_semantic_2_loss: 0.0016
# Epoch 62/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0078 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0048 - semantic_2_loss: 0.0015Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0089 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0057 - semantic_2_loss: 0.0016
# Epoch 00062: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 453ms/step - loss: 0.0078 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0048 - semantic_2_loss: 0.0015 - val_loss: 0.0089 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0057 - val_semantic_2_loss: 0.0016
# Epoch 63/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0077 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0047 - semantic_2_loss: 0.0015Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0091 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0058 - semantic_2_loss: 0.0016
# Epoch 00063: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 454ms/step - loss: 0.0077 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0047 - semantic_2_loss: 0.0015 - val_loss: 0.0091 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0058 - val_semantic_2_loss: 0.0016
# Epoch 64/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0079 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0048 - semantic_2_loss: 0.0015Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0089 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0057 - semantic_2_loss: 0.0016
# Epoch 00064: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 453ms/step - loss: 0.0079 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0048 - semantic_2_loss: 0.0015 - val_loss: 0.0089 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0057 - val_semantic_2_loss: 0.0016
# Epoch 65/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0079 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0048 - semantic_2_loss: 0.0015Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0090 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0057 - semantic_2_loss: 0.0016
# Epoch 00065: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 453ms/step - loss: 0.0079 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0048 - semantic_2_loss: 0.0015 - val_loss: 0.0090 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0057 - val_semantic_2_loss: 0.0016
# Epoch 66/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0077 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0047 - semantic_2_loss: 0.0015Epoch 1/100
#  32/291 [==>...........................] - ETA: 52s - loss: 0.0090 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0057 - semantic_2_loss: 0.0016
# Epoch 00066: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 454ms/step - loss: 0.0077 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0047 - semantic_2_loss: 0.0015 - val_loss: 0.0090 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0057 - val_semantic_2_loss: 0.0016
# Epoch 67/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0078 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0048 - semantic_2_loss: 0.0015Epoch 1/100
#  32/291 [==>...........................] - ETA: 52s - loss: 0.0089 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0057 - semantic_2_loss: 0.0016
# Epoch 00067: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 452ms/step - loss: 0.0078 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0048 - semantic_2_loss: 0.0015 - val_loss: 0.0089 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0057 - val_semantic_2_loss: 0.0016
# Epoch 68/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0078 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0048 - semantic_2_loss: 0.0015Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0091 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0057 - semantic_2_loss: 0.0016
# Epoch 00068: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 454ms/step - loss: 0.0078 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0048 - semantic_2_loss: 0.0015 - val_loss: 0.0091 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0057 - val_semantic_2_loss: 0.0016
# Epoch 69/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0078 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0048 - semantic_2_loss: 0.0015Epoch 1/100
#  32/291 [==>...........................] - ETA: 52s - loss: 0.0091 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0058 - semantic_2_loss: 0.0016
# Epoch 00069: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 453ms/step - loss: 0.0078 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0048 - semantic_2_loss: 0.0015 - val_loss: 0.0091 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0058 - val_semantic_2_loss: 0.0016
# Epoch 70/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0077 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0047 - semantic_2_loss: 0.0015Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0090 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0057 - semantic_2_loss: 0.0016
# Epoch 00070: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 453ms/step - loss: 0.0077 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0047 - semantic_2_loss: 0.0015 - val_loss: 0.0090 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0057 - val_semantic_2_loss: 0.0016
# Epoch 71/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0077 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0047 - semantic_2_loss: 0.0015Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0090 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0057 - semantic_2_loss: 0.0016
# Epoch 00071: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 453ms/step - loss: 0.0077 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0047 - semantic_2_loss: 0.0015 - val_loss: 0.0090 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0057 - val_semantic_2_loss: 0.0016
# Epoch 72/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0076 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0047 - semantic_2_loss: 0.0014Epoch 1/100
#  32/291 [==>...........................] - ETA: 52s - loss: 0.0091 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0058 - semantic_2_loss: 0.0016
# Epoch 00072: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 453ms/step - loss: 0.0076 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0047 - semantic_2_loss: 0.0014 - val_loss: 0.0091 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0058 - val_semantic_2_loss: 0.0016
# Epoch 73/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0079 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0048 - semantic_2_loss: 0.0015Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0090 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0057 - semantic_2_loss: 0.0016
# Epoch 00073: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 454ms/step - loss: 0.0079 - semantic_0_loss: 0.0016 - semantic_1_loss: 0.0048 - semantic_2_loss: 0.0015 - val_loss: 0.0090 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0057 - val_semantic_2_loss: 0.0016
# Epoch 74/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0077 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0047 - semantic_2_loss: 0.0015Epoch 1/100
#  32/291 [==>...........................] - ETA: 52s - loss: 0.0091 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0057 - semantic_2_loss: 0.0016
# Epoch 00074: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 454ms/step - loss: 0.0077 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0047 - semantic_2_loss: 0.0015 - val_loss: 0.0091 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0057 - val_semantic_2_loss: 0.0016
# Epoch 75/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0077 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0047 - semantic_2_loss: 0.0014Epoch 1/100
#  32/291 [==>...........................] - ETA: 52s - loss: 0.0090 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0057 - semantic_2_loss: 0.0016
# Epoch 00075: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 452ms/step - loss: 0.0077 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0047 - semantic_2_loss: 0.0014 - val_loss: 0.0090 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0057 - val_semantic_2_loss: 0.0016
# Epoch 76/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0076 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0046 - semantic_2_loss: 0.0014Epoch 1/100
#  32/291 [==>...........................] - ETA: 52s - loss: 0.0089 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0057 - semantic_2_loss: 0.0016
# Epoch 00076: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 453ms/step - loss: 0.0076 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0046 - semantic_2_loss: 0.0014 - val_loss: 0.0089 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0057 - val_semantic_2_loss: 0.0016
# Epoch 77/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0077 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0047 - semantic_2_loss: 0.0014Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0092 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0058 - semantic_2_loss: 0.0016
# Epoch 00077: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 454ms/step - loss: 0.0077 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0047 - semantic_2_loss: 0.0014 - val_loss: 0.0092 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0058 - val_semantic_2_loss: 0.0016
# Epoch 78/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0077 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0047 - semantic_2_loss: 0.0015Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0091 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0058 - semantic_2_loss: 0.0016
# Epoch 00078: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 452ms/step - loss: 0.0077 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0047 - semantic_2_loss: 0.0015 - val_loss: 0.0091 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0058 - val_semantic_2_loss: 0.0016
# Epoch 79/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0078 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0048 - semantic_2_loss: 0.0015Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0090 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0057 - semantic_2_loss: 0.0016
# Epoch 00079: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 455ms/step - loss: 0.0078 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0048 - semantic_2_loss: 0.0015 - val_loss: 0.0090 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0057 - val_semantic_2_loss: 0.0016
# Epoch 80/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0074 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0045 - semantic_2_loss: 0.0014Epoch 1/100
#  32/291 [==>...........................] - ETA: 52s - loss: 0.0090 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0057 - semantic_2_loss: 0.0016
# Epoch 00080: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 453ms/step - loss: 0.0074 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0045 - semantic_2_loss: 0.0014 - val_loss: 0.0090 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0057 - val_semantic_2_loss: 0.0016
# Epoch 81/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0077 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0047 - semantic_2_loss: 0.0015Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0091 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0058 - semantic_2_loss: 0.0016
# Epoch 00081: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 455ms/step - loss: 0.0077 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0047 - semantic_2_loss: 0.0015 - val_loss: 0.0091 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0058 - val_semantic_2_loss: 0.0016
# Epoch 82/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0075 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0046 - semantic_2_loss: 0.0014Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0091 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0058 - semantic_2_loss: 0.0016
# Epoch 00082: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 454ms/step - loss: 0.0075 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0046 - semantic_2_loss: 0.0014 - val_loss: 0.0091 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0058 - val_semantic_2_loss: 0.0016
# Epoch 83/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0077 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0047 - semantic_2_loss: 0.0015Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0091 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0058 - semantic_2_loss: 0.0016
# Epoch 00083: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 453ms/step - loss: 0.0077 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0047 - semantic_2_loss: 0.0015 - val_loss: 0.0091 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0058 - val_semantic_2_loss: 0.0016
# Epoch 84/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0076 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0046 - semantic_2_loss: 0.0014Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0091 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0058 - semantic_2_loss: 0.0016
# Epoch 00084: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 453ms/step - loss: 0.0076 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0046 - semantic_2_loss: 0.0014 - val_loss: 0.0091 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0058 - val_semantic_2_loss: 0.0016
# Epoch 85/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0075 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0045 - semantic_2_loss: 0.0014Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0092 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0058 - semantic_2_loss: 0.0017
# Epoch 00085: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 454ms/step - loss: 0.0075 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0045 - semantic_2_loss: 0.0014 - val_loss: 0.0092 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0058 - val_semantic_2_loss: 0.0017
# Epoch 86/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0077 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0047 - semantic_2_loss: 0.0015Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0092 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0058 - semantic_2_loss: 0.0016
# Epoch 00086: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 455ms/step - loss: 0.0078 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0047 - semantic_2_loss: 0.0015 - val_loss: 0.0092 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0058 - val_semantic_2_loss: 0.0016
# Epoch 87/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0075 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0046 - semantic_2_loss: 0.0014Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0092 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0058 - semantic_2_loss: 0.0016
# Epoch 00087: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 453ms/step - loss: 0.0075 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0046 - semantic_2_loss: 0.0014 - val_loss: 0.0092 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0058 - val_semantic_2_loss: 0.0016
# Epoch 88/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0077 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0047 - semantic_2_loss: 0.0014Epoch 1/100
#  32/291 [==>...........................] - ETA: 52s - loss: 0.0093 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0059 - semantic_2_loss: 0.0017
# Epoch 00088: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 454ms/step - loss: 0.0077 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0047 - semantic_2_loss: 0.0014 - val_loss: 0.0093 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0059 - val_semantic_2_loss: 0.0017
# Epoch 89/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0074 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0045 - semantic_2_loss: 0.0014Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0092 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0058 - semantic_2_loss: 0.0016
# Epoch 00089: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 453ms/step - loss: 0.0074 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0045 - semantic_2_loss: 0.0014 - val_loss: 0.0092 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0058 - val_semantic_2_loss: 0.0016
# Epoch 90/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0074 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0045 - semantic_2_loss: 0.0014Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0091 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0058 - semantic_2_loss: 0.0016
# Epoch 00090: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 454ms/step - loss: 0.0074 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0045 - semantic_2_loss: 0.0014 - val_loss: 0.0091 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0058 - val_semantic_2_loss: 0.0016
# Epoch 91/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0076 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0046 - semantic_2_loss: 0.0014Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0091 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0058 - semantic_2_loss: 0.0016
# Epoch 00091: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 454ms/step - loss: 0.0076 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0046 - semantic_2_loss: 0.0014 - val_loss: 0.0091 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0058 - val_semantic_2_loss: 0.0016
# Epoch 92/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0077 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0047 - semantic_2_loss: 0.0015Epoch 1/100
#  32/291 [==>...........................] - ETA: 52s - loss: 0.0092 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0058 - semantic_2_loss: 0.0016
# Epoch 00092: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 453ms/step - loss: 0.0077 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0047 - semantic_2_loss: 0.0014 - val_loss: 0.0092 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0058 - val_semantic_2_loss: 0.0016
# Epoch 93/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0074 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0045 - semantic_2_loss: 0.0014Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0091 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0058 - semantic_2_loss: 0.0016
# Epoch 00093: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 453ms/step - loss: 0.0074 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0045 - semantic_2_loss: 0.0014 - val_loss: 0.0091 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0058 - val_semantic_2_loss: 0.0016
# Epoch 94/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0075 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0046 - semantic_2_loss: 0.0014Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0091 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0058 - semantic_2_loss: 0.0016
# Epoch 00094: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 454ms/step - loss: 0.0075 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0046 - semantic_2_loss: 0.0014 - val_loss: 0.0091 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0058 - val_semantic_2_loss: 0.0016
# Epoch 95/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0075 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0046 - semantic_2_loss: 0.0014Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0092 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0058 - semantic_2_loss: 0.0016
# Epoch 00095: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 453ms/step - loss: 0.0075 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0046 - semantic_2_loss: 0.0014 - val_loss: 0.0092 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0058 - val_semantic_2_loss: 0.0016
# Epoch 96/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0074 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0045 - semantic_2_loss: 0.0014Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0091 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0058 - semantic_2_loss: 0.0016
# Epoch 00096: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 454ms/step - loss: 0.0075 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0046 - semantic_2_loss: 0.0014 - val_loss: 0.0091 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0058 - val_semantic_2_loss: 0.0016
# Epoch 97/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0075 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0046 - semantic_2_loss: 0.0014Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0091 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0058 - semantic_2_loss: 0.0016
# Epoch 00097: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 454ms/step - loss: 0.0075 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0046 - semantic_2_loss: 0.0014 - val_loss: 0.0091 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0058 - val_semantic_2_loss: 0.0016
# Epoch 98/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0073 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0044 - semantic_2_loss: 0.0014Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0091 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0058 - semantic_2_loss: 0.0016
# Epoch 00098: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 453ms/step - loss: 0.0072 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0044 - semantic_2_loss: 0.0014 - val_loss: 0.0091 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0058 - val_semantic_2_loss: 0.0016
# Epoch 99/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0077 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0047 - semantic_2_loss: 0.0015Epoch 1/100
#  32/291 [==>...........................] - ETA: 52s - loss: 0.0091 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0058 - semantic_2_loss: 0.0016
# Epoch 00099: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 454ms/step - loss: 0.0077 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0047 - semantic_2_loss: 0.0015 - val_loss: 0.0091 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0058 - val_semantic_2_loss: 0.0016
# Epoch 100/100
# 290/291 [============================>.] - ETA: 0s - loss: 0.0074 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0045 - semantic_2_loss: 0.0014Epoch 1/100
#  32/291 [==>...........................] - ETA: 53s - loss: 0.0091 - semantic_0_loss: 0.0017 - semantic_1_loss: 0.0058 - semantic_2_loss: 0.0016
# Epoch 00100: val_loss did not improve from 0.00857
# 291/291 [==============================] - 132s 453ms/step - loss: 0.0074 - semantic_0_loss: 0.0015 - semantic_1_loss: 0.0045 - semantic_2_loss: 0.0014 - val_loss: 0.0091 - val_semantic_0_loss: 0.0017 - val_semantic_1_loss: 0.0058 - val_semantic_2_loss: 0.0016

# %% [markdown]
# ## Predict on test data
#
# Use the trained model to predict on new data. First, create a new prediction model without the foreground background semantic head. While this head is very useful during training, the output is unused during prediction. By using `model.load_weights(path, by_name=True)`, the semantic head can be removed.

# %%
from deepcell.model_zoo.panopticnet import PanopticNet

prediction_model = PanopticNet(
    backbone='resnet50',
    input_shape=X_train.shape[1:],
    norm_method='std',
    num_semantic_heads=2,
    num_semantic_classes=[1, 1], # inner distance, outer distance
    location=True,  # should always be true
    include_top=True)
# Out:
# Downloading data from https://github.com/keras-team/keras-applications/releases/download/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 4s 0us/step

# %%
model_path = os.path.join(MODEL_DIR, '{}.h5'.format(model_name))
prediction_model.load_weights(model_path, by_name=True)

# %%
# make predictions on testing data
from timeit import default_timer

start = default_timer()
test_images = prediction_model.predict(X_test)
watershed_time = default_timer() - start

print('Watershed segmentation of shape', test_images[0].shape, 'in', watershed_time, 'seconds.')
# Out:
# Watershed segmentation of shape (330, 256, 256, 1) in 9.56416448391974 seconds.

# %%
import time

from matplotlib import pyplot as plt
import numpy as np

from skimage.feature import peak_local_max

from deepcell_toolbox.deep_watershed import deep_watershed

index = 48#np.random.choice(X_test.shape[0])
print(index)

fig, axes = plt.subplots(1, 4, figsize=(20, 20))

print(test_images[0].shape)

masks = deep_watershed(
    test_images,
    min_distance=10,
    detection_threshold=0.1,
    distance_threshold=0.01,
    exclude_border=False,
    small_objects_threshold=0)

print('length of test_images is: ', len(test_images))
print('shape of test_images[0] is: ', test_images[0].shape)
print('shape of masks is: ', masks.shape)

# calculated in the postprocessing above, but useful for visualizing
inner_distance = test_images[0]
outer_distance = test_images[1]

coords = peak_local_max(
    inner_distance[index],
    min_distance=10,
    threshold_abs=0.1,
    exclude_border=False)

# raw image with centroid
axes[0].imshow(X_test[index, ..., 0])
axes[0].scatter(coords[..., 1], coords[..., 0],
                color='r', marker='.', s=10)

axes[1].imshow(inner_distance[index, ..., 0], cmap='jet')
axes[2].imshow(outer_distance[index, ..., 0], cmap='jet')
axes[3].imshow(masks[index, ...], cmap='jet')

plt.show()
# Out:
# 48
# (330, 256, 256, 1)
# length of test_images is:  2
# shape of test_images[0] is:  (330, 256, 256, 1)
# shape of masks is:  (330, 256, 256)

# %%
print(coords)

# %%
# Out:
# 48

# %% [markdown]
# ## Evaluate results
#
# The `deepcell.metrics` package is used to measure advanced metrics for instance segmentation predictions.

# %%
from deepcell_toolbox.metrics import Metrics
from skimage.morphology import watershed, remove_small_objects
from skimage.segmentation import clear_border

outputs = prediction_model.predict(X_test)

y_pred = []

for i in range(outputs[0].shape[0]):

    mask = deep_watershed(
        [t[[i]] for t in outputs],
        min_distance=10,
        detection_threshold=0.1,
        distance_threshold=0.01,
        exclude_border=False,
        small_objects_threshold=0)

    y_pred.append(mask[0])

y_pred = np.stack(y_pred, axis=0)
y_pred = np.expand_dims(y_pred, axis=-1)
y_true = y_test.copy()

print('DeepWatershed - Remove no pixels')
m = Metrics('DeepWatershed - Remove no pixels', seg=False)
m.calc_object_stats(y_true, y_pred)
print('\n')

for i in range(y_pred.shape[0]):
    y_pred[i] = remove_small_objects(y_pred[i].astype(int), min_size=100)
    y_true[i] = remove_small_objects(y_true[i].astype(int), min_size=100)

print('DeepWatershed - Remove objects < 100 pixels')
m = Metrics('DeepWatershed - Remove 100 pixels', seg=False)
m.calc_object_stats(y_true, y_pred)
print('\n')
# Out:
# DeepWatershed - Remove no pixels
#
# ____________Object-based statistics____________
#
# Number of true cells:		 3350
# Number of predicted cells:	 3941
#
# Correct detections:  2401	Recall: 71.671641791044777392016840167343616485595703125%
# Incorrect detections: 1540	Precision: 60.92362344582593181030460982583463191986083984375%
#
# Gained detections: 1197	Perc Error: 57.65895953757225100844152620993554592132568359375%
# Missed detections: 682	Perc Error: 32.8516377649325619358933181501924991607666015625%
# Merges: 65		Perc Error: 3.131021194605009494438263573101721704006195068359375%
# Splits: 132		Perc Error: 6.3583815028901735644240034162066876888275146484375%
# Catastrophes: 0		Perc Error: 0%
#
# Gained detections from splits: 146
# Missed detections from merges: 70
# True detections involved in catastrophes: 0
# Predicted detections involved in catastrophes: 0
#
# Average Pixel IOU (Jaccard Index): 0.671394729944708945623688123305328190326690673828125
#
#
#
# DeepWatershed - Remove objects < 100 pixels
#
# ____________Object-based statistics____________
#
# Number of true cells:		 3271
# Number of predicted cells:	 3892
#
# Correct detections:  2395	Recall: 73.2191990217059043288827524520456790924072265625%
# Incorrect detections: 1497	Precision: 61.5364850976361736911712796427309513092041015625%
#
# Gained detections: 1162	Perc Error: 58.7759231158320716303933295421302318572998046875%
# Missed detections: 626	Perc Error: 31.66413758219524510195697075687348842620849609375%
# Merges: 57		Perc Error: 2.883156297420333746828191578970290720462799072265625%
# Splits: 132		Perc Error: 6.676783004552351741267557372339069843292236328125%
# Catastrophes: 0		Perc Error: 0%
#
# Gained detections from splits: 146
# Missed detections from merges: 61
# True detections involved in catastrophes: 0
# Predicted detections involved in catastrophes: 0
#
# Average Pixel IOU (Jaccard Index): 0.671007856833493843140558965387754142284393310546875
