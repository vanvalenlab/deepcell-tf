# %% [markdown]
# # Watershed Distance Transform for 2D Data
# ---
# Implementation of papers:
#
# [Deep Watershed Transform for Instance Segmentation](http://openaccess.thecvf.com/content_cvpr_2017/papers/Bai_Deep_Watershed_Transform_CVPR_2017_paper.pdf)
#
# [Learn to segment single cells with deep distance estimator and deep cell detector](https://arxiv.org/abs/1803.10829)

# %%
import os
import errno
import numpy as np
import deepcell
from tensorflow.python import keras
import matplotlib.pyplot as plt
import xarray as xr

# %%
from tensorflow.keras.optimizers import SGD
from deepcell.utils.train_utils import rate_scheduler

test_size = .10  # % of data saved as test
norm_method = 'std'  # data normalization
receptive_field = 61  # should be adjusted for the scale of the data

optimizer = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)

lr_sched = rate_scheduler(lr=0.01, decay=0.99)

# Sample mode settings
batch_size = 64  # number of images per batch (should be 2 ^ n)
win = (receptive_field - 1) // 2  # sample window size
balance_classes = True  # sample each class equally
max_class_samples = 1e6  # max number of samples per class

# Transformation settings
transform = 'watershed'
distance_bins = 4  # number of distance "classes"
erosion_width = 2  # erode edges
LOG_DIR = '/data/logs'

# %%
base_name = 'Ilastik_Labels'
npz_name = '/data/npz_data/' + base_name + ".npz"
MODEL_DIR = '/data/models/' + '20191121_Codex'
MODEL_NAME = base_name + "_watershed_61_rf_256_dense_64_conv_2erosion"

if not os.path.isdir(MODEL_DIR):
    os.makedirs(MODEL_DIR)

# %% [markdown]
# ### Load the Training Data

# %%
CHANNEL_AXIS = 3
training_data = np.load(npz_name)

X, y = training_data["X"], training_data["y"]
print("X.shape: {} & y.shape: {}".format(X.shape, y.shape))
# Out:
# X.shape: (4, 964, 964, 2) & y.shape: (4, 964, 964, 1)

# %% [markdown]
# ### Create a model for the watershed energy transform
#
# #### Instantiate the distance transform model

# %%
from deepcell import model_zoo
from deepcell.training import train_model_sample

watershed_model = model_zoo.bn_feature_net_2D(
    receptive_field=receptive_field,
    n_channels=X.shape[CHANNEL_AXIS],
    n_features=distance_bins,
    n_conv_filters=64,
    n_dense_filters=256)

# %%
MODEL_NAME
# Out:
# 'Ilastik_Labels_watershed_61_rf_256_dense_64_conv_2erosion'

# %% [markdown]
# #### Train the model

# %%
watershed_model = train_model_sample(
    model=watershed_model,
    dataset=npz_name, 
    model_name=MODEL_NAME,
    test_size=test_size,
    optimizer=optimizer,
    batch_size=batch_size,
    n_epoch=5,
    window_size=(win, win),
    transform=transform,
    distance_bins=distance_bins,
    erosion_width=erosion_width,
    balance_classes=True,
    max_class_samples=700000,
    model_dir=MODEL_DIR,
    log_dir=LOG_DIR,
    lr_sched=lr_sched,
    rotation_range=180,
    flip=True,
    shear=False,
    zoom_range=(0.8, 1.2),
    val_monitor=False,
    save_period=1)
# Out:
# using all data as training data
# Using class weights of {0: 1.0, 1: 1.0, 2: 1.0, 3: 1.0}
# X_train shape: (4, 964, 964, 2)
# y_train shape: (4, 964, 964, 1)
# Output Shape: (None, 4)
# Number of Classes: 4
# Training on 1 GPUs
# the max_class_samples per image is 175000
# analyzing image 0
# the least represented class has 13565 examples
# analyzing class 0
# downsampling from 746442 examples per class
# analyzing class 1
# downsampling from 37887 examples per class
# analyzing class 2
# downsampling from 17515 examples per class
# analyzing class 3
# downsampling from 13565 examples per class
# analyzing image 1
# the least represented class has 8339 examples
# analyzing class 0
# downsampling from 782718 examples per class
# analyzing class 1
# downsampling from 15772 examples per class
# analyzing class 2
# downsampling from 8339 examples per class
# analyzing class 3
# downsampling from 8580 examples per class
# analyzing image 2
# the least represented class has 9385 examples
# analyzing class 0
# downsampling from 775117 examples per class
# analyzing class 1
# downsampling from 20612 examples per class
# analyzing class 2
# downsampling from 10295 examples per class
# analyzing class 3
# downsampling from 9385 examples per class
# analyzing image 3
# the least represented class has 8365 examples
# analyzing class 0
# downsampling from 773487 examples per class
# analyzing class 1
# downsampling from 23292 examples per class
# analyzing class 2
# downsampling from 10265 examples per class
# analyzing class 3
# downsampling from 8365 examples per class
# running model without validation checks
# Epoch 1/5
# 2476/2478 [============================>.] - ETA: 0s - loss: 1.0146 - acc: 0.4744
# Epoch 00001: saving model to /data/models/20191121_Codex/Ilastik_Labels_watershed_61_rf_256_dense_64_conv_2erosion_epoch_01.h5
# 2478/2478 [==============================] - 129s 52ms/step - loss: 1.0147 - acc: 0.4743
# Epoch 2/5
# 2477/2478 [============================>.] - ETA: 0s - loss: 0.9657 - acc: 0.5008
# Epoch 00002: saving model to /data/models/20191121_Codex/Ilastik_Labels_watershed_61_rf_256_dense_64_conv_2erosion_epoch_02.h5
# 2478/2478 [==============================] - 125s 50ms/step - loss: 0.9657 - acc: 0.5008
# Epoch 3/5
# 2476/2478 [============================>.] - ETA: 0s - loss: 0.9528 - acc: 0.5071
# Epoch 00003: saving model to /data/models/20191121_Codex/Ilastik_Labels_watershed_61_rf_256_dense_64_conv_2erosion_epoch_03.h5
# 2478/2478 [==============================] - 125s 50ms/step - loss: 0.9528 - acc: 0.5071
# Epoch 4/5
# 2476/2478 [============================>.] - ETA: 0s - loss: 0.9472 - acc: 0.5112
# Epoch 00004: saving model to /data/models/20191121_Codex/Ilastik_Labels_watershed_61_rf_256_dense_64_conv_2erosion_epoch_04.h5
# 2478/2478 [==============================] - 125s 50ms/step - loss: 0.9472 - acc: 0.5112
# Epoch 5/5
# 2476/2478 [============================>.] - ETA: 0s - loss: 0.9428 - acc: 0.5124
# Epoch 00005: saving model to /data/models/20191121_Codex/Ilastik_Labels_watershed_61_rf_256_dense_64_conv_2erosion_epoch_05.h5
# 2478/2478 [==============================] - 125s 50ms/step - loss: 0.9427 - acc: 0.5123

# %%
hist = np.load(os.path.join(MODEL_DIR, MODEL_NAME + ".npz"))
hist['loss_history'].tolist()['acc']
# Out:
# [0.47433649528380856,
#  0.500832534435148,
#  0.5071017710247941,
#  0.5112644432125638,
#  0.5122546546213429]

# %%
EPOCH_NAME = "_epoch_05"
watershed_weights_file = os.path.join(MODEL_DIR, MODEL_NAME + EPOCH_NAME + ".h5")

# %%
# load watershed model
run_watershed_model = model_zoo.bn_feature_net_2D(
    dilated=True,
    receptive_field=receptive_field,
    n_features=distance_bins,
    input_shape=tuple(X.shape[1:]), 
    n_conv_filters=64,
    n_dense_filters=256)
run_watershed_model.load_weights(watershed_weights_file)

# %%
# load test data
test_data = np.load("/data/npz_data/Ilastik_Labels.npz")

X_test, y_test = test_data["X"], test_data["y"]
print("X.shape: {} & y.shape: {}".format(X.shape, y.shape))
# Out:
# X.shape: (4, 964, 964, 2) & y.shape: (4, 964, 964, 1)

# %%
# run the model
test_images1 = run_watershed_model.predict(X_test[2:, ...])

# %%
xr_output = xr.DataArray(test_images,
                         coords=[['Point3', 'Point4'], range(test_images.shape[1]), range(test_images.shape[2]),
                                    ['level_1', 'level_2', 'level_3', 'level_4']],
                         dims=['points', 'rows', 'cols', 'masks'])
xr_output.to_netcdf(os.path.join(MODEL_DIR, "watershed_output1.nc"), format="NETCDF3_64BIT")

# %%
argmax_images = []
for j in range(test_images.shape[0]):
    argmax_images.append(np.argmax(test_images[j, ...], axis=-1))
argmax_images = np.array(argmax_images)

# %%
plt.figure(figsize = (13, 13))
plt.imshow(argmax_images[0, 400:600, 200:400])

# %%
plt.figure(figsize = (13, 13))
plt.imshow(argmax_images[0, :, :])

# %%
plt.figure(figsize = (13, 13))
plt.imshow(X_test[0, :, :, 5])
