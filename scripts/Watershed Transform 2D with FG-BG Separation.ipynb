# %% [markdown]
# # Watershed distance transform with foreground and background separation
# ---
# Implementation of papers:
#
# [Deep Watershed Transform for Instance Segmentation](http://openaccess.thecvf.com/content_cvpr_2017/papers/Bai_Deep_Watershed_Transform_CVPR_2017_paper.pdf)
#
# [Learn to segment single cells with deep distance estimator and deep cell detector](https://arxiv.org/abs/1803.10829)

# %%
import os
import errno
import argparse

import numpy as np
from skimage.external import tifffile as tiff
from tensorflow.python.keras.optimizers import SGD, Adam
from tensorflow.python.keras import backend as K

from deepcell import get_data
from deepcell import make_training_data
from deepcell import rate_scheduler
from deepcell.model_zoo import bn_multires_feature_net
from deepcell.model_zoo import bn_feature_net_61x61
from deepcell.model_zoo import dilated_bn_feature_net_61x61
from deepcell.training import train_model_conv
from deepcell.training import train_model_sample
from deepcell.training import train_model_watershed
from deepcell.training import train_model_watershed_sample
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# ## Conv Based Training

# %%
DATA_OUTPUT_MODE = 'conv'
BORDER_MODE = 'same'
RESIZE = True
RESHAPE_SIZE = 256
BINS = 4

# filepath constants
DATA_DIR = '/data/data'
MODEL_DIR = '/data/models'
NPZ_DIR = '/data/npz_data'
RESULTS_DIR = '/data/results'
EXPORT_DIR = '/data/exports'
PREFIX = 'cells/unspecified_nuclear_data/nuclei_broad'
CONV_DATA_FILE = 'nuclei_broad_watershed_{}'.format(DATA_OUTPUT_MODE)

# Check for channels_first or channels_last
IS_CHANNELS_FIRST = K.image_data_format() == 'channels_first'

ROW_AXIS = 2 if IS_CHANNELS_FIRST else 1
COL_AXIS = 3 if IS_CHANNELS_FIRST else 2
CHANNEL_AXIS = 1 if IS_CHANNELS_FIRST else -1

# create these directories if they do not exist
for d in (NPZ_DIR, MODEL_DIR, RESULTS_DIR):
    try:
        os.makedirs(os.path.join(d, PREFIX))
        print('Created new directory:', os.path.join(d, PREFIX))
    except OSError as exc: # Guard against race condition
        if exc.errno != errno.EEXIST:
            raise

# %%
# Make the training data for foreground/background segmentation
make_training_data(
    direc_name=os.path.join(DATA_DIR, PREFIX),
    dimensionality=2,
    max_training_examples=1e6,
    window_size_x=30,
    window_size_y=30,
    border_mode=BORDER_MODE,
    file_name_save=os.path.join(NPZ_DIR, PREFIX, CONV_DATA_FILE),
    training_direcs=['set1', 'set2', 'set3', 'set4', 'set5'],
    distance_transform=False,  # not needed for conv mode
    distance_bins=BINS,  # not needed for conv mode
    channel_names=['nuclear'],
    num_of_features=BINS,
    raw_image_direc='raw',
    annotation_direc='annotated',
    reshape_size=RESHAPE_SIZE if RESIZE else None,
    edge_feature=[1, 0, 0],
    dilation_radius=1,
    output_mode=DATA_OUTPUT_MODE,
    display=False,
    verbose=False)

if os.path.isfile(os.path.join(NPZ_DIR, PREFIX, CONV_DATA_FILE) + '.npz'):
    print('Data Saved to', os.path.join(NPZ_DIR, PREFIX, CONV_DATA_FILE) + '.npz')
else:
    raise Exception('Uh Oh!  Your data file did not save properly :(')
# Out:
# Reshaped feature data from (5, 520, 696, 3) to (45, 256, 256, 3)
# Reshaped training data from (5, 520, 696, 1) to (45, 256, 256, 1)
# Data Saved to /data/npz_data/cells/unspecified_nuclear_data/nuclei_broad/nuclei_broad_watershed_conv.npz

# %%
# Load the training data from NPZ into a numpy array
training_data = np.load(os.path.join(NPZ_DIR, PREFIX, CONV_DATA_FILE + '.npz'))

X, y = training_data['X'], training_data['y']
print('X.shape: {}\ny.shape: {}'.format(X.shape, y.shape))

# save the size of the input data for input_shape model parameter
size = (RESHAPE_SIZE, RESHAPE_SIZE) if RESIZE else X.shape[ROW_AXIS:COL_AXIS + 1]
if IS_CHANNELS_FIRST:
    input_shape = (X.shape[CHANNEL_AXIS], size[0], size[1])
else:
    input_shape = (size[0], size[1], X.shape[CHANNEL_AXIS])
    
# Set up other training parameters
n_epoch = 10
batch_size = 1
optimizer = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
lr_sched = rate_scheduler(lr=0.01, decay=0.99)
# Out:
# X.shape: (45, 256, 256, 1)
# y.shape: (45, 256, 256, 3)

# %%
# First, create a foreground/background separation model

# Instantiate the model
fgbg_model = bn_multires_feature_net(n_features=3, input_shape=input_shape)

# Train the model
train_model_conv(
    model=fgbg_model,
    dataset=CONV_DATA_FILE,
    optimizer=optimizer,
    batch_size=batch_size,
    n_epoch=n_epoch,
    direc_save=os.path.join(MODEL_DIR, PREFIX),
    direc_data=os.path.join(NPZ_DIR, PREFIX),
    expt='fgbg',
    lr_sched=lr_sched,
    class_weight=training_data['class_weights'],
    rotation_range=180,
    flip=True,
    shear=False)
# Out:
# X_train shape: (40, 256, 256, 1)
# y_train shape: (40, 256, 256, 3)
# X_test shape: (5, 256, 256, 1)
# y_test shape: (5, 256, 256, 3)
# Output Shape: (None, 256, 256, 3)
# Number of Classes: 3
# Using real-time data augmentation.
# Epoch 1/10
# 39/40 [============================>.] - ETA: 0s - loss: 0.3760 - acc: 0.7597
# Epoch 00001: val_loss improved from inf to 0.53179, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-07-11_nuclei_broad_watershed_conv_fgbg_0.h5
# 40/40 [==============================] - 12s 295ms/step - loss: 0.3716 - acc: 0.7632 - val_loss: 0.5318 - val_acc: 0.7355
# Epoch 2/10
# 39/40 [============================>.] - ETA: 0s - loss: 0.1830 - acc: 0.8367
# Epoch 00002: val_loss improved from 0.53179 to 0.32971, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-07-11_nuclei_broad_watershed_conv_fgbg_0.h5
# 40/40 [==============================] - 2s 55ms/step - loss: 0.1831 - acc: 0.8364 - val_loss: 0.3297 - val_acc: 0.9045
# Epoch 3/10
# 39/40 [============================>.] - ETA: 0s - loss: 0.1641 - acc: 0.8558
# Epoch 00003: val_loss improved from 0.32971 to 0.25567, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-07-11_nuclei_broad_watershed_conv_fgbg_0.h5
# 40/40 [==============================] - 2s 55ms/step - loss: 0.1632 - acc: 0.8576 - val_loss: 0.2557 - val_acc: 0.9389
# Epoch 4/10
# 39/40 [============================>.] - ETA: 0s - loss: 0.1512 - acc: 0.8537
# Epoch 00004: val_loss improved from 0.25567 to 0.22036, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-07-11_nuclei_broad_watershed_conv_fgbg_0.h5
# 40/40 [==============================] - 2s 55ms/step - loss: 0.1519 - acc: 0.8554 - val_loss: 0.2204 - val_acc: 0.9475
# Epoch 5/10
# 39/40 [============================>.] - ETA: 0s - loss: 0.1406 - acc: 0.8412
# Epoch 00005: val_loss improved from 0.22036 to 0.19729, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-07-11_nuclei_broad_watershed_conv_fgbg_0.h5
# 40/40 [==============================] - 2s 55ms/step - loss: 0.1417 - acc: 0.8407 - val_loss: 0.1973 - val_acc: 0.9539
# Epoch 6/10
# 38/40 [===========================>..] - ETA: 0s - loss: 0.1381 - acc: 0.8554
# Epoch 00006: val_loss improved from 0.19729 to 0.18777, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-07-11_nuclei_broad_watershed_conv_fgbg_0.h5
# 40/40 [==============================] - 2s 55ms/step - loss: 0.1389 - acc: 0.8533 - val_loss: 0.1878 - val_acc: 0.9534
# Epoch 7/10
# 39/40 [============================>.] - ETA: 0s - loss: 0.1366 - acc: 0.8518
# Epoch 00007: val_loss improved from 0.18777 to 0.18324, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-07-11_nuclei_broad_watershed_conv_fgbg_0.h5
# 40/40 [==============================] - 2s 54ms/step - loss: 0.1355 - acc: 0.8509 - val_loss: 0.1832 - val_acc: 0.9543
# Epoch 8/10
# 39/40 [============================>.] - ETA: 0s - loss: 0.1333 - acc: 0.8466
# Epoch 00008: val_loss improved from 0.18324 to 0.17689, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-07-11_nuclei_broad_watershed_conv_fgbg_0.h5
# 40/40 [==============================] - 2s 56ms/step - loss: 0.1339 - acc: 0.8460 - val_loss: 0.1769 - val_acc: 0.9516
# Epoch 9/10
# 39/40 [============================>.] - ETA: 0s - loss: 0.1329 - acc: 0.8473
# Epoch 00009: val_loss did not improve
# 40/40 [==============================] - 2s 52ms/step - loss: 0.1332 - acc: 0.8474 - val_loss: 0.1843 - val_acc: 0.9542
# Epoch 10/10
# 38/40 [===========================>..] - ETA: 0s - loss: 0.1300 - acc: 0.8491
# Epoch 00010: val_loss improved from 0.17689 to 0.16902, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-07-11_nuclei_broad_watershed_conv_fgbg_0.h5
# 40/40 [==============================] - 2s 56ms/step - loss: 0.1302 - acc: 0.8490 - val_loss: 0.1690 - val_acc: 0.9528

# %%
# Next, Create a model for the watershed energy transform

# Instantiate the model
watershed_model = bn_multires_feature_net(n_features=BINS, input_shape=input_shape)

# Train the model
train_model_watershed(
    model=watershed_model,
    dataset=CONV_DATA_FILE,
    optimizer=optimizer,
    batch_size=batch_size,
    n_epoch=n_epoch,
    distance_bins=BINS,
    direc_save=os.path.join(MODEL_DIR, PREFIX),
    direc_data=os.path.join(NPZ_DIR, PREFIX),
    expt='watershed',
    lr_sched=lr_sched,
    class_weight=training_data['class_weights'],
    rotation_range=180,
    flip=True,
    shear=False)
# Out:
# X_train shape: (40, 256, 256, 1)
# y_train shape: (40, 256, 256, 3)
# X_test shape: (5, 256, 256, 1)
# y_test shape: (5, 256, 256, 3)
# Output Shape: (None, 256, 256, 4)
# Number of Classes: 4
# Using real-time data augmentation.
# Epoch 1/10
# 39/40 [============================>.] - ETA: 0s - loss: 0.3261 - acc: 0.8860
# Epoch 00001: val_loss improved from inf to 0.42442, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-07-11_nuclei_broad_watershed_conv_watershed_0.h5
# 40/40 [==============================] - 5s 114ms/step - loss: 0.3224 - acc: 0.8870 - val_loss: 0.4244 - val_acc: 0.9075
# Epoch 2/10
# 38/40 [===========================>..] - ETA: 0s - loss: 0.1376 - acc: 0.9479
# Epoch 00002: val_loss improved from 0.42442 to 0.20115, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-07-11_nuclei_broad_watershed_conv_watershed_0.h5
# 40/40 [==============================] - 2s 59ms/step - loss: 0.1390 - acc: 0.9474 - val_loss: 0.2012 - val_acc: 0.9457
# Epoch 3/10
# 39/40 [============================>.] - ETA: 0s - loss: 0.1213 - acc: 0.9552
# Epoch 00003: val_loss improved from 0.20115 to 0.15263, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-07-11_nuclei_broad_watershed_conv_watershed_0.h5
# 40/40 [==============================] - 2s 60ms/step - loss: 0.1202 - acc: 0.9557 - val_loss: 0.1526 - val_acc: 0.9363
# Epoch 4/10
# 39/40 [============================>.] - ETA: 0s - loss: 0.1134 - acc: 0.9593
# Epoch 00004: val_loss improved from 0.15263 to 0.11344, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-07-11_nuclei_broad_watershed_conv_watershed_0.h5
# 40/40 [==============================] - 2s 58ms/step - loss: 0.1141 - acc: 0.9591 - val_loss: 0.1134 - val_acc: 0.9612
# Epoch 5/10
# 39/40 [============================>.] - ETA: 0s - loss: 0.1073 - acc: 0.9611
# Epoch 00005: val_loss did not improve
# 40/40 [==============================] - 2s 55ms/step - loss: 0.1063 - acc: 0.9617 - val_loss: 0.1172 - val_acc: 0.9501
# Epoch 6/10
# 39/40 [============================>.] - ETA: 0s - loss: 0.1053 - acc: 0.9625
# Epoch 00006: val_loss improved from 0.11344 to 0.08961, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-07-11_nuclei_broad_watershed_conv_watershed_0.h5
# 40/40 [==============================] - 2s 57ms/step - loss: 0.1053 - acc: 0.9625 - val_loss: 0.0896 - val_acc: 0.9685
# Epoch 7/10
# 39/40 [============================>.] - ETA: 0s - loss: 0.1007 - acc: 0.9642
# Epoch 00007: val_loss improved from 0.08961 to 0.07709, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-07-11_nuclei_broad_watershed_conv_watershed_0.h5
# 40/40 [==============================] - 2s 58ms/step - loss: 0.1014 - acc: 0.9638 - val_loss: 0.0771 - val_acc: 0.9747
# Epoch 8/10
# 39/40 [============================>.] - ETA: 0s - loss: 0.1005 - acc: 0.9642
# Epoch 00008: val_loss did not improve
# 40/40 [==============================] - 2s 54ms/step - loss: 0.0999 - acc: 0.9644 - val_loss: 0.0848 - val_acc: 0.9700
# Epoch 9/10
# 39/40 [============================>.] - ETA: 0s - loss: 0.0985 - acc: 0.9650
# Epoch 00009: val_loss did not improve
# 40/40 [==============================] - 2s 55ms/step - loss: 0.0983 - acc: 0.9651 - val_loss: 0.0777 - val_acc: 0.9732
# Epoch 10/10
# 38/40 [===========================>..] - ETA: 0s - loss: 0.0948 - acc: 0.9665
# Epoch 00010: val_loss did not improve
# 40/40 [==============================] - 2s 54ms/step - loss: 0.0940 - acc: 0.9668 - val_loss: 0.0801 - val_acc: 0.9714

# %%
# With the trained model, make predictions on testing data
training_data_file = os.path.join(NPZ_DIR, PREFIX, CONV_DATA_FILE + '.npz')

train_dict, (X_test, y_test) = get_data(
    training_data_file, mode=DATA_OUTPUT_MODE, seed=21)

test_images = watershed_model.predict(X_test)
test_images_fgbg = fgbg_model.predict(X_test)

print('watershed transform shape:', test_images.shape)
print('segmentation mask shape:', test_images_fgbg.shape)

argmax_images = []
for i in range(test_images.shape[0]):
    max_image = np.argmax(test_images[i], axis=CHANNEL_AXIS)
    argmax_images.append(max_image)
argmax_images = np.array(argmax_images)
argmax_images = np.expand_dims(argmax_images, axis=CHANNEL_AXIS)

print('watershed argmax shape:', argmax_images.shape)
# Out:
# watershed transform shape: (5, 256, 256, 4)
# segmentation mask shape: (5, 256, 256, 3)
# watershed argmax shape: (5, 256, 256, 1)

# %%
# Plot the results
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [15, 15]

if IS_CHANNELS_FIRST:
    fg_thresh = test_images_fgbg[:, 1, :, :] > 0.8
else:
    fg_thresh = test_images_fgbg[:, :, :, 1] > 0.8

fg_thresh = np.expand_dims(fg_thresh, axis=CHANNEL_AXIS)
argmax_images_post_fgbg = argmax_images * fg_thresh

index = 0

plt.subplot(3, 2, 1)
plt.imshow(X_test[index, :, :, 0])

plt.subplot(3, 2, 2)
plt.imshow(test_images_fgbg[index, :, :, 1])

plt.subplot(3, 2, 3)
plt.imshow(argmax_images[index, :, :, 0], cmap='jet')

plt.subplot(3, 2, 4)
plt.imshow(argmax_images_post_fgbg[index, :, :, 0], cmap='jet')

# %% [markdown]
# # Sample Based Training

# %%
DATA_OUTPUT_MODE = 'sample'
BORDER_MODE = 'valid'
RESIZE = True
RESHAPE_SIZE = 256
BINS = 4

# filepath constants
DATA_DIR = '/data/data'
MODEL_DIR = '/data/models'
NPZ_DIR = '/data/npz_data'
RESULTS_DIR = '/data/results'
EXPORT_DIR = '/data/exports'
PREFIX = 'cells/unspecified_nuclear_data/nuclei_broad'
WATERSHED_DATA_FILE = 'nuclei_broad_watershed_{}'.format(DATA_OUTPUT_MODE)
FG_BG_DATA_FILE = 'nuclei_broad_{}'.format(DATA_OUTPUT_MODE)

# %%
# Make the training data for foreground/background segmentation
make_training_data(
    direc_name=os.path.join(DATA_DIR, PREFIX),
    dimensionality=2,
    max_training_examples=1e6,
    window_size_x=30,
    window_size_y=30,
    border_mode=BORDER_MODE,
    file_name_save=os.path.join(NPZ_DIR, PREFIX, FG_BG_DATA_FILE),
    training_direcs=['set1', 'set2', 'set3', 'set4', 'set5'],
    distance_transform=False,  # only used for watershed transform data
    distance_bins=BINS,
    channel_names=['nuclear'],
    num_of_features=BINS,
    raw_image_direc='raw',
    annotation_direc='annotated',
    reshape_size=RESHAPE_SIZE if RESIZE else None,
    edge_feature=[1, 0, 0],
    dilation_radius=1,
    output_mode=DATA_OUTPUT_MODE,
    display=False,
    verbose=False)

if os.path.isfile(os.path.join(NPZ_DIR, PREFIX, WATERSHED_DATA_FILE) + '.npz'):
    print('Data Saved to', os.path.join(NPZ_DIR, PREFIX, WATERSHED_DATA_FILE) + '.npz')
else:
    raise Exception('Uh Oh!  Your data file did not save properly :(')
# Out:
# Reshaped feature data from (5, 520, 696, 3) to (45, 256, 256, 3)
# Reshaped training data from (5, 520, 696, 1) to (45, 256, 256, 1)
# Data Saved to /data/npz_data/cells/unspecified_nuclear_data/nuclei_broad/nuclei_broad_watershed_sample.npz

# %%
# Make the training data for watershed energy transform
make_training_data(
    direc_name=os.path.join(DATA_DIR, PREFIX),
    dimensionality=2,
    max_training_examples=1e6,
    window_size_x=30,
    window_size_y=30,
    border_mode=BORDER_MODE,
    file_name_save=os.path.join(NPZ_DIR, PREFIX, WATERSHED_DATA_FILE),
    training_direcs=['set1', 'set2', 'set3', 'set4', 'set5'],
    distance_transform=True,  # transforms the data before passing to data generator
    distance_bins=BINS,
    channel_names=['nuclear'],
    num_of_features=BINS,
    raw_image_direc='raw',
    annotation_direc='annotated',
    reshape_size=RESHAPE_SIZE if RESIZE else None,
    edge_feature=[1, 0, 0],
    dilation_radius=1,
    output_mode=DATA_OUTPUT_MODE,
    display=False,
    verbose=False)

if os.path.isfile(os.path.join(NPZ_DIR, PREFIX, WATERSHED_DATA_FILE) + '.npz'):
    print('Data Saved to', os.path.join(NPZ_DIR, PREFIX, WATERSHED_DATA_FILE) + '.npz')
else:
    raise Exception('Uh Oh!  Your data file did not save properly :(')
# Out:
# Reshaped feature data from (5, 520, 696, 3) to (45, 256, 256, 3)
# Reshaped training data from (5, 520, 696, 1) to (45, 256, 256, 1)
# Data Saved to /data/npz_data/cells/unspecified_nuclear_data/nuclei_broad/nuclei_broad_watershed_sample.npz

# %%
# Load the training data from NPZ into a numpy array
training_data = np.load(os.path.join(NPZ_DIR, PREFIX, FG_BG_DATA_FILE + '.npz'))

X, y = training_data['X'], training_data['y']
print('X.shape: {}\ny.shape: {}'.format(X.shape, y.shape))

# save the size of the input data for input_shape model parameter
size = (RESHAPE_SIZE, RESHAPE_SIZE) if RESIZE else X.shape[ROW_AXIS:COL_AXIS + 1]
if IS_CHANNELS_FIRST:
    input_shape = (X.shape[CHANNEL_AXIS], size[0], size[1])
else:
    input_shape = (size[0], size[1], X.shape[CHANNEL_AXIS])
    
# Set up other training parameters
n_epoch = 3
batch_size = 32
optimizer = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
lr_sched = rate_scheduler(lr=0.01, decay=0.99)
# Out:
# X.shape: (45, 256, 256, 1)
# y.shape: (638858,)

# %%
# First, create a foreground/background separation model

# Instantiate the model
fgbg_model = bn_feature_net_61x61(n_features=3)

# Train the model
train_model_sample(
    model=fgbg_model,
    dataset=FG_BG_DATA_FILE,
    optimizer=optimizer,
    batch_size=batch_size,
    n_epoch=n_epoch,
    direc_save=os.path.join(MODEL_DIR, PREFIX),
    direc_data=os.path.join(NPZ_DIR, PREFIX),
    expt='fgbg',
    lr_sched=lr_sched,
    class_weight=training_data['class_weights'],
    rotation_range=180,
    flip=True,
    shear=False)
# Out:
# Using feature net 61x61 with batch normalization
# X_train shape: (574972, 61, 61, 1)
# y_train shape: (574972,)
# X_test shape: (63886, 61, 61, 1)
# y_test shape: (63886,)
# Output Shape: (None, 3)
# Number of Classes: 3
# Using real-time data augmentation.
# Epoch 1/3
# 17964/17967 [============================>.] - ETA: 0s - loss: 0.2987 - acc: 0.8764
# Epoch 00001: val_loss improved from inf to 0.19269, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-07-11_nuclei_broad_sample_fgbg_0.h5
# 17967/17967 [==============================] - 369s 21ms/step - loss: 0.2987 - acc: 0.8764 - val_loss: 0.1927 - val_acc: 0.9316
# Epoch 2/3
# 17966/17967 [============================>.] - ETA: 0s - loss: 0.2812 - acc: 0.8836
# Epoch 00002: val_loss did not improve
# 17967/17967 [==============================] - 368s 20ms/step - loss: 0.2812 - acc: 0.8836 - val_loss: 0.1967 - val_acc: 0.9294
# Epoch 3/3
# 17965/17967 [============================>.] - ETA: 0s - loss: 0.2743 - acc: 0.8859
# Epoch 00003: val_loss did not improve
# 17967/17967 [==============================] - 369s 21ms/step - loss: 0.2743 - acc: 0.8859 - val_loss: 0.1961 - val_acc: 0.9314

# %%
# Next, Create a model for the watershed energy transform

# Instantiate the model
watershed_model = bn_feature_net_61x61(n_features=BINS)

# Train the model
train_model_watershed_sample(
    model=watershed_model,
    dataset=WATERSHED_DATA_FILE,
    optimizer=optimizer,
    batch_size=batch_size,
    n_epoch=n_epoch,
    distance_bins=BINS,
    direc_save=os.path.join(MODEL_DIR, PREFIX),
    direc_data=os.path.join(NPZ_DIR, PREFIX),
    expt='watershed',
    lr_sched=lr_sched,
    class_weight=training_data['class_weights'],
    rotation_range=180,
    flip=True,
    shear=False)
# Out:
# Using feature net 61x61 with batch normalization
# X_train shape: (134953, 61, 61, 1)
# y_train shape: (134953,)
# X_test shape: (14995, 61, 61, 1)
# y_test shape: (14995,)
# Output Shape: (None, 4)
# Number of Classes: 4
# Using real-time data augmentation.
# Epoch 1/3
# 4216/4217 [============================>.] - ETA: 0s - loss: 0.4106 - acc: 0.8222
# Epoch 00001: val_loss improved from inf to 0.30398, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-07-11_nuclei_broad_watershed_sample_watershed_0.h5
# 4217/4217 [==============================] - 89s 21ms/step - loss: 0.4106 - acc: 0.8222 - val_loss: 0.3040 - val_acc: 0.9002
# Epoch 2/3
# 4216/4217 [============================>.] - ETA: 0s - loss: 0.3843 - acc: 0.8339
# Epoch 00002: val_loss improved from 0.30398 to 0.28215, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-07-11_nuclei_broad_watershed_sample_watershed_0.h5
# 4217/4217 [==============================] - 86s 20ms/step - loss: 0.3843 - acc: 0.8339 - val_loss: 0.2821 - val_acc: 0.8926
# Epoch 3/3
# 4216/4217 [============================>.] - ETA: 0s - loss: 0.3730 - acc: 0.8389
# Epoch 00003: val_loss did not improve
# 4217/4217 [==============================] - 86s 20ms/step - loss: 0.3730 - acc: 0.8389 - val_loss: 0.3003 - val_acc: 0.8878

# %%
# Re-initializing dilated models for sample-mode predictions
model_fn = dilated_bn_feature_net_61x61
watershed_weights_file = '2018-07-11_nuclei_broad_watershed_sample_watershed_0.h5'
watershed_weights_file = os.path.join(MODEL_DIR, PREFIX, watershed_weights_file)

fg_bg_weights_file = '2018-07-11_nuclei_broad_sample_fgbg_0.h5'
fg_bg_weights_file = os.path.join(MODEL_DIR, PREFIX, fg_bg_weights_file)

run_watershed_model = model_fn(n_features=BINS, input_shape=input_shape)
run_watershed_model.load_weights(watershed_weights_file)

run_fgbg_model = model_fn(n_features=3, input_shape=input_shape)
run_fgbg_model.load_weights(fg_bg_weights_file)
# Out:
# Using dilated feature net 61x61 with batch normalization
# Using dilated feature net 61x61 with batch normalization

# %%
# With the trained model, make predictions on testing data
training_data_file = os.path.join(NPZ_DIR, PREFIX, CONV_DATA_FILE + '.npz')

train_dict, (X_test, y_test) = get_data(training_data_file, mode='conv', seed=21)

test_images = run_watershed_model.predict(X_test)
test_images_fgbg = run_fgbg_model.predict(X_test)

print('watershed transform shape:', test_images.shape)
print('segmentation mask shape:', test_images_fgbg.shape)

argmax_images = []
for i in range(test_images.shape[0]):
    argmax_images.append(np.argmax(test_images[i], axis=CHANNEL_AXIS))
argmax_images = np.array(argmax_images)
argmax_images = np.expand_dims(argmax_images, axis=CHANNEL_AXIS)

print('watershed argmax shape:', argmax_images.shape)
# Out:
# watershed transform shape: (5, 196, 196, 4)
# segmentation mask shape: (5, 196, 196, 3)
# watershed argmax shape: (5, 196, 196, 1)

# %%
# Plot the results
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [15, 15]

if IS_CHANNELS_FIRST:
    fg_thresh = test_images_fgbg[:, 1, :, :] > 0.8
else:
    fg_thresh = test_images_fgbg[:, :, :, 1] > 0.8

fg_thresh = np.expand_dims(fg_thresh, axis=CHANNEL_AXIS)
argmax_images_post_fgbg = argmax_images * fg_thresh

index = 0

plt.subplot(3, 2, 1)
plt.imshow(X_test[index, :, :, 0])

plt.subplot(3, 2, 2)
plt.imshow(test_images_fgbg[index, :, :, 1])

plt.subplot(3, 2, 3)
plt.imshow(argmax_images[index, :, :, 0], cmap='jet')

plt.subplot(3, 2, 4)
plt.imshow(argmax_images_post_fgbg[index, :, :, 0], cmap='jet')
