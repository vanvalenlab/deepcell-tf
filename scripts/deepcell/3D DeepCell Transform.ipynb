# %%
import os
import errno
import argparse

import numpy as np
from tensorflow.python.keras.optimizers import SGD
from tensorflow.python.keras import backend as K

from deepcell import get_data
from deepcell import make_training_data
from deepcell import rate_scheduler
from deepcell.model_zoo import bn_feature_net_3D
from deepcell.model_zoo import bn_feature_net_61x61_3D
from deepcell.model_zoo import bn_feature_net_skip_3D
from deepcell.training import train_model_conv
from deepcell.training import train_model_sample
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Load the Training Data

# %%
RESIZE = False
RESHAPE_SIZE = 256
NUM_FRAMES = 15  # get first N frames from each training folder

WIN_X = 30
WIN_Y = 30
WIN_Z = 2

# filepath constants
DATA_DIR = '/data/data'
MODEL_DIR = '/data/models'
NPZ_DIR = '/data/npz_data'
RESULTS_DIR = '/data/results'
EXPORT_DIR = '/data/exports'
PREFIX = 'cells/MouseBrain/generic'
DATA_FILE = 'MouseBrain_3d_{}'.format(K.image_data_format())

# Check for channels_first or channels_last
IS_CHANNELS_FIRST = K.image_data_format() == 'channels_first'

ROW_AXIS = 3 if IS_CHANNELS_FIRST else 2
COL_AXIS = 4 if IS_CHANNELS_FIRST else 3
CHANNEL_AXIS = 1 if IS_CHANNELS_FIRST else 4

# create these directories if they do not exist
for d in (NPZ_DIR, MODEL_DIR, RESULTS_DIR):
    try:
        os.makedirs(os.path.join(d, PREFIX))
        print('Created new directory:', os.path.join(d, PREFIX))
    except OSError as exc:  # Guard against race condition
        if exc.errno != errno.EEXIST:
            raise

# %%
# Create the training data
make_training_data(
    dimensionality=3,
    direc_name=os.path.join(DATA_DIR, PREFIX),
    file_name_save=os.path.join(NPZ_DIR, PREFIX, DATA_FILE),
    channel_names=[''],  # for iterating over stacks of images from a montage
    training_direcs=None,  # all training directories
    reshape_size=None if not RESIZE else RESHAPE_SIZE,
    num_frames=NUM_FRAMES,
    montage_mode=True,  # annotation folder has montaged sub-dirs
    annotation_name='',  # basically channel name but for annotated images
    raw_image_direc='stacked_raw_parts',
    annotation_direc='annotated/all_montages')

if os.path.isfile(os.path.join(NPZ_DIR, PREFIX, DATA_FILE) + '.npz'):
    print('\nData saved to', os.path.join(NPZ_DIR, PREFIX, DATA_FILE) + '.npz')
else:
    raise Exception('Uh Oh!  Your data file did not save properly :(')
# Out:
# Data saved to /data/npz_data/cells/MouseBrain/generic/MouseBrain_3d_channels_last.npz

# %% [markdown]
# ## Fully Convolutional Training

# %%
# Load the training data from NPZ into a numpy array
training_data = np.load(os.path.join(NPZ_DIR, PREFIX, DATA_FILE + '.npz'))

X, y = training_data['X'], training_data['y']
print('X.shape: {}\ny.shape: {}'.format(X.shape, y.shape))

# Set up training parameters
n_epoch = 8
batch_size = 1
frames_per_batch = 3
optimizer = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
lr_sched = rate_scheduler(lr=0.01, decay=0.95)

# save the size of the input data for batch_shape model parameter
size = (RESHAPE_SIZE, RESHAPE_SIZE) if RESIZE else X.shape[ROW_AXIS:COL_AXIS + 1]
if IS_CHANNELS_FIRST:
    input_shape = (X.shape[CHANNEL_AXIS], frames_per_batch, size[0], size[1])
else:
    input_shape = (frames_per_batch, size[0], size[1], X.shape[CHANNEL_AXIS])
# Out:
# X.shape: (220, 15, 256, 256, 1)
# y.shape: (220, 15, 256, 256, 1)

# %%
# Instantiate the model
conv_model = bn_feature_net_skip_3D(
    n_features=3,  # (cell edge, cell interior, background)
    n_frames=frames_per_batch,
    input_shape=input_shape,
    norm_method='whole_image')

# Train the model
train_model_conv(
    model=conv_model,
    dataset=DATA_FILE,
    expt='conv',
    optimizer=optimizer,
    transform='deepcell',
    dilation_radius=None,
    batch_size=batch_size,
    frames_per_batch=frames_per_batch,
    n_epoch=n_epoch,
    direc_save=os.path.join(MODEL_DIR, PREFIX),
    direc_data=os.path.join(NPZ_DIR, PREFIX),
    lr_sched=rate_scheduler(lr=0.01, decay=0.95),
    rotation_range=180,
    flip=True,
    shear=False)
# Out:
# X_train shape: (198, 15, 256, 256, 1)
# y_train shape: (198, 15, 256, 256, 1)
# X_test shape: (22, 15, 256, 256, 1)
# y_test shape: (22, 15, 256, 256, 1)
# Output Shape: (None, 3, 256, 256, 3)
# Number of Classes: 3
# Epoch 1/8
# 197/198 [============================>.] - ETA: 0s - loss: 0.6899 - acc: 0.8444
# Epoch 00001: val_loss improved from inf to 0.90117, saving model to /data/models/cells/MouseBrain/generic/2018-08-31_MouseBrain_3d_channels_last_conv.h5
# 198/198 [==============================] - 235s 1s/step - loss: 0.6893 - acc: 0.8446 - val_loss: 0.9012 - val_acc: 0.8875
# Epoch 2/8
# 197/198 [============================>.] - ETA: 0s - loss: 0.5958 - acc: 0.8615
# Epoch 00002: val_loss improved from 0.90117 to 0.62495, saving model to /data/models/cells/MouseBrain/generic/2018-08-31_MouseBrain_3d_channels_last_conv.h5
# 198/198 [==============================] - 196s 990ms/step - loss: 0.5957 - acc: 0.8615 - val_loss: 0.6249 - val_acc: 0.8235
# Epoch 3/8
# 197/198 [============================>.] - ETA: 0s - loss: 0.5903 - acc: 0.8623
# Epoch 00003: val_loss improved from 0.62495 to 0.61653, saving model to /data/models/cells/MouseBrain/generic/2018-08-31_MouseBrain_3d_channels_last_conv.h5
# 198/198 [==============================] - 196s 991ms/step - loss: 0.5898 - acc: 0.8623 - val_loss: 0.6165 - val_acc: 0.8940
# Epoch 4/8
# 197/198 [============================>.] - ETA: 0s - loss: 0.5930 - acc: 0.8643
# Epoch 00004: val_loss improved from 0.61653 to 0.58642, saving model to /data/models/cells/MouseBrain/generic/2018-08-31_MouseBrain_3d_channels_last_conv.h5
# 198/198 [==============================] - 196s 990ms/step - loss: 0.5928 - acc: 0.8642 - val_loss: 0.5864 - val_acc: 0.8935
# Epoch 5/8
# 197/198 [============================>.] - ETA: 0s - loss: 0.5807 - acc: 0.8652
# Epoch 00005: val_loss did not improve
# 198/198 [==============================] - 196s 991ms/step - loss: 0.5804 - acc: 0.8654 - val_loss: 0.6693 - val_acc: 0.8710
# Epoch 6/8
# 197/198 [============================>.] - ETA: 0s - loss: 0.5683 - acc: 0.8705
# Epoch 00006: val_loss improved from 0.58642 to 0.56613, saving model to /data/models/cells/MouseBrain/generic/2018-08-31_MouseBrain_3d_channels_last_conv.h5
# 198/198 [==============================] - 196s 991ms/step - loss: 0.5682 - acc: 0.8705 - val_loss: 0.5661 - val_acc: 0.8712
# Epoch 7/8
# 197/198 [============================>.] - ETA: 0s - loss: 0.5568 - acc: 0.8720
# Epoch 00007: val_loss did not improve
# 198/198 [==============================] - 196s 990ms/step - loss: 0.5571 - acc: 0.8720 - val_loss: 0.5721 - val_acc: 0.8832
# Epoch 8/8
# 197/198 [============================>.] - ETA: 0s - loss: 0.5674 - acc: 0.8698
# Epoch 00008: val_loss did not improve
# 198/198 [==============================] - 196s 990ms/step - loss: 0.5674 - acc: 0.8698 - val_loss: 0.5785 - val_acc: 0.8744

# %%
# With the trained model, make predictions on testing data
training_data_file = os.path.join(NPZ_DIR, PREFIX, DATA_FILE + '.npz')

train_dict, test_dict = get_data(training_data_file, mode='conv', seed=21)

# too many batches at once causes OOM
X_test, y_test = test_dict['X'][:4], test_dict['y'][:4]

# To predict on variable number of frames
# we need to re-instantiate model and load weights
conv_weights_file = '2018-08-31_MouseBrain_3d_channels_last_conv.h5'
conv_weights_file = os.path.join(MODEL_DIR, PREFIX, conv_weights_file)

run_conv_model = bn_feature_net_skip_3D(
    n_features=3,
    n_frames=frames_per_batch,
    input_shape=X_test.shape[1:],
    norm_method='whole_image')
run_conv_model.load_weights(conv_weights_file)

test_images_conv = run_conv_model.predict(X_test)

# %%
# Plot the results
import matplotlib.pyplot as plt
import matplotlib.animation as animation

index = 0
frame = 3

fig, axes = plt.subplots(ncols=3, nrows=1, figsize=(15, 15), sharex=True, sharey=True)
ax = axes.ravel()

ax[0].imshow(X_test[index, frame, :, :, 0])
ax[0].set_title('Source Image')

ax[1].imshow(test_images_conv[index, frame, :, :, 0])
ax[1].set_title('Edge Prediction')

ax[2].imshow(test_images_conv[index, frame, :, :, 1], cmap='jet')
ax[2].set_title('Interior Prediction')

fig.tight_layout()
plt.show()

# %%
from deepcell.utils.plot_utils import get_js_video
from IPython.display import HTML

HTML(get_js_video(test_images_conv, batch=0, channel=1))
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img5d5c9b57acd94cad909b45afabd2210e">
#     <br>
#     <input id="_anim_slider5d5c9b57acd94cad909b45afabd2210e" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim5d5c9b57acd94cad909b45afabd2210e.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim5d5c9b57acd94cad909b45afabd2210e.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim5d5c9b57acd94cad909b45afabd2210e.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim5d5c9b57acd94cad909b45afabd2210e.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim5d5c9b57acd94cad909b45afabd2210e.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim5d5c9b57acd94cad909b45afabd2210e.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim5d5c9b57acd94cad909b45afabd2210e.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim5d5c9b57acd94cad909b45afabd2210e.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim5d5c9b57acd94cad909b45afabd2210e.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim5d5c9b57acd94cad909b45afabd2210e.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select5d5c9b57acd94cad909b45afabd2210e" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img5d5c9b57acd94cad909b45afabd2210e";
#     var slider_id = "_anim_slider5d5c9b57acd94cad909b45afabd2210e";
#     var loop_select_id = "_anim_loop_select5d5c9b57acd94cad909b45afabd2210e";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvhp/UCwAAIABJREFUeJzsvX90G9eV5/mBAYgkSIAIQREUf0iQ\
# RFqyfjiMTUeOLdtKW47TSmLHu0lsp6fjxJ1WOjM5PdPTvXu6T/ps4p2d0+7Z+ZGzJ70nrZOctHvS\
# +eHJru2etNtOKx05lj2SlrbpSNEPk7Iok6JIiqRBEiRBARD3j1sP9VAqgKBEiiD5PueUUCgUql6h\
# qPute99993lmZ2dnMRgMBoNhmXHTUjfAYDAYDIZrwQiYwWAwGJYlRsAMBoPBsCwxAmYwGAyGZYkR\
# MIPBYDAsS4yAGQwGg2FZYgTMYDAYDMsSI2AGg8FgWJYYATMYDAbDssQImMFgMBiWJUbADAaDwbAs\
# MQJmMBgMhmWJETCDwWAwLEuMgBkMBoNhWWIEzGAwGAzLEiNgBoPBYFiWGAEzGAwGw7LECJjBYDAY\
# liVGwAwGg8GwLDECZjAYDIZliREwg8FgMCxLjIAZDAaDYVliBMxgMBgMyxIjYAaDwWBYlhgBMxgM\
# BsOyxAiYwWAwGJYlRsAMBoPBsCwxAmYwGAyGZYkRMIPBYDAsS4yAGQwGg2FZYgSsBHnppZfYsmUL\
# LS0tPP3000vdHIPBYChJPLOzs7NL3QiDTSaT4eabb+af/umfaGpq4o477uBHP/oR27ZtW+qmGQwG\
# Q0lhPLAS49ixY7S0tLBp0ybWrFnDY489xgsvvLDUzTIYDIaSwwhYiXHhwgWam5uz75uamrhw4cIS\
# tshgMBhKE99SN8BwbRw4cIADBw4AcPqtN9haAZQBaSAIhIAkMAvcBGMfCDJBkAxehlO1MH4TjAIp\
# a5/LwJUZ4AqwxjrLhPXhLOCxPsNaV9u91va0nIibrM/T1na3CPW1RK09Luvq+WtWW67nHIbFw3n/\
# 1OJFzJAfCMhqENZsSuIlwxpmKGeGMapJXgjAGDANMAXMIPc5ZR3Xec+L+Rso9u8kzuzsVJH7Gm4U\
# RsBKjMbGRnp7e7Pv+/r6aGxsvGq//fv3s3//fgDaqzx0NAOTQCtwC7ATSFg7b4IXHvkIz/Fp3mEL\
# w+fvge/6oQPoA2qtfTuB9AgQQYzCQWAEEaMUUGMdcNp6rQCiiPFJWdsHrffjiAD6tO+ntStIMT/8\
# 2nqFtr5QxzcsLur+KbFSr+ppKwbcKn+LbXD5P0JV7BJbKk+ymbO8zl2c//2tcAQ4MQUcR/54p4Eh\
# 7Twp7L9H/e8hH8X+nRwocj/DjcQIWIlxxx130NXVxblz52hsbOTHP/4xP/zhD+f+4ihQCfQjD6an\
# EA0JAXfCw60/Z2pHBbWM0Luhmb6WVjEWfUAb8DPgBJAOQRXQ5Ie+35b1AYBB2BEVoYtZSxNiI7Za\
# 653WcXqshSnggtWQIUQMR7EFsFjj4Xe8T7msO42VHyNipYQSlrS1VFjv1d/CKDAOAyH5O/o2JNJr\
# OXbnfRzbexd0+OEw0A3ykNSH/E05/xaKES3DSsEIWInh8/n49re/zYMPPkgmk+HJJ59k+/btBb+T\
# noSTkxD1gt8HoVGgDhEyS9RmGyDANBVM0UA/fVWWgIURW1CFvI/7RZz6kL8OH/A1YDgKfw63bH+T\
# c2MxPlTdSR2DBEnwBrezhstwP7y9+075zkHgYAA6W2F4Cvupe5riPSWncOX9BVy2GfEqPZSIKaax\
# TdCItVRAwi8i5kPC4H1+GEaW9CzyUDSBLVjOe53GmLbVgbnLJci+ffvYt29f0ftPIQ+m5zMQzEDN\
# EMQmIVCJRP3S4DkF8bvDjFDLDGXQgnhJ3UgocUD2I4GIVxpIzELcI2GbHRLS+TBH+ZfV/zdtvMU0\
# AfaMHeaH1Z9jkDpe5V4mdgXZya95/fa7ubRnvZzjuwE4dCukBxFvTBmYYjwxFSJ0Y

# %% [markdown]
# # Sample Based Training

# %%
# Load the training data from NPZ into a numpy array
training_data = np.load(os.path.join(NPZ_DIR, PREFIX, DATA_FILE + '.npz'))

X, y = training_data['X'], training_data['y']
print('X.shape: {}\ny.shape: {}'.format(X.shape, y.shape))

# Set up training parameters
n_epoch = 3
batch_size = 128
optimizer = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
lr_sched = rate_scheduler(lr=0.01, decay=0.99)
# Out:
# X.shape: (220, 15, 256, 256, 1)
# y.shape: (220, 15, 256, 256, 1)

# %%
# First, create a foreground/background separation model

# Instantiate the model
sample_model = bn_feature_net_61x61_3D(
    n_features=3,  # (cell edge, cell interior, background)
    n_frames=2 * WIN_Z + 1,
    norm_method='whole_image',
    n_channels=X.shape[CHANNEL_AXIS])

# Train the model
train_model_sample(
    model=sample_model,
    expt='sample',
    dataset=DATA_FILE,
    optimizer=optimizer,
    batch_size=batch_size,
    transform='deepcell',
    dilation_radius=None,
    window_size=(WIN_X, WIN_Y, WIN_Z),
    balance_classes=True,
    max_class_samples=1e5,
    n_epoch=n_epoch,
    direc_save=os.path.join(MODEL_DIR, PREFIX),
    direc_data=os.path.join(NPZ_DIR, PREFIX),
    lr_sched=lr_sched,
    rotation_range=180,
    flip=True,
    shear=False)
# Out:
# X_train shape: (198, 15, 256, 256, 1)
# y_train shape: (198, 15, 256, 256, 1)
# X_test shape: (22, 15, 256, 256, 1)
# y_test shape: (22, 15, 256, 256, 1)
# Output Shape: (None, 3)
# Number of Classes: 3
# Epoch 1/3
# 2337/2338 [============================>.] - ETA: 0s - loss: 0.5594 - acc: 0.7506
# Epoch 00001: val_loss improved from inf to 0.53381, saving model to /data/models/cells/MouseBrain/generic/2018-08-31_MouseBrain_3d_channels_last_sample.h5
# 2338/2338 [==============================] - 666s 285ms/step - loss: 0.5594 - acc: 0.7505 - val_loss: 0.5338 - val_acc: 0.7674
# Epoch 2/3
# 2337/2338 [============================>.] - ETA: 0s - loss: 0.5352 - acc: 0.7628
# Epoch 00002: val_loss improved from 0.53381 to 0.51607, saving model to /data/models/cells/MouseBrain/generic/2018-08-31_MouseBrain_3d_channels_last_sample.h5
# 2338/2338 [==============================] - 663s 283ms/step - loss: 0.5353 - acc: 0.7628 - val_loss: 0.5161 - val_acc: 0.7758
# Epoch 3/3
# 2337/2338 [============================>.] - ETA: 0s - loss: 0.5285 - acc: 0.7663
# Epoch 00003: val_loss did not improve
# 2338/2338 [==============================] - 665s 284ms/step - loss: 0.5285 - acc: 0.7663 - val_loss: 0.5261 - val_acc: 0.7750

# %%
# With the trained model, make predictions on testing data
training_data_file = os.path.join(NPZ_DIR, PREFIX, DATA_FILE + '.npz')

train_dict, test_dict = get_data(training_data_file, mode='conv', seed=21)

# too many batches at once causes OOM
X_test, y_test = test_dict['X'][:4], test_dict['y'][:4]

# To predict on variable number of frames
# we need to re-instantiate model and load weights
sample_weights_file = '2018-08-31_MouseBrain_3d_channels_last_sample.h5'
sample_weights_file = os.path.join(MODEL_DIR, PREFIX, sample_weights_file)

run_sample_model = bn_feature_net_61x61_3D(
    n_features=3,
    dilated=True,
    n_frames=2 * WIN_Z + 1,
    input_shape=X_test.shape[1:],
    norm_method='whole_image')
run_sample_model.load_weights(sample_weights_file)

test_images_sample = run_sample_model.predict(X_test)

# %%
# Plot the results
import matplotlib.pyplot as plt
import matplotlib.animation as animation

index = 0
frame = 5

fig, axes = plt.subplots(ncols=3, nrows=1, figsize=(15, 15), sharex=True, sharey=True)
ax = axes.ravel()

ax[0].imshow(X_test[index, frame, :, :, 0])
ax[0].set_title('Source Image')

ax[1].imshow(test_images_sample[index, frame, :, :, 0])
ax[1].set_title('Edge Prediction')

ax[2].imshow(test_images_sample[index, frame, :, :, 1], cmap='jet')
ax[2].set_title('Interior Prediction')

fig.tight_layout()
plt.show()

# %%
from deepcell.utils.plot_utils import get_js_video
from IPython.display import HTML

HTML(get_js_video(test_images_sample, batch=0, channel=1))
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img14f6dda2c3394963bc4382994ca91405">
#     <br>
#     <input id="_anim_slider14f6dda2c3394963bc4382994ca91405" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim14f6dda2c3394963bc4382994ca91405.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim14f6dda2c3394963bc4382994ca91405.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim14f6dda2c3394963bc4382994ca91405.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim14f6dda2c3394963bc4382994ca91405.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim14f6dda2c3394963bc4382994ca91405.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim14f6dda2c3394963bc4382994ca91405.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim14f6dda2c3394963bc4382994ca91405.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim14f6dda2c3394963bc4382994ca91405.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim14f6dda2c3394963bc4382994ca91405.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim14f6dda2c3394963bc4382994ca91405.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select14f6dda2c3394963bc4382994ca91405" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img14f6dda2c3394963bc4382994ca91405";
#     var slider_id = "_anim_slider14f6dda2c3394963bc4382994ca91405";
#     var loop_select_id = "_anim_loop_select14f6dda2c3394963bc4382994ca91405";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvhp/UCwAAIABJREFUeJzsvW1wY9d55/mDAJAESJAQQRFsvqjZ\
# 3aSaYndLVES5VbJjaSP5pbReOZ6dcuxUNvY4m045VZuaVKq2XOX9EH/ZKFOV2i/OVqVrXYm8s7HG\
# O7OJUllHduKJPHY0aq1eKHe7X0y2GhLYbJJNUiABkiAJNPfDuQf38PS9wMUbCaLPvwp1gftyzrkv\
# eP73eZ7/Oce3u7u7i4GBgYGBwSHDfQfdAAMDAwMDg0pgCMzAwMDA4FDCEJiBgYGBwaGEITADAwMD\
# g0MJQ2AGBgYGBocShsAMDAwMDA4lDIEZGBgYGBxKGAIzMDAwMDiUMARmYGBgYHAoYQjMwMDAwOBQ\
# whCYgYGBgcGhhCEwAwMDA4NDCUNgBgYGBgaHEobADAwMDAwOJQyBGRgYGBgcShgCMzAwMDA4lDAE\
# ZmBgYGBwKGEIzMDAwMDgUMIQmIGBgYHBoYQhMAMDAwODQwlDYAYGBgYGhxKGwAwMDAwMDiUMgRkY\
# GBgYHEoYAjMwMDAwOJQwBGZgYGBgcChhCMzAwMDA4FDCEJiBgYGBwaGEITADAwMDg0MJQ2AGBgYG\
# BocShsAMDAwMDA4lDIE1IF599VVOnjzJyMgIL7744kE3x8DAwKAh4dvd3d096EYY2Mjn8zz00EP8\
# 4z/+I4ODgzzxxBN873vfY3x8/KCbZmBgYNBQMB5Yg+HNN99kZGSE48eP09LSwpe+9CVeeeWVg26W\
# gYGBQcPBEFiD4ebNmwwNDRV+Dw4OcvPmzQNskYGBgUFjInDQDTCoDOfPn+f8+fMAXL3yNmPDwA6Q\
# BfLALuAHwrAbhjV/hB2C5AiQpY0UUfJLQUgDOWv/EBCF7sgSm4TY3AlB/j7YAlaBFatsH+LJuQO0\
# Am2IV6E2UR9ZoB1xXNA6JrQLaZ8oJ2/tcx+wbZVzH3Anb52EPIEta+Ou9fFZy2Jw2l7sGC9l6vs3\
# AuT1KLYdh33U4/Yze+DW1vsQD+p9FB6m1vvgAaB7l/v8ee5sBcTzsgxkEI8HdxAP7jbimbmD/dzI\
# +tTzq/ZcP2J3d73KMgxqDUNgDYaBgQGSyWTh9+zsLAMDA3ftd+7cOc6dOwfAY5P38db/sSvI4Sri\
# z34F6EeQylm4+XSQd5kgQJ53eYy/5je59K0nYAZIALPAJPAcnP29/4dlYgC8+cFTcCkI/wS8rDSg\
# wyp7EHgS8SQ9CW2TK2xnW7mTaqdreJ7V+RjMB0W7LgGvWscFEHUv7QKbcCdoNXpH/CYHTFtLuS7o\
# 4QruOKzLFdk/UGK7ut9BIqe1Qf9dbdn1Qqk2hqxPJzAMfAwe8MFvAZ+DOznsZ3QKeA3IbCDevJaB\
# RcTDu4n93DjB6bkoBlmOfD7+9zKPN9gPHPS/0kDDE088wfT0NDdu3GBgYICXX36Zv/7rvy56jH9l\
# V3hHGWvFFoIkVhD/70XgaYiQ4QIf43We4tJLT8BfAT3APJCylgn4hz/9VxBFEFN0R2yLIoxK1qpj\
# 0KpjEr748Zc4w0XiLLBAnHyXn1Q8SpIhlo72MNU3wWq2Txw7jLAHb8j2phHG6zKCsIIIQ6QaHGlM\
# NrEfWZXM3IxTKeLSv9fTkJcDN3KS63PKb1z2LRe1ugY6yTp9V7FpLeV9T8DsMLzsE7w0iCCwGcQL\
# UG4ZWMAmrDX2kpf6LHh54XGCl3YbNAIMgTUYAoEA3/72t/nMZz5DPp/na1/7GqdOnSp+0BbwvvVd\
# LnPYob8hyOEnj58wm2zTAn3Y5DVrHbNkfaIIckkBqaDYpwObILOIN+JBIABz9NPCNmkihNlgjn6i\
# pAixSR4/+ZxfkN2MVdclILeGbXykQQoiWHcH23DsaL9V417qrdqrd1Xp/pXCqY5Sd
