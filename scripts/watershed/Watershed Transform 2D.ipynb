# %% [markdown]
# # Watershed distance transform with foreground and background separation
# ---
# Implementation of papers:
#
# [Deep Watershed Transform for Instance Segmentation](http://openaccess.thecvf.com/content_cvpr_2017/papers/Bai_Deep_Watershed_Transform_CVPR_2017_paper.pdf)
#
# [Learn to segment single cells with deep distance estimator and deep cell detector](https://arxiv.org/abs/1803.10829)

# %%
import os
import errno

import numpy as np
from skimage.external import tifffile as tiff
from tensorflow.python.keras.optimizers import SGD, Adam
from tensorflow.python.keras import backend as K

from deepcell import get_data
from deepcell import make_training_data
from deepcell import rate_scheduler
from deepcell.model_zoo import bn_feature_net_61x61
from deepcell.model_zoo import bn_feature_net_2D
from deepcell.model_zoo import bn_feature_net_skip_2D

from deepcell.training import train_model_conv
from deepcell.training import train_model_sample
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Load the Training Data

# %%
RESIZE = True
RESHAPE_SIZE = 256
BINS = 4
EROSION = 0

# filepath constants
DATA_DIR = '/data/data'
MODEL_DIR = '/data/models'
NPZ_DIR = '/data/npz_data'
RESULTS_DIR = '/data/results'
EXPORT_DIR = '/data/exports'
PREFIX = 'cells/unspecified_nuclear_data/nuclei_broad'
DATA_FILE = 'nuclei_broad_watershed'

# Check for channels_first or channels_last
IS_CHANNELS_FIRST = K.image_data_format() == 'channels_first'

ROW_AXIS = 2 if IS_CHANNELS_FIRST else 1
COL_AXIS = 3 if IS_CHANNELS_FIRST else 2
CHANNEL_AXIS = 1 if IS_CHANNELS_FIRST else -1

WIN_X = 30
WIN_Y = 30

# create these directories if they do not exist
for d in (NPZ_DIR, MODEL_DIR, RESULTS_DIR):
    try:
        os.makedirs(os.path.join(d, PREFIX))
        print('Created new directory:', os.path.join(d, PREFIX))
    except OSError as exc: # Guard against race condition
        if exc.errno != errno.EEXIST:
            raise

# %%
# Make the training data for watershed distance transform
make_training_data(
    direc_name=os.path.join(DATA_DIR, PREFIX),
    dimensionality=2,
    file_name_save=os.path.join(NPZ_DIR, PREFIX, DATA_FILE),
    training_direcs=['set1', 'set2', 'set3', 'set4', 'set5'],
    channel_names=['nuclear'],
    num_of_features=BINS,
    raw_image_direc='processed',
    annotation_direc='annotated',
    reshape_size=RESHAPE_SIZE if RESIZE else None)

if os.path.isfile(os.path.join(NPZ_DIR, PREFIX, DATA_FILE) + '.npz'):
    print('Data Saved to', os.path.join(NPZ_DIR, PREFIX, DATA_FILE) + '.npz')
else:
    raise Exception('Uh Oh!  Your data file did not save properly :(')
# Out:
# Reshaped feature data from (5, 520, 696, 1) to (45, 256, 256, 1)
# Reshaped training data from (5, 520, 696, 1) to (45, 256, 256, 1)
# Data Saved to /data/npz_data/cells/unspecified_nuclear_data/nuclei_broad/nuclei_broad_watershed.npz

# %% [markdown]
# ## Conv Based Training

# %%
# Load the training data from NPZ into a numpy array
training_data = np.load(os.path.join(NPZ_DIR, PREFIX, DATA_FILE + '.npz'))

X, y = training_data['X'], training_data['y']
print('X.shape: {}\ny.shape: {}'.format(X.shape, y.shape))

# save the size of the input data for input_shape model parameter
size = (RESHAPE_SIZE, RESHAPE_SIZE) if RESIZE else X.shape[ROW_AXIS:COL_AXIS + 1]
if IS_CHANNELS_FIRST:
    input_shape = (X.shape[CHANNEL_AXIS], size[0], size[1])
else:
    input_shape = (size[0], size[1], X.shape[CHANNEL_AXIS])
    
# Set up other training parameters
n_epoch = 10
batch_size = 1
optimizer = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
lr_sched = rate_scheduler(lr=0.01, decay=0.99)
# Out:
# X.shape: (45, 256, 256, 1)
# y.shape: (45, 256, 256, 1)

# %%
# First, create a foreground/background separation model

# Instantiate the model
fgbg_model = bn_feature_net_skip_2D(
    receptive_field=61,
    n_skips=2,
    n_features=2,  # segmentation mask (is_cell, is_not_cell)
    n_conv_filters=32,
    n_dense_filters=128,
    input_shape=input_shape,
    multires=False,
    last_only=False)

# Train the model
train_model_conv(
    model=fgbg_model,
    dataset=DATA_FILE,
    optimizer=optimizer,
    batch_size=batch_size,
    transform=None,  # fg/bg separation
    n_epoch=n_epoch,
    direc_save=os.path.join(MODEL_DIR, PREFIX),
    direc_data=os.path.join(NPZ_DIR, PREFIX),
    expt='conv_fgbg',
    lr_sched=lr_sched,
    skip=2,
    rotation_range=180,
    flip=True,
    shear=False)
# Out:
# X_train shape: (40, 256, 256, 1)
# y_train shape: (40, 256, 256, 1)
# X_test shape: (5, 256, 256, 1)
# y_test shape: (5, 256, 256, 1)
# Output Shape: (None, 256, 256, 2)
# Number of Classes: 2
# Epoch 1/10
# 39/40 [============================>.] - ETA: 0s - loss: 0.4825 - model_1_loss: 0.1453 - model_2_loss: 0.1748 - model_3_loss: 0.1415 - model_1_acc: 0.8882 - model_2_acc: 0.8838 - model_3_acc: 0.8819
# Epoch 00001: val_loss improved from inf to 0.88863, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-08-31_nuclei_broad_watershed_conv_fgbg.h5
# 40/40 [==============================] - 11s 276ms/step - loss: 0.4757 - model_1_loss: 0.1427 - model_2_loss: 0.1722 - model_3_loss: 0.1399 - model_1_acc: 0.8891 - model_2_acc: 0.8843 - model_3_acc: 0.8823 - val_loss: 0.8886 - val_model_1_loss: 0.3063 - val_model_2_loss: 0.2858 - val_model_3_loss: 0.2756 - val_model_1_acc: 0.9584 - val_model_2_acc: 0.8794 - val_model_3_acc: 0.8689
# Epoch 2/10
# 39/40 [============================>.] - ETA: 0s - loss: 0.1615 - model_1_loss: 0.0431 - model_2_loss: 0.0473 - model_3_loss: 0.0501 - model_1_acc: 0.9396 - model_2_acc: 0.9391 - model_3_acc: 0.9381
# Epoch 00002: val_loss improved from 0.88863 to 0.42343, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-08-31_nuclei_broad_watershed_conv_fgbg.h5
# 40/40 [==============================] - 6s 147ms/step - loss: 0.1606 - model_1_loss: 0.0428 - model_2_loss: 0.0470 - model_3_loss: 0.0498 - model_1_acc: 0.9399 - model_2_acc: 0.9393 - model_3_acc: 0.9382 - val_loss: 0.4234 - val_model_1_loss: 0.1394 - val_model_2_loss: 0.1377 - val_model_3_loss: 0.1254 - val_model_1_acc: 0.9512 - val_model_2_acc: 0.9422 - val_model_3_acc: 0.9430
# Epoch 3/10
# 39/40 [============================>.] - ETA: 0s - loss: 0.1237 - model_1_loss: 0.0322 - model_2_loss: 0.0346 - model_3_loss: 0.0359 - model_1_acc: 0.9422 - model_2_acc: 0.9437 - model_3_acc: 0.9429
# Epoch 00003: val_loss improved from 0.42343 to 0.33110, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-08-31_nuclei_broad_watershed_conv_fgbg.h5
# 40/40 [==============================] - 6s 149ms/step - loss: 0.1222 - model_1_loss: 0.0317 - model_2_loss: 0.0341 - model_3_loss: 0.0355 - model_1_acc: 0.9415 - model_2_acc: 0.9430 - model_3_acc: 0.9423 - val_loss: 0.3311 - val_model_1_loss: 0.0999 - val_model_2_loss: 0.1110 - val_model_3_loss: 0.0993 - val_model_1_acc: 0.9531 - val_model_2_acc: 0.9469 - val_model_3_acc: 0.9501
# Epoch 4/10
# 39/40 [============================>.] - ETA: 0s - loss: 0.1063 - model_1_loss: 0.0264 - model_2_loss: 0.0295 - model_3_loss: 0.0295 - model_1_acc: 0.9411 - model_2_acc: 0.9407 - model_3_acc: 0.9407
# Epoch 00004: val_loss improved from 0.33110 to 0.24077, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-08-31_nuclei_broad_watershed_conv_fgbg.h5
# 40/40 [==============================] - 6s 148ms/step - loss: 0.1051 - model_1_loss: 0.0260 - model_2_loss: 0.0290 - model_3_loss: 0.0291 - model_1_acc: 0.9417 - model_2_acc: 0.9413 - model_3_acc: 0.9414 - val_loss: 0.2408 - val_model_1_loss: 0.0702 - val_model_2_loss: 0.0735 - val_model_3_loss: 0.0761 - val_model_1_acc: 0.9792 - val_model_2_acc: 0.9709 - val_model_3_acc: 0.9647
# Epoch 5/10
# 39/40 [============================>.] - ETA: 0s - loss: 0.0954 - model_1_loss: 0.0224 - model_2_loss: 0.0257 - model_3_loss: 0.0263 - model_1_acc: 0.9438 - model_2_acc: 0.9434 - model_3_acc: 0.9419
# Epoch 00005: val_loss improved from 0.24077 to 0.22642, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-08-31_nuclei_broad_watershed_conv_fgbg.h5
# 40/40 [==============================] - 6s 150ms/step - loss: 0.0948 - model_1_loss: 0.0222 - model_2_loss: 0.0255 - model_3_loss: 0.0261 - model_1_acc: 0.9439 - model_2_acc: 0.9433 - model_3_acc: 0.9418 - val_loss: 0.2264 - val_model_1_loss: 0.0781 - val_model_2_loss: 0.0644 - val_model_3_loss: 0.0630 - val_model_1_acc: 0.9824 - val_model_2_acc: 0.9778 - val_model_3_acc: 0.9746
# Epoch 6/10
# 39/40 [============================>.] - ETA: 0s - loss: 0.0905 - model_1_loss: 0.0213 - model_2_loss: 0.0239 - model_3_loss: 0.0243 - model_1_acc: 0.9431 - model_2_acc: 0.9422 - model_3_acc: 0.9421
# Epoch 00006: val_loss improved from 0.22642 to 0.20434, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-08-31_nuclei_broad_watershed_conv_fgbg.h5
# 40/40 [==============================] - 6s 146ms/step - loss: 0.0897 - model_1_loss: 0.0211 - model_2_loss: 0.0237 - model_3_loss: 0.0240 - model_1_acc: 0.9430 - model_2_acc: 0.9420 - model_3_acc: 0.9419 - val_loss: 0.2043 - val_model_1_loss: 0.0651 - val_model_2_loss: 0.0597 - val_model_3_loss: 0.0586 - val_model_1_acc: 0.9826 - val_model_2_acc: 0.9803 - val_model_3_acc: 0.9765
# Epoch 7/10
# 39/40 [============================>.] - ETA: 0s - loss: 0.0868 - model_1_loss: 0.0202 - model_2_loss: 0.0229 - model_3_loss: 0.0227 - model_1_acc: 0.9472 - model_2_acc: 0.9463 - model_3_acc: 0.9464
# Epoch 00007: val_loss improved from 0.20434 to 0.18492, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-08-31_nuclei_broad_watershed_conv_fgbg.h5
# 40/40 [==============================] - 6s 149ms/step - loss: 0.0874 - model_1_loss: 0.0205 - model_2_loss: 0.0232 - model_3_loss: 0.0228 - model_1_acc: 0.9463 - model_2_acc: 0.9456 - model_3_acc: 0.9456 - val_loss: 0.1849 - val_model_1_loss: 0.0532 - val_model_2_loss: 0.0554 - val_model_3_loss: 0.0553 - val_model_1_acc: 0.9786 - val_model_2_acc: 0.9800 - val_model_3_acc: 0.9794
# Epoch 8/10
# 39/40 [============================>.] - ETA: 0s - loss: 0.0836 - model_1_loss: 0.0196 - model_2_loss: 0.0217 - model_3_loss: 0.0214 - model_1_acc: 0.9401 - model_2_acc: 0.9391 - model_3_acc: 0.9390
# Epoch 00008: val_loss did not improve
# 40/40 [==============================] - 6s 145ms/step - loss: 0.0842 - model_1_loss: 0.0198 - model_2_loss: 0.0219 - model_3_loss: 0.0216 - model_1_acc: 0.9403 - model_2_acc: 0.9393 - model_3_acc: 0.9393 - val_loss: 0.2265 - val_model_1_loss: 0.0817 - val_model_2_loss: 0.0643 - val_model_3_loss: 0.0596 - val_model_1_acc: 0.9836 - val_model_2_acc: 0.9836 - val_model_3_acc: 0.9827
# Epoch 9/10
# 39/40 [============================>.] - ETA: 0s - loss: 0.0838 - model_1_loss: 0.0197 - model_2_loss: 0.0220 - model_3_loss: 0.0212 - model_1_acc: 0.9446 - model_2_acc: 0.9435 - model_3_acc: 0.9436
# Epoch 00009: val_loss did not improve
# 40/40 [==============================] - 6s 146ms/step - loss: 0.0828 - model_1_loss: 0.0193 - model_2_loss: 0.0216 - model_3_loss: 0.0209 - model_1_acc: 0.9454 - model_2_acc: 0.9443 - model_3_acc: 0.9444 - val_loss: 0.2106 - val_model_1_loss: 0.0744 - val_model_2_loss: 0.0578 - val_model_3_loss: 0.0574 - val_model_1_acc: 0.9837 - val_model_2_acc: 0.9824 - val_model_3_acc: 0.9825
# Epoch 10/10
# 39/40 [============================>.] - ETA: 0s - loss: 0.0811 - model_1_loss: 0.0190 - model_2_loss: 0.0209 - model_3_loss: 0.0203 - model_1_acc: 0.9473 - model_2_acc: 0.9458 - model_3_acc: 0.9446
# Epoch 00010: val_loss did not improve
# 40/40 [==============================] - 6s 145ms/step - loss: 0.0816 - model_1_loss: 0.0192 - model_2_loss: 0.0211 - model_3_loss: 0.0204 - model_1_acc: 0.9462 - model_2_acc: 0.9448 - model_3_acc: 0.9437 - val_loss: 0.2314 - val_model_1_loss: 0.0866 - val_model_2_loss: 0.0700 - val_model_3_loss: 0.0538 - val_model_1_acc: 0.9834 - val_model_2_acc: 0.9839 - val_model_3_acc: 0.9803

# %%
# Next, Create a model for the watershed energy transform

# Instantiate the model
watershed_model = bn_feature_net_skip_2D(
    fgbg_model=fgbg_model,
    receptive_field=61,
    n_skips=2,
    n_features=BINS,
    n_conv_filters=32,
    n_dense_filters=128,
    multires=False,
    last_only=False,
    input_shape=input_shape)

# Train the model
train_model_conv(
    model=watershed_model,
    dataset=DATA_FILE,
    optimizer=optimizer,
    batch_size=batch_size,
    n_epoch=n_epoch,
    skip=2,
    transform='watershed',
    distance_bins=BINS,
    erosion_width=EROSION,
    direc_save=os.path.join(MODEL_DIR, PREFIX),
    direc_data=os.path.join(NPZ_DIR, PREFIX),
    expt='conv_watershed',
    lr_sched=lr_sched,
    rotation_range=180,
    flip=True,
    shear=False)
# Out:
# X_train shape: (40, 256, 256, 1)
# y_train shape: (40, 256, 256, 1)
# X_test shape: (5, 256, 256, 1)
# y_test shape: (5, 256, 256, 1)
# Output Shape: (None, 256, 256, 4)
# Number of Classes: 4
# Epoch 1/10
# 39/40 [============================>.] - ETA: 0s - loss: 2.0145 - model_5_loss: 0.6648 - model_6_loss: 0.6676 - model_7_loss: 0.6402 - model_5_acc: 0.7339 - model_6_acc: 0.7429 - model_7_acc: 0.7451
# Epoch 00001: val_loss improved from inf to 3.65018, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-08-31_nuclei_broad_watershed_conv_watershed.h5
# 40/40 [==============================] - 14s 338ms/step - loss: 1.9948 - model_5_loss: 0.6583 - model_6_loss: 0.6605 - model_7_loss: 0.6341 - model_5_acc: 0.7363 - model_6_acc: 0.7453 - model_7_acc: 0.7474 - val_loss: 3.6502 - val_model_5_loss: 1.6467 - val_model_6_loss: 0.9902 - val_model_7_loss: 0.9713 - val_model_5_acc: 0.6915 - val_model_6_acc: 0.7938 - val_model_7_acc: 0.8106
# Epoch 2/10
# 39/40 [============================>.] - ETA: 0s - loss: 1.1756 - model_5_loss: 0.3821 - model_6_loss: 0.3732 - model_7_loss: 0.3783 - model_5_acc: 0.8715 - model_6_acc: 0.8722 - model_7_acc: 0.8614
# Epoch 00002: val_loss improved from 3.65018 to 2.10250, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-08-31_nuclei_broad_watershed_conv_watershed.h5
# 40/40 [==============================] - 9s 233ms/step - loss: 1.1680 - model_5_loss: 0.3795 - model_6_loss: 0.3711 - model_7_loss: 0.3754 - model_5_acc: 0.8720 - model_6_acc: 0.8726 - model_7_acc: 0.8621 - val_loss: 2.1025 - val_model_5_loss: 0.7183 - val_model_6_loss: 0.6374 - val_model_7_loss: 0.7048 - val_model_5_acc: 0.8075 - val_model_6_acc: 0.8703 - val_model_7_acc: 0.9185
# Epoch 3/10
# 39/40 [============================>.] - ETA: 0s - loss: 0.9835 - model_5_loss: 0.3203 - model_6_loss: 0.3100 - model_7_loss: 0.3112 - model_5_acc: 0.8823 - model_6_acc: 0.8850 - model_7_acc: 0.8791
# Epoch 00003: val_loss improved from 2.10250 to 1.89865, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-08-31_nuclei_broad_watershed_conv_watershed.h5
# 40/40 [==============================] - 9s 232ms/step - loss: 0.9760 - model_5_loss: 0.3174 - model_6_loss: 0.3075 - model_7_loss: 0.3090 - model_5_acc: 0.8827 - model_6_acc: 0.8853 - model_7_acc: 0.8794 - val_loss: 1.8987 - val_model_5_loss: 0.6178 - val_model_6_loss: 0.5929 - val_model_7_loss: 0.6458 - val_model_5_acc: 0.8964 - val_model_6_acc: 0.9176 - val_model_7_acc: 0.9342
# Epoch 4/10
# 39/40 [============================>.] - ETA: 0s - loss: 0.9035 - model_5_loss: 0.2938 - model_6_loss: 0.2851 - model_7_loss: 0.2824 - model_5_acc: 0.8911 - model_6_acc: 0.8923 - model_7_acc: 0.8876
# Epoch 00004: val_loss did not improve
# 40/40 [==============================] - 9s 225ms/step - loss: 0.9143 - model_5_loss: 0.2968 - model_6_loss: 0.2893 - model_7_loss: 0.2861 - model_5_acc: 0.8919 - model_6_acc: 0.8931 - model_7_acc: 0.8876 - val_loss: 2.0058 - val_model_5_loss: 0.8464 - val_model_6_loss: 0.5340 - val_model_7_loss: 0.5834 - val_model_5_acc: 0.8811 - val_model_6_acc: 0.9171 - val_model_7_acc: 0.9431
# Epoch 5/10
# 39/40 [============================>.] - ETA: 0s - loss: 0.8392 - model_5_loss: 0.2734 - model_6_loss: 0.2593 - model_7_loss: 0.2644 - model_5_acc: 0.8917 - model_6_acc: 0.8943 - model_7_acc: 0.8894
# Epoch 00005: val_loss improved from 1.89865 to 1.51530, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-08-31_nuclei_broad_watershed_conv_watershed.h5
# 40/40 [==============================] - 9s 234ms/step - loss: 0.8453 - model_5_loss: 0.2750 - model_6_loss: 0.2614 - model_7_loss: 0.2668 - model_5_acc: 0.8917 - model_6_acc: 0.8941 - model_7_acc: 0.8894 - val_loss: 1.5153 - val_model_5_loss: 0.5585 - val_model_6_loss: 0.4710 - val_model_7_loss: 0.4437 - val_model_5_acc: 0.9207 - val_model_6_acc: 0.9367 - val_model_7_acc: 0.9302
# Epoch 6/10
# 39/40 [============================>.] - ETA: 0s - loss: 0.8128 - model_5_loss: 0.2703 - model_6_loss: 0.2523 - model_7_loss: 0.2481 - model_5_acc: 0.8966 - model_6_acc: 0.8988 - model_7_acc: 0.8945
# Epoch 00006: val_loss improved from 1.51530 to 1.34494, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-08-31_nuclei_broad_watershed_conv_watershed.h5
# 40/40 [==============================] - 9s 231ms/step - loss: 0.8129 - model_5_loss: 0.2701 - model_6_loss: 0.2521 - model_7_loss: 0.2486 - model_5_acc: 0.8971 - model_6_acc: 0.8989 - model_7_acc: 0.8945 - val_loss: 1.3449 - val_model_5_loss: 0.4611 - val_model_6_loss: 0.4251 - val_model_7_loss: 0.4167 - val_model_5_acc: 0.9312 - val_model_6_acc: 0.9381 - val_model_7_acc: 0.9286
# Epoch 7/10
# 39/40 [============================>.] - ETA: 0s - loss: 0.8352 - model_5_loss: 0.2761 - model_6_loss: 0.2614 - model_7_loss: 0.2556 - model_5_acc: 0.8981 - model_6_acc: 0.8994 - model_7_acc: 0.8967
# Epoch 00007: val_loss did not improve
# 40/40 [==============================] - 9s 222ms/step - loss: 0.8241 - model_5_loss: 0.2728 - model_6_loss: 0.2575 - model_7_loss: 0.2517 - model_5_acc: 0.8990 - model_6_acc: 0.9003 - model_7_acc: 0.8974 - val_loss: 1.3584 - val_model_5_loss: 0.4880 - val_model_6_loss: 0.4213 - val_model_7_loss: 0.4070 - val_model_5_acc: 0.9299 - val_model_6_acc: 0.9388 - val_model_7_acc: 0.9440
# Epoch 8/10
# 39/40 [============================>.] - ETA: 0s - loss: 0.7733 - model_5_loss: 0.2582 - model_6_loss: 0.2369 - model_7_loss: 0.2360 - model_5_acc: 0.8996 - model_6_acc: 0.9009 - model_7_acc: 0.8999
# Epoch 00008: val_loss did not improve
# 40/40 [==============================] - 9s 225ms/step - loss: 0.7716 - model_5_loss: 0.2575 - model_6_loss: 0.2362 - model_7_loss: 0.2357 - model_5_acc: 0.8995 - model_6_acc: 0.9009 - model_7_acc: 0.8999 - val_loss: 1.4099 - val_model_5_loss: 0.5282 - val_model_6_loss: 0.4421 - val_model_7_loss: 0.3974 - val_model_5_acc: 0.9264 - val_model_6_acc: 0.9321 - val_model_7_acc: 0.9378
# Epoch 9/10
# 39/40 [============================>.] - ETA: 0s - loss: 0.7594 - model_5_loss: 0.2504 - model_6_loss: 0.2360 - model_7_loss: 0.2308 - model_5_acc: 0.8996 - model_6_acc: 0.9019 - model_7_acc: 0.8997
# Epoch 00009: val_loss improved from 1.34494 to 1.26544, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-08-31_nuclei_broad_watershed_conv_watershed.h5
# 40/40 [==============================] - 9s 232ms/step - loss: 0.7602 - model_5_loss: 0.2511 - model_6_loss: 0.2362 - model_7_loss: 0.2308 - model_5_acc: 0.8991 - model_6_acc: 0.9013 - model_7_acc: 0.8992 - val_loss: 1.2654 - val_model_5_loss: 0.4467 - val_model_6_loss: 0.3892 - val_model_7_loss: 0.3874 - val_model_5_acc: 0.9428 - val_model_6_acc: 0.9461 - val_model_7_acc: 0.9457
# Epoch 10/10
# 39/40 [============================>.] - ETA: 0s - loss: 0.7206 - model_5_loss: 0.2370 - model_6_loss: 0.2219 - model_7_loss: 0.2196 - model_5_acc: 0.9012 - model_6_acc: 0.9037 - model_7_acc: 0.9024
# Epoch 00010: val_loss improved from 1.26544 to 1.23239, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-08-31_nuclei_broad_watershed_conv_watershed.h5
# 40/40 [==============================] - 9s 232ms/step - loss: 0.7172 - model_5_loss: 0.2355 - model_6_loss: 0.2210 - model_7_loss: 0.2185 - model_5_acc: 0.9009 - model_6_acc: 0.9034 - model_7_acc: 0.9022 - val_loss: 1.2324 - val_model_5_loss: 0.4139 - val_model_6_loss: 0.3855 - val_model_7_loss: 0.3908 - val_model_5_acc: 0.9389 - val_model_6_acc: 0.9432 - val_model_7_acc: 0.9365

# %%
# With the trained model, make predictions on testing data
training_data_file = os.path.join(NPZ_DIR, PREFIX, DATA_FILE + '.npz')

train_dict, test_dict = get_data(training_data_file, mode='conv', seed=21)

X_test, y_test = test_dict['X'], test_dict['y']

test_images = watershed_model.predict(X_test)[-1]
test_images_fgbg = fgbg_model.predict(X_test)[-1]

print('watershed transform shape:', test_images.shape)
print('segmentation mask shape:', test_images_fgbg.shape)

argmax_images = []
for i in range(test_images.shape[0]):
    max_image = np.argmax(test_images[i], axis=CHANNEL_AXIS)
    argmax_images.append(max_image)
argmax_images = np.array(argmax_images)
argmax_images = np.expand_dims(argmax_images, axis=CHANNEL_AXIS)

print('watershed argmax shape:', argmax_images.shape)
# Out:
# watershed transform shape: (5, 256, 256, 4)
# segmentation mask shape: (5, 256, 256, 2)
# watershed argmax shape: (5, 256, 256, 1)

# %%
# threshold the foreground/background
# and remove back ground from watershed transform
if IS_CHANNELS_FIRST:
    fg_thresh = test_images_fgbg[:, 1, :, :] > 0.5
else:
    fg_thresh = test_images_fgbg[:, :, :, 1] > 0.5

fg_thresh = np.expand_dims(fg_thresh.astype(np.int16), axis=CHANNEL_AXIS)
argmax_images_post_fgbg = argmax_images * fg_thresh

# %%
# Apply watershed method with the distance transform as seed
from scipy import ndimage
from skimage.morphology import watershed
from skimage.feature import peak_local_max

watershed_images = []
for i in range(argmax_images_post_fgbg.shape[0]):
    if IS_CHANNELS_FIRST:
        image = fg_thresh[i, 0, :, :]
        distance = argmax_images_post_fgbg[i, 0, :, :]
    else:
        image = fg_thresh[i, :, :, 0]
        distance = argmax_images_post_fgbg[i, :, :, 0]

    local_maxi = peak_local_max(test_images[i, :, :, -1], min_distance=15, 
                                exclude_border=False, indices=False, labels=image)

    markers = ndimage.label(local_maxi)[0]
    segments = watershed(-distance, markers, mask=image)
    watershed_images.append(segments)

watershed_images = np.array(watershed_images)
watershed_images = np.expand_dims(watershed_images, axis=CHANNEL_AXIS)

# %% [markdown]
# ## Plot the Results

# %%
import matplotlib.pyplot as plt

index = 0

fig, axes = plt.subplots(ncols=3, nrows=2, figsize=(15, 15), sharex=True, sharey=True)
ax = axes.ravel()

ax[0].imshow(X_test[index, :, :, 0])
ax[0].set_title('Source Image')

ax[1].imshow(test_images_fgbg[index, :, :, 1])
ax[1].set_title('Segmentation Prediction')

ax[2].imshow(fg_thresh[index, :, :, 0], cmap='jet')
ax[2].set_title('Thresholded Segmentation')

ax[3].imshow(argmax_images[index, :, :, 0], cmap='jet')
ax[3].set_title('Watershed Transform')

ax[4].imshow(argmax_images_post_fgbg[index, :, :, 0], cmap='jet')
ax[4].set_title('Watershed Transform w/o Background')

ax[5].imshow(watershed_images[index, :, :, 0], cmap='jet')
ax[5].set_title('Watershed Segmentation')

fig.tight_layout()
plt.show()

# %% [markdown]
# # Sample Based Training

# %%
# Load the training data from NPZ into a numpy array
training_data = np.load(os.path.join(NPZ_DIR, PREFIX, DATA_FILE + '.npz'))

X, y = training_data['X'], training_data['y']
print('X.shape: {}\ny.shape: {}'.format(X.shape, y.shape))

# save the size of the input data for input_shape model parameter
size = (RESHAPE_SIZE, RESHAPE_SIZE) if RESIZE else X.shape[ROW_AXIS:COL_AXIS + 1]
if IS_CHANNELS_FIRST:
    input_shape = (X.shape[CHANNEL_AXIS], size[0], size[1])
else:
    input_shape = (size[0], size[1], X.shape[CHANNEL_AXIS])
    
# Sample window dimensions
WIN_X = 30
WIN_Y = 30
    
# Set up other training parameters
n_epoch = 3
batch_size = 32
optimizer = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
lr_sched = rate_scheduler(lr=0.01, decay=0.99)
# Out:
# X.shape: (45, 256, 256, 1)
# y.shape: (45, 256, 256, 1)

# %%
# First, create a foreground/background separation model

# Instantiate the model
fgbg_model = bn_feature_net_2D(
    receptive_field=WIN_X + WIN_Y + 1,
    n_features=2)

# Train the model
train_model_sample(
    model=fgbg_model,
    dataset=DATA_FILE,
    optimizer=optimizer,
    window_size=(WIN_X, WIN_Y),
    batch_size=batch_size,
    transform=None,  # fg/bg separation
    n_epoch=n_epoch,
    balance_classes=True,
    max_class_samples=None,
    direc_save=os.path.join(MODEL_DIR, PREFIX),
    direc_data=os.path.join(NPZ_DIR, PREFIX),
    expt='sample_fgbg',
    lr_sched=lr_sched,
    rotation_range=180,
    flip=True,
    shear=False)
# Out:
# X_train shape: (40, 256, 256, 1)
# y_train shape: (40, 256, 256, 1)
# X_test shape: (5, 256, 256, 1)
# y_test shape: (5, 256, 256, 1)
# Output Shape: (None, 2)
# Number of Classes: 2
# Epoch 1/3
# 17117/17120 [============================>.] - ETA: 0s - loss: 0.1125 - acc: 0.9544
# Epoch 00001: val_loss improved from inf to 0.06594, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-08-31_nuclei_broad_watershed_sample_fgbg.h5
# 17120/17120 [==============================] - 358s 21ms/step - loss: 0.1125 - acc: 0.9544 - val_loss: 0.0659 - val_acc: 0.9648
# Epoch 2/3
# 17117/17120 [============================>.] - ETA: 0s - loss: 0.1065 - acc: 0.9567
# Epoch 00002: val_loss improved from 0.06594 to 0.06240, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-08-31_nuclei_broad_watershed_sample_fgbg.h5
# 17120/17120 [==============================] - 340s 20ms/step - loss: 0.1065 - acc: 0.9567 - val_loss: 0.0624 - val_acc: 0.9708
# Epoch 3/3
# 17119/17120 [============================>.] - ETA: 0s - loss: 0.1047 - acc: 0.9570
# Epoch 00003: val_loss improved from 0.06240 to 0.05814, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-08-31_nuclei_broad_watershed_sample_fgbg.h5
# 17120/17120 [==============================] - 335s 20ms/step - loss: 0.1047 - acc: 0.9570 - val_loss: 0.0581 - val_acc: 0.9715

# %%
# Next, Create a model for the watershed energy transform

# Instantiate the model
watershed_model = bn_feature_net_2D(
    receptive_field=WIN_X + WIN_Y + 1,
    n_features=BINS)

# Train the model
train_model_sample(
    model=watershed_model,
    dataset=DATA_FILE,
    optimizer=optimizer,
    batch_size=batch_size,
    n_epoch=n_epoch,
    window_size=(WIN_X, WIN_Y),
    transform='watershed',
    distance_bins=BINS,
    erosion_width=EROSION,
    balance_classes=True,
    max_class_samples=None,
    direc_save=os.path.join(MODEL_DIR, PREFIX),
    direc_data=os.path.join(NPZ_DIR, PREFIX),
    expt='sample_watershed',
    lr_sched=lr_sched,
    rotation_range=180,
    flip=True,
    shear=False)
# Out:
# X_train shape: (40, 256, 256, 1)
# y_train shape: (40, 256, 256, 1)
# X_test shape: (5, 256, 256, 1)
# y_test shape: (5, 256, 256, 1)
# Output Shape: (None, 4)
# Number of Classes: 4
# Epoch 1/3
# 3887/3888 [============================>.] - ETA: 0s - loss: 0.5388 - acc: 0.7223
# Epoch 00001: val_loss improved from inf to 0.22857, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-08-31_nuclei_broad_watershed_sample_watershed.h5
# 3888/3888 [==============================] - 107s 28ms/step - loss: 0.5388 - acc: 0.7223 - val_loss: 0.2286 - val_acc: 0.9136
# Epoch 2/3
# 3887/3888 [============================>.] - ETA: 0s - loss: 0.5044 - acc: 0.7392
# Epoch 00002: val_loss improved from 0.22857 to 0.22473, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-08-31_nuclei_broad_watershed_sample_watershed.h5
# 3888/3888 [==============================] - 104s 27ms/step - loss: 0.5044 - acc: 0.7392 - val_loss: 0.2247 - val_acc: 0.9014
# Epoch 3/3
# 3886/3888 [============================>.] - ETA: 0s - loss: 0.4940 - acc: 0.7452
# Epoch 00003: val_loss improved from 0.22473 to 0.21558, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-08-31_nuclei_broad_watershed_sample_watershed.h5
# 3888/3888 [==============================] - 111s 29ms/step - loss: 0.4940 - acc: 0.7452 - val_loss: 0.2156 - val_acc: 0.9186

# %%
# Re-initializing dilated models for sample-mode predictions
model_fn = bn_feature_net_61x61
watershed_weights_file = '2018-08-31_nuclei_broad_watershed_sample_watershed.h5'
watershed_weights_file = os.path.join(MODEL_DIR, PREFIX, watershed_weights_file)

fg_bg_weights_file = '2018-08-31_nuclei_broad_watershed_sample_fgbg.h5'
fg_bg_weights_file = os.path.join(MODEL_DIR, PREFIX, fg_bg_weights_file)

run_watershed_model = bn_feature_net_2D(
    receptive_field=WIN_X + WIN_Y + 1,
    dilated=True,
    n_features=BINS,
    input_shape=input_shape)
run_watershed_model.load_weights(watershed_weights_file)

run_fgbg_model = bn_feature_net_2D(
    receptive_field=WIN_X + WIN_Y + 1,
    dilated=True,
    n_features=2,
    input_shape=input_shape)
run_fgbg_model.load_weights(fg_bg_weights_file)

# %%
# With the trained model, make predictions on testing data
training_data_file = os.path.join(NPZ_DIR, PREFIX, DATA_FILE + '.npz')

train_dict, test_dict = get_data(training_data_file, mode='conv', seed=21)

X_test, y_test = test_dict['X'], test_dict['y']

test_images = run_watershed_model.predict(X_test)
test_images_fgbg = run_fgbg_model.predict(X_test)

print('watershed transform shape:', test_images.shape)
print('segmentation mask shape:', test_images_fgbg.shape)

argmax_images = []
for i in range(test_images.shape[0]):
    argmax_images.append(np.argmax(test_images[i], axis=CHANNEL_AXIS))
argmax_images = np.array(argmax_images)
argmax_images = np.expand_dims(argmax_images, axis=CHANNEL_AXIS)

print('watershed argmax shape:', argmax_images.shape)
# Out:
# watershed transform shape: (5, 256, 256, 4)
# segmentation mask shape: (5, 256, 256, 2)
# watershed argmax shape: (5, 256, 256, 1)

# %%
# threshold the foreground/background
# and remove back ground from watershed transform
if IS_CHANNELS_FIRST:
    fg_thresh = test_images_fgbg[:, 1, :, :] > 0.9
else:
    fg_thresh = test_images_fgbg[:, :, :, 1] > 0.9

fg_thresh = np.expand_dims(fg_thresh, axis=CHANNEL_AXIS)
argmax_images_post_fgbg = argmax_images * fg_thresh

# %%
# Apply watershed method with the distance transform as seed
from scipy import ndimage
from skimage.morphology import watershed
from skimage.feature import peak_local_max

watershed_images = []
for i in range(argmax_images_post_fgbg.shape[0]):
    if IS_CHANNELS_FIRST:
        image = fg_thresh[i, 0, :, :]
        distance = argmax_images_post_fgbg[i, 0, :, :]
    else:
        image = fg_thresh[i, :, :, 0]
        distance = argmax_images_post_fgbg[i, :, :, 0]

    local_maxi = peak_local_max(test_images[i, :, :, -1], min_distance=15, 
                                exclude_border=False, indices=False, labels=image)

    markers = ndimage.label(local_maxi)[0]
    segments = watershed(-distance, markers, mask=image)
    watershed_images.append(segments)

watershed_images = np.array(watershed_images)
watershed_images = np.expand_dims(watershed_images, axis=CHANNEL_AXIS)

# %% [markdown]
# ## Plot the Results

# %%
import matplotlib.pyplot as plt

index = 0

fig, axes = plt.subplots(ncols=3, nrows=2, figsize=(15, 15), sharex=True, sharey=True)
ax = axes.ravel()

ax[0].imshow(X_test[index, :, :, 0])
ax[0].set_title('Source Image')

ax[1].imshow(test_images_fgbg[index, :, :, 1])
ax[1].set_title('Segmentation Prediction')

ax[2].imshow(fg_thresh[index, :, :, 0], cmap='jet')
ax[2].set_title('Thresholded Segmentation')

ax[3].imshow(argmax_images[index, :, :, 0], cmap='jet')
ax[3].set_title('Watershed Transform')

ax[4].imshow(argmax_images_post_fgbg[index, :, :, 0], cmap='jet')
ax[4].set_title('Watershed Transform w/o Background')

ax[5].imshow(watershed_images[index, :, :, 0], cmap='jet')
ax[5].set_title('Watershed Segmentation')

fig.tight_layout()
plt.show()
