# %% [markdown]
# # Watershed Distance Transform for 2D Data
# ---
# Implementation of papers:
#
# [Deep Watershed Transform for Instance Segmentation](http://openaccess.thecvf.com/content_cvpr_2017/papers/Bai_Deep_Watershed_Transform_CVPR_2017_paper.pdf)
#
# [Learn to segment single cells with deep distance estimator and deep cell detector](https://arxiv.org/abs/1803.10829)

# %%
import os
import errno

import numpy as np
from skimage.external import tifffile as tiff
from tensorflow.python.keras.optimizers import SGD, Adam
from tensorflow.python.keras import backend as K

from deepcell import get_data
from deepcell import make_training_data
from deepcell import rate_scheduler
from deepcell.model_zoo import bn_feature_net_61x61
from deepcell.model_zoo import bn_feature_net_2D
from deepcell.model_zoo import bn_feature_net_skip_2D

from deepcell.training import train_model_conv
from deepcell.training import train_model_sample
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Load the Training Data

# %%
RESIZE = True
RESHAPE_SIZE = 256
BINS = 4
EROSION = 0

# filepath constants
DATA_DIR = '/data/data'
MODEL_DIR = '/data/models'
NPZ_DIR = '/data/npz_data'
RESULTS_DIR = '/data/results'
EXPORT_DIR = '/data/exports'
PREFIX = 'cells/unspecified_nuclear_data/nuclei_broad'
DATA_FILE = 'nuclei_broad_watershed'

# Check for channels_first or channels_last
IS_CHANNELS_FIRST = K.image_data_format() == 'channels_first'

ROW_AXIS = 2 if IS_CHANNELS_FIRST else 1
COL_AXIS = 3 if IS_CHANNELS_FIRST else 2
CHANNEL_AXIS = 1 if IS_CHANNELS_FIRST else -1

WIN_X = 30
WIN_Y = 30

# create these directories if they do not exist
for d in (NPZ_DIR, MODEL_DIR, RESULTS_DIR):
    try:
        os.makedirs(os.path.join(d, PREFIX))
        print('Created new directory:', os.path.join(d, PREFIX))
    except OSError as exc: # Guard against race condition
        if exc.errno != errno.EEXIST:
            raise

# %%
# Make the training data for watershed distance transform
make_training_data(
    direc_name=os.path.join(DATA_DIR, PREFIX),
    dimensionality=2,
    file_name_save=os.path.join(NPZ_DIR, PREFIX, DATA_FILE),
    training_direcs=['set1', 'set2', 'set3', 'set4', 'set5'],
    channel_names=['nuclear'],
    num_of_features=BINS,
    raw_image_direc='processed',
    annotation_direc='annotated',
    reshape_size=RESHAPE_SIZE if RESIZE else None)

if os.path.isfile(os.path.join(NPZ_DIR, PREFIX, DATA_FILE) + '.npz'):
    print('Data Saved to', os.path.join(NPZ_DIR, PREFIX, DATA_FILE) + '.npz')
else:
    raise Exception('Uh Oh!  Your data file did not save properly :(')
# Out:
# Reshaped feature data from (5, 520, 696, 1) to (45, 256, 256, 1)
# Reshaped training data from (5, 520, 696, 1) to (45, 256, 256, 1)
# Data Saved to /data/npz_data/cells/unspecified_nuclear_data/nuclei_broad/nuclei_broad_watershed.npz

# %% [markdown]
# ## Conv Based Training

# %%
# Load the training data from NPZ into a numpy array
training_data = np.load(os.path.join(NPZ_DIR, PREFIX, DATA_FILE + '.npz'))

X, y = training_data['X'], training_data['y']
print('X.shape: {}\ny.shape: {}'.format(X.shape, y.shape))

# save the size of the input data for input_shape model parameter
size = (RESHAPE_SIZE, RESHAPE_SIZE) if RESIZE else X.shape[ROW_AXIS:COL_AXIS + 1]
if IS_CHANNELS_FIRST:
    input_shape = (X.shape[CHANNEL_AXIS], size[0], size[1])
else:
    input_shape = (size[0], size[1], X.shape[CHANNEL_AXIS])
    
# Set up other training parameters
n_epoch = 10
batch_size = 1
optimizer = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
lr_sched = rate_scheduler(lr=0.01, decay=0.99)
# Out:
# X.shape: (45, 256, 256, 1)
# y.shape: (45, 256, 256, 1)

# %%
# First, create a foreground/background separation model

# Instantiate the model
fgbg_model = bn_feature_net_skip_2D(
    receptive_field=61,
    n_skips=2,
    n_features=2,  # segmentation mask (is_cell, is_not_cell)
    n_conv_filters=32,
    n_dense_filters=128,
    input_shape=input_shape,
    multires=False,
    last_only=False)

# Train the model
train_model_conv(
    model=fgbg_model,
    dataset=DATA_FILE,
    optimizer=optimizer,
    batch_size=batch_size,
    transform=None,  # fg/bg separation
    n_epoch=n_epoch,
    direc_save=os.path.join(MODEL_DIR, PREFIX),
    direc_data=os.path.join(NPZ_DIR, PREFIX),
    expt='conv_fgbg',
    lr_sched=lr_sched,
    skip=None,
    rotation_range=180,
    flip=True,
    shear=False)
# Out:
# X_train shape: (40, 256, 256, 1)
# y_train shape: (40, 256, 256, 1)
# X_test shape: (5, 256, 256, 1)
# y_test shape: (5, 256, 256, 1)
# Output Shape: (None, 256, 256, 2)
# Number of Classes: 2
# Epoch 1/10
# 39/40 [============================>.] - ETA: 0s - loss: 0.5140 - model_1_loss: 0.1410 - model_2_loss: 0.1710 - model_3_loss: 0.1811 - model_1_acc: 0.8859 - model_2_acc: 0.8717 - model_3_acc: 0.8639
# Epoch 00001: val_loss improved from inf to 0.95324, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-08-31_nuclei_broad_watershed_conv_fgbg.h5
# 40/40 [==============================] - 11s 275ms/step - loss: 0.5066 - model_1_loss: 0.1390 - model_2_loss: 0.1683 - model_3_loss: 0.1785 - model_1_acc: 0.8868 - model_2_acc: 0.8727 - model_3_acc: 0.8648 - val_loss: 0.9532 - val_model_1_loss: 0.3125 - val_model_2_loss: 0.2670 - val_model_3_loss: 0.3529 - val_model_1_acc: 0.8663 - val_model_2_acc: 0.9059 - val_model_3_acc: 0.9187
# Epoch 2/10
# 39/40 [============================>.] - ETA: 0s - loss: 0.1707 - model_1_loss: 0.0449 - model_2_loss: 0.0501 - model_3_loss: 0.0547 - model_1_acc: 0.9340 - model_2_acc: 0.9295 - model_3_acc: 0.9273
# Epoch 00002: val_loss improved from 0.95324 to 0.59878, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-08-31_nuclei_broad_watershed_conv_fgbg.h5
# 40/40 [==============================] - 6s 149ms/step - loss: 0.1686 - model_1_loss: 0.0443 - model_2_loss: 0.0494 - model_3_loss: 0.0539 - model_1_acc: 0.9342 - model_2_acc: 0.9298 - model_3_acc: 0.9276 - val_loss: 0.5988 - val_model_1_loss: 0.2135 - val_model_2_loss: 0.1875 - val_model_3_loss: 0.1769 - val_model_1_acc: 0.8823 - val_model_2_acc: 0.8935 - val_model_3_acc: 0.9241
# Epoch 3/10
# 39/40 [============================>.] - ETA: 0s - loss: 0.1227 - model_1_loss: 0.0316 - model_2_loss: 0.0347 - model_3_loss: 0.0355 - model_1_acc: 0.9398 - model_2_acc: 0.9379 - model_3_acc: 0.9357
# Epoch 00003: val_loss improved from 0.59878 to 0.36341, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-08-31_nuclei_broad_watershed_conv_fgbg.h5
# 40/40 [==============================] - 6s 146ms/step - loss: 0.1227 - model_1_loss: 0.0316 - model_2_loss: 0.0347 - model_3_loss: 0.0354 - model_1_acc: 0.9397 - model_2_acc: 0.9379 - model_3_acc: 0.9357 - val_loss: 0.3634 - val_model_1_loss: 0.1123 - val_model_2_loss: 0.1163 - val_model_3_loss: 0.1139 - val_model_1_acc: 0.9423 - val_model_2_acc: 0.9375 - val_model_3_acc: 0.9578
# Epoch 4/10
# 39/40 [============================>.] - ETA: 0s - loss: 0.1096 - model_1_loss: 0.0282 - model_2_loss: 0.0295 - model_3_loss: 0.0309 - model_1_acc: 0.9422 - model_2_acc: 0.9409 - model_3_acc: 0.9384
# Epoch 00004: val_loss improved from 0.36341 to 0.26786, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-08-31_nuclei_broad_watershed_conv_fgbg.h5
# 40/40 [==============================] - 6s
10
# 39/40 [============================>.] - ETA: 0s - loss: 0.0880 - model_1_loss: 0.0214 - model_2_loss: 0.0225 - model_3_loss: 0.0231 - model_1_acc: 0.9456 - model_2_acc: 0.9451 - model_3_acc: 0.9434
# Epoch 00009: val_loss improved from 0.20396 to 0.19321, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-08-31_nuclei_broad_watershed_conv_fgbg.h5
# 40/40 [==============================] - 6s 148ms/step - loss: 0.0877 - model_1_loss: 0.0213 - model_2_loss: 0.0224 - model_3_loss: 0.0230 - model_1_acc: 0.9450 - model_2_acc: 0.9445 - model_3_acc: 0.9428 - val_loss: 0.1932 - val_model_1_loss: 0.0548 - val_model_2_loss: 0.0607 - val_model_3_loss: 0.0568 - val_model_1_acc: 0.9792 - val_model_2_acc: 0.9742 - val_model_3_acc: 0.9797
# Epoch 10/10
# 39/40 [============================>.] - ETA: 0s - loss: 0.0850 - model_1_loss: 0.0209 - model_2_loss: 0.0215 - model_3_loss: 0.0217 - model_1_acc: 0.9447 - model_2_acc: 0.9444 - model_3_acc: 0.9424
# Epoch 00010: val_loss improved from 0.19321 to 0.19003, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-08-31_nuclei_broad_watershed_conv_fgbg.h5
# 40/40 [==============================] - 6s 145ms/step - loss: 0.0845 - model_1_loss: 0.0207 - model_2_loss: 0.0213 - model_3_loss: 0.0215 - model_1_acc: 0.9445 - model_2_acc: 0.9442 - model_3_acc: 0.9422 - val_loss: 0.1900 - val_model_1_loss: 0.0571 - val_model_2_loss: 0.0572 - val_model_3_loss: 0.0548 - val_model_1_acc: 0.9807 - val_model_2_acc: 0.9758 - val_model_3_acc: 0.9768

# %%
# Next, Create a model for the watershed energy transform

# Instantiate the model
watershed_model = bn_feature_net_skip_2D(
    fgbg_model=fgbg_model,
    receptive_field=61,
    n_skips=2,
    n_features=BINS,
    n_conv_filters=32,
    n_dense_filters=128,
    multires=False,
    last_only=False,
    input_shape=input_shape)

# Train the model
train_model_conv(
    model=watershed_model,
    dataset=DATA_FILE,
    optimizer=optimizer,
    batch_size=batch_size,
    n_epoch=n_epoch,
    transform='watershed',
    distance_bins=BINS,
    erosion_width=EROSION,
    direc_save=os.path.join(MODEL_DIR, PREFIX),
    direc_data=os.path.join(NPZ_DIR, PREFIX),
    expt='conv_watershed',
    lr_sched=lr_sched,
    rotation_range=180,
    flip=True,
    shear=False)
# Out:
# X_train shape: (40, 256, 256, 1)
# y_train shape: (40, 256, 256, 1)
# X_test shape: (5, 256, 256, 1)
# y_test shape: (5, 256, 256, 1)
# Output Shape: (None, 256, 256, 4)
# Number of Classes: 4
# Epoch 1/10
# 39/40 [============================>.] - ETA: 0s - loss: 2.1055 - model_5_loss: 0.6841 - model_6_loss: 0.7154 - model_7_loss: 0.6641 - model_5_acc: 0.7410 - model_6_acc: 0.6609 - model_7_acc: 0.7226
# Epoch 00001: val_loss improved from inf to 4.37483, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-08-31_nuclei_broad_watershed_conv_watershed.h5
# 40/40 [==============================] - 14s 344ms/step - loss: 2.0818 - model_5_loss: 0.6761 - model_6_loss: 0.7071 - model_7_loss: 0.6567 - model_5_acc: 0.7438 - model_6_acc: 0.6656 - model_7_acc: 0.7253 - val_loss: 4.3748 - val_model_5_loss: 2.0448 - val_model_6_loss: 1.2225 - val_model_7_loss: 1.0655 - val_model_5_acc: 0.6803 - val_model_6_acc: 0.8585 - val_model_7_acc: 0.8433
# Epoch 2/10
# 39/40 [============================>.] - ETA: 0s - loss: 1.1525 - model_5_loss: 0.3715 - model_6_loss: 0.3722 - model_7_loss: 0.3667 - model_5_acc: 0.8739 - model_6_acc: 0.8737 - model_7_acc: 0.8628
# Epoch 00002: val_loss improved from 4.37483 to 2.70903, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-08-31_nuclei_broad_watershed_conv_watershed.h5
# 40/40 [==============================] - 9s
10
# 39/40 [============================>.] - ETA: 0s - loss: 0.8207 - model_5_loss: 0.2703 - model_6_loss: 0.2580 - model_7_loss: 0.2502 - model_5_acc: 0.8968 - model_6_acc: 0.8950 - model_7_acc: 0.8918
# Epoch 00007: val_loss improved from 1.41973 to 1.32699, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-08-31_nuclei_broad_watershed_conv_watershed.h5
# 40/40 [==============================] - 9s 229ms/step - loss: 0.8186 - model_5_loss: 0.2694 - model_6_loss: 0.2573 - model_7_loss: 0.2497 - model_5_acc: 0.8965 - model_6_acc: 0.8947 - model_7_acc: 0.8918 - val_loss: 1.3270 - val_model_5_loss: 0.4361 - val_model_6_loss: 0.4262 - val_model_7_loss: 0.4225 - val_model_5_acc: 0.9443 - val_model_6_acc: 0.9437 - val_model_7_acc: 0.9504
# Epoch 8/10
# 39/40 [============================>.] - ETA: 0s - loss: 0.8114 - model_5_loss: 0.2676 - model_6_loss: 0.2566 - model_7_loss: 0.2451 - model_5_acc: 0.8990 - model_6_acc: 0.8982 - model_7_acc: 0.8986
# Epoch 00008: val_loss improved from 1.32699 to 1.28747, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-08-31_nuclei_broad_watershed_conv_watershed.h5
# 40/40 [==============================] - 9s 232ms/step - loss: 0.8150 - model_5_loss: 0.2686 - model_6_loss: 0.2574 - model_7_loss: 0.2468 - model_5_acc: 0.8979 - model_6_acc: 0.8972 - model_7_acc: 0.8975 - val_loss: 1.2875 - val_model_5_loss: 0.4203 - val_model_6_loss: 0.4240 - val_model_7_loss: 0.4009 - val_model_5_acc: 0.9338 - val_model_6_acc: 0.9303 - val_model_7_acc: 0.9449
# Epoch 9/10
# 39/40 [============================>.] - ETA: 0s - loss: 0.7464 - model_5_loss: 0.2471 - model_6_loss: 0.2284 - model_7_loss: 0.2287 - model_5_acc: 0.8989 - model_6_acc: 0.9006 - model_7_acc: 0.8986
# Epoch 00009: val_loss improved from 1.28747 to 1.23609, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-08-31_nuclei_broad_watershed_conv_watershed.h5
# 40/40 [==============================] - 9s 230ms/step - loss: 0.7460 - model_5_loss: 0.2467 - model_6_loss: 0.2285 - model_7_loss: 0.2287 - model_5_acc: 0.8982 - model_6_acc: 0.8997 - model_7_acc: 0.8978 - val_loss: 1.2361 - val_model_5_loss: 0.4165 - val_model_6_loss: 0.3983 - val_model_7_loss: 0.3791 - val_model_5_acc: 0.9404 - val_model_6_acc: 0.9310 - val_model_7_acc: 0.9431
# Epoch 10/10
# 39/40 [============================>.] - ETA: 0s - loss: 0.7233 - model_5_loss: 0.2413 - model_6_loss: 0.2183 - model_7_loss: 0.2213 - model_5_acc: 0.8980 - model_6_acc: 0.8992 - model_7_acc: 0.8963
# Epoch 00010: val_loss did not improve
# 40/40 [==============================] - 9s 221ms/step - loss: 0.7233 - model_5_loss: 0.2411 - model_6_loss: 0.2185 - model_7_loss: 0.2215 - model_5_acc: 0.8972 - model_6_acc: 0.8984 - model_7_acc: 0.8957 - val_loss: 1.2469 - val_model_5_loss: 0.4128 - val_model_6_loss: 0.3985 - val_model_7_loss: 0.3932 - val_model_5_acc: 0.9404 - val_model_6_acc: 0.9361 - val_model_7_acc: 0.9391

# %%
# With the trained model, make predictions on testing data
training_data_file = os.path.join(NPZ_DIR, PREFIX, DATA_FILE + '.npz')

train_dict, test_dict = get_data(training_data_file, mode='conv', seed=21)

X_test, y_test = test_dict['X'], test_dict['y']

test_images = watershed_model.predict(X_test)[-1]
test_images_fgbg = fgbg_model.predict(X_test)[-1]

print('watershed transform shape:', test_images.shape)
print('segmentation mask shape:', test_images_fgbg.shape)

argmax_images = []
for i in range(test_images.shape[0]):
    max_image = np.argmax(test_images[i], axis=CHANNEL_AXIS)
    argmax_images.append(max_image)
argmax_images = np.array(argmax_images)
argmax_images = np.expand_dims(argmax_images, axis=CHANNEL_AXIS)

print('watershed argmax shape:', argmax_images.shape)
# Out:
# watershed transform shape: (5, 256, 256, 4)
# segmentation mask shape: (5, 256, 256, 2)
# watershed argmax shape: (5, 256, 256, 1)

# %%
# threshold the foreground/background
# and remove back ground from watershed transform
if IS_CHANNELS_FIRST:
    fg_thresh = test_images_fgbg[:, 1, :, :] > 0.5
else:
    fg_thresh = test_images_fgbg[:, :, :, 1] > 0.5

fg_thresh = np.expand_dims(fg_thresh.astype(np.int16), axis=CHANNEL_AXIS)
argmax_images_post_fgbg = argmax_images * fg_thresh

# %%
# Apply watershed method with the distance transform as seed
from scipy import ndimage
from skimage.morphology import watershed
from skimage.feature import peak_local_max

watershed_images = []
for i in range(argmax_images_post_fgbg.shape[0]):
    if IS_CHANNELS_FIRST:
        image = fg_thresh[i, 0, :, :]
        distance = argmax_images_post_fgbg[i, 0, :, :]
    else:
        image = fg_thresh[i, :, :, 0]
        distance = argmax_images_post_fgbg[i, :, :, 0]

    local_maxi = peak_local_max(test_images[i, :, :, -1], min_distance=15, 
                                exclude_border=False, indices=False, labels=image)

    markers = ndimage.label(local_maxi)[0]
    segments = watershed(-distance, markers, mask=image)
    watershed_images.append(segments)

watershed_images = np.array(watershed_images)
watershed_images = np.expand_dims(watershed_images, axis=CHANNEL_AXIS)

# %% [markdown]
# ## Plot the Results

# %%
import matplotlib.pyplot as plt

index = 0

fig, axes = plt.subplots(ncols=3, nrows=2, figsize=(15, 15), sharex=True, sharey=True)
ax = axes.ravel()

ax[0].imshow(X_test[index, :, :, 0])
ax[0].set_title('Source Image')

ax[1].imshow(test_images_fgbg[index, :, :, 1])
ax[1].set_title('Segmentation Prediction')

ax[2].imshow(fg_thresh[index, :, :, 0], cmap='jet')
ax[2].set_title('Thresholded Segmentation')

ax[3].imshow(argmax_images[index, :, :, 0], cmap='jet')
ax[3].set_title('Watershed Transform')

ax[4].imshow(argmax_images_post_fgbg[index, :, :, 0], cmap='jet')
ax[4].set_title('Watershed Transform w/o Background')

ax[5].imshow(watershed_images[index, :, :, 0], cmap='jet')
ax[5].set_title('Watershed Segmentation')

fig.tight_layout()
plt.show()

# %% [markdown]
# # Sample Based Training

# %%
# Load the training data from NPZ into a numpy array
training_data = np.load(os.path.join(NPZ_DIR, PREFIX, DATA_FILE + '.npz'))

X, y = training_data['X'], training_data['y']
print('X.shape: {}\ny.shape: {}'.format(X.shape, y.shape))

# save the size of the input data for input_shape model parameter
size = (RESHAPE_SIZE, RESHAPE_SIZE) if RESIZE else X.shape[ROW_AXIS:COL_AXIS + 1]
if IS_CHANNELS_FIRST:
    input_shape = (X.shape[CHANNEL_AXIS], size[0], size[1])
else:
    input_shape = (size[0], size[1], X.shape[CHANNEL_AXIS])
    
# Sample window dimensions
WIN_X = 30
WIN_Y = 30
    
# Set up other training parameters
n_epoch = 3
batch_size = 32
optimizer = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
lr_sched = rate_scheduler(lr=0.01, decay=0.99)
# Out:
# X.shape: (45, 256, 256, 1)
# y.shape: (45, 256, 256, 1)

# %%
# First, create a foreground/background separation model

# Instantiate the model
fgbg_model = bn_feature_net_2D(
    receptive_field=WIN_X + WIN_Y + 1,
    n_features=2)

# Train the model
train_model_sample(
    model=fgbg_model,
    dataset=DATA_FILE,
    optimizer=optimizer,
    window_size=(WIN_X, WIN_Y),
    batch_size=batch_size,
    transform=None,  # fg/bg separation
    n_epoch=n_epoch,
    balance_classes=True,
    max_class_samples=None,
    direc_save=os.path.join(MODEL_DIR, PREFIX),
    direc_data=os.path.join(NPZ_DIR, PREFIX),
    expt='sample_fgbg',
    lr_sched=lr_sched,
    rotation_range=180,
    flip=True,
    shear=False)
# Out:
# X_train shape: (40, 256, 256, 1)
# y_train shape: (40, 256, 256, 1)
# X_test shape: (5, 256, 256, 1)
# y_test shape: (5, 256, 256, 1)
# Output Shape: (None, 2)
# Number of Classes: 2
# Epoch 1/3
# 16710/16711 [============================>.] - ETA: 0s - loss: 0.1118 - acc: 0.9548
# Epoch 00001: val_loss improved from inf to 0.07223, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-08-31_nuclei_broad_watershed_sample_fgbg.h5
# 16711/16711 [==============================] - 343s 21ms/step - loss: 0.1118 - acc: 0.9548 - val_loss: 0.0722 - val_acc: 0.9647
# Epoch 2/3
# 16708/16711 [============================>.] - ETA: 0s - loss: 0.1059 - acc: 0.9567
# Epoch 00002: val_loss improved from 0.07223 to 0.07152, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-08-31_nuclei_broad_watershed_sample_fgbg.h5
# 16711/16711 [==============================] - 338s 20ms/step - loss: 0.1059 - acc: 0.9567 - val_loss: 0.0715 - val_acc: 0.9618
# Epoch 3/3
# 16708/16711 [============================>.] - ETA: 0s - loss: 0.1036 - acc: 0.9576
# Epoch 00003: val_loss did not improve
# 16711/16711 [==============================] - 340s 20ms/step - loss: 0.1036 - acc: 0.9576 - val_loss: 0.0731 - val_acc: 0.9577

# %%
# Next, Create a model for the watershed energy transform

# Instantiate the model
watershed_model = bn_feature_net_2D(
    receptive_field=WIN_X + WIN_Y + 1,
    n_features=BINS)

# Train the model
train_model_sample(
    model=watershed_model,
    dataset=DATA_FILE,
    optimizer=optimizer,
    batch_size=batch_size,
    n_epoch=n_epoch,
    window_size=(WIN_X, WIN_Y),
    transform='watershed',
    distance_bins=BINS,
    erosion_width=EROSION,
    balance_classes=True,
    max_class_samples=None,
    direc_save=os.path.join(MODEL_DIR, PREFIX),
    direc_data=os.path.join(NPZ_DIR, PREFIX),
    expt='sample_watershed',
    lr_sched=lr_sched,
    rotation_range=180,
    flip=True,
    shear=False)
# Out:
# X_train shape: (40, 256, 256, 1)
# y_train shape: (40, 256, 256, 1)
# X_test shape: (5, 256, 256, 1)
# y_test shape: (5, 256, 256, 1)
# Output Shape: (None, 4)
# Number of Classes: 4
# Epoch 1/3
# 3953/3955 [============================>.] - ETA: 0s - loss: 0.5408 - acc: 0.7207
# Epoch 00001: val_loss improved from inf to 0.22051, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-08-31_nuclei_broad_watershed_sample_watershed.h5
# 3955/3955 [==============================] - 113s 28ms/step - loss: 0.5408 - acc: 0.7207 - val_loss: 0.2205 - val_acc: 0.9095
# Epoch 2/3
# 3952/3955 [============================>.] - ETA: 0s - loss: 0.5064 - acc: 0.7387
# Epoch 00002: val_loss improved from 0.22051 to 0.21443, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-08-31_nuclei_broad_watershed_sample_watershed.h5
# 3955/3955 [==============================] - 109s 28ms/step - loss: 0.5064 - acc: 0.7387 - val_loss: 0.2144 - val_acc: 0.9108
# Epoch 3/3
# 3954/3955 [============================>.] - ETA: 0s - loss: 0.4958 - acc: 0.7440
# Epoch 00003: val_loss improved from 0.21443 to 0.21287, saving model to /data/models/cells/unspecified_nuclear_data/nuclei_broad/2018-08-31_nuclei_broad_watershed_sample_watershed.h5
# 3955/3955 [==============================] - 109s 28ms/step - loss: 0.4958 - acc: 0.7440 - val_loss: 0.2129 - val_acc: 0.9112

# %%
# Re-initializing dilated models for sample-mode predictions
model_fn = bn_feature_net_61x61
watershed_weights_file = '2018-08-31_nuclei_broad_watershed_sample_watershed.h5'
watershed_weights_file = os.path.join(MODEL_DIR, PREFIX, watershed_weights_file)

fg_bg_weights_file = '2018-08-31_nuclei_broad_watershed_sample_fgbg.h5'
fg_bg_weights_file = os.path.join(MODEL_DIR, PREFIX, fg_bg_weights_file)

run_watershed_model = bn_feature_net_2D(
    receptive_field=WIN_X + WIN_Y + 1,
    dilated=True,
    n_features=BINS,
    input_shape=input_shape)
run_watershed_model.load_weights(watershed_weights_file)

run_fgbg_model = bn_feature_net_2D(
    receptive_field=WIN_X + WIN_Y + 1,
    dilated=True,
    n_features=2,
    input_shape=input_shape)
run_fgbg_model.load_weights(fg_bg_weights_file)

# %%
# With the trained model, make predictions on testing data
training_data_file = os.path.join(NPZ_DIR, PREFIX, DATA_FILE + '.npz')

train_dict, test_dict = get_data(training_data_file, mode='conv', seed=21)

X_test, y_test = test_dict['X'], test_dict['y']

test_images = run_watershed_model.predict(X_test)
test_images_fgbg = run_fgbg_model.predict(X_test)

print('watershed transform shape:', test_images.shape)
print('segmentation mask shape:', test_images_fgbg.shape)

argmax_images = []
for i in range(test_images.shape[0]):
    argmax_images.append(np.argmax(test_images[i], axis=CHANNEL_AXIS))
argmax_images = np.array(argmax_images)
argmax_images = np.expand_dims(argmax_images, axis=CHANNEL_AXIS)

print('watershed argmax shape:', argmax_images.shape)
# Out:
# watershed transform shape: (5, 256, 256, 4)
# segmentation mask shape: (5, 256, 256, 2)
# watershed argmax shape: (5, 256, 256, 1)

# %%
# threshold the foreground/background
# and remove back ground from watershed transform
if IS_CHANNELS_FIRST:
    fg_thresh = test_images_fgbg[:, 1, :, :] > 0.9
else:
    fg_thresh = test_images_fgbg[:, :, :, 1] > 0.9

fg_thresh = np.expand_dims(fg_thresh, axis=CHANNEL_AXIS)
argmax_images_post_fgbg = argmax_images * fg_thresh

# %%
# Apply watershed method with the distance transform as seed
from scipy import ndimage
from skimage.morphology import watershed
from skimage.feature import peak_local_max

watershed_images = []
for i in range(argmax_images_post_fgbg.shape[0]):
    if IS_CHANNELS_FIRST:
        image = fg_thresh[i, 0, :, :]
        distance = argmax_images_post_fgbg[i, 0, :, :]
    else:
        image = fg_thresh[i, :, :, 0]
        distance = argmax_images_post_fgbg[i, :, :, 0]

    local_maxi = peak_local_max(test_images[i, :, :, -1], min_distance=15, 
                                exclude_border=False, indices=False, labels=image)

    markers = ndimage.label(local_maxi)[0]
    segments = watershed(-distance, markers, mask=image)
    watershed_images.append(segments)

watershed_images = np.array(watershed_images)
watershed_images = np.expand_dims(watershed_images, axis=CHANNEL_AXIS)

# %% [markdown]
# ## Plot the Results

# %%
import matplotlib.pyplot as plt

index = 0

fig, axes = plt.subplots(ncols=3, nrows=2, figsize=(15, 15), sharex=True, sharey=True)
ax = axes.ravel()

ax[0].imshow(X_test[index, :, :, 0])
ax[0].set_title('Source Image')

ax[1].imshow(test_images_fgbg[index, :, :, 1])
ax[1].set_title('Segmentation Prediction')

ax[2].imshow(fg_thresh[index, :, :, 0], cmap='jet')
ax[2].set_title('Thresholded Segmentation')

ax[3].imshow(argmax_images[index, :, :, 0], cmap='jet')
ax[3].set_title('Watershed Transform')

ax[4].imshow(argmax_images_post_fgbg[index, :, :, 0], cmap='jet')
ax[4].set_title('Watershed Transform w/o Background')

ax[5].imshow(watershed_images[index, :, :, 0], cmap='jet')
ax[5].set_title('Watershed Segmentation')

fig.tight_layout()
plt.show()
