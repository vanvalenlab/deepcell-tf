# %% [markdown]
# # 2D Nuclear Segmentation with RetinaNet

# %%
import os
import errno

import numpy as np

import deepcell

# %%
# Download the data (saves to ~/.keras/datasets)
filename = 'HeLa_S3.npz'
(X_train, y_train), (X_test, y_test) = deepcell.datasets.hela_s3.load_data(filename)

print('X.shape: {}\ny.shape: {}'.format(X_train.shape, y_train.shape))
# Out:
# X.shape: (5760, 216, 256, 1)
# y.shape: (5760, 216, 256, 1)

# %% [markdown]
# ### Set up filepath constants

# %%
# the path to the data file is currently required for `train_model_()` functions

# NOTE: Change DATA_DIR if you are not using `deepcell.datasets`
DATA_DIR = os.path.expanduser(os.path.join('~', '.keras', 'datasets'))

DATA_FILE = os.path.join(DATA_DIR, filename)

# confirm the data file is available
assert os.path.isfile(DATA_FILE)

# %%
# Set up other required filepaths

# If the data file is in a subdirectory, mirror it in MODEL_DIR and LOG_DIR
PREFIX = os.path.relpath(os.path.dirname(DATA_FILE), DATA_DIR)

ROOT_DIR = '/data'  # TODO: Change this! Usually a mounted volume
MODEL_DIR = os.path.abspath(os.path.join(ROOT_DIR, 'models', PREFIX))
LOG_DIR = os.path.abspath(os.path.join(ROOT_DIR, 'logs', PREFIX))

# create directories if they do not exist
for d in (MODEL_DIR, LOG_DIR):
    try:
        os.makedirs(d)
    except OSError as exc:  # Guard against race condition
        if exc.errno != errno.EEXIST:
            raise

# %% [markdown]
# ### Set up training parameters

# %%
from tensorflow.keras.optimizers import SGD, Adam
from deepcell.utils.train_utils import rate_scheduler

# Supported backbones:
# vgg16, vgg19
# densenet121, densenet169, densenet201
# mobilenet, mobilenetv2
# nasnet_large, nasnet_mobile
# resnet50
backbone = 'resnet50'

model_name = '{}_retinanet'.format(backbone)

n_epoch = 10  # Number of training epochs
test_size = .20  # % of data saved as test
lr = 1e-5

optimizer = Adam(lr=lr, clipnorm=0.001)

lr_sched = rate_scheduler(lr=lr, decay=0.99)

batch_size = 4

num_classes = 1  # "object" is the only class

# %% [markdown]
# ## Create the RetinaNet Model

# %%
from deepcell.utils.retinanet_anchor_utils import generate_anchor_params

# Pick and choose which backbone layers and anchors to use in training
backbone_levels = ['C3', 'C4', 'C5']
pyramid_levels = ['P3', 'P4']
anchor_size_dict = {'P3': 32, 'P4': 64}

anchor_params = generate_anchor_params(pyramid_levels, anchor_size_dict)

# %%
from deepcell import model_zoo

# training model is `retinanet` while prediction model is `retinanet_bbox`
model = model_zoo.RetinaNet(
    backbone=backbone,
    use_imagenet=False,
    panoptic=True,
    num_semantic_classes=4,
    input_shape=X_train.shape[1:],
    num_classes=num_classes,
    backbone_levels=backbone_levels,
    pyramid_levels=pyramid_levels)
# Out:
# /usr/local/lib/python3.5/dist-packages/keras_applications/resnet50.py:264: UserWarning: The output shape of `ResNet50(include_top=False)` has been changed since Keras 2.2.0.
#   warnings.warn('The output shape of `ResNet50(include_top=False)` '

# %%
from deepcell.training import train_model_retinanet

model = train_model_retinanet(
    model=model,
    backbone=backbone,
    dataset=DATA_FILE,  # full path to npz file
    model_name=model_name,
    anchor_params=anchor_params,
    pyramid_levels=pyramid_levels,
    panoptic=True,
    sigma=3.0,
    alpha=0.25,
    gamma=2.0,
    weighted_average=True,
    score_threshold=0.01,
    iou_threshold=0.5,
    max_detections=100,
    test_size=test_size,
    optimizer=optimizer,
    batch_size=batch_size,
    n_epoch=n_epoch,
    log_dir=LOG_DIR,
    model_dir=MODEL_DIR,
    lr_sched=lr_sched,
    rotation_range=180,
    flip=True,
    shear=False,
    zoom_range=(0.8, 1.2))
# Out:
# X_train shape: (5760, 216, 256, 1)
# y_train shape: (5760, 216, 256, 1)
# X_test shape: (1440, 216, 256, 1)
# y_test shape: (1440, 216, 256, 1)
# Output Shape: (None, 216, 256, 4)
# Number of Classes: 4
# Training on 1 GPUs
# WARNING:tensorflow:Removing 614 of 5760 images with fewer than 3 objects.
# WARNING:tensorflow:Removing 134 of 1440 images with fewer than 3 objects.
# Epoch 1/10
# 1285/1286 [============================>.] - ETA: 0s - loss: 6.3344 - regression_loss: 1.6387 - classification_loss: 0.3324 - semantic_loss: 4.3633
# Epoch 00001: val_loss improved from inf to 4.32920, saving model to /data/models/resnet50_retinanet.h5
# 9989 instances of class 0 with average precision: 0.7689
# mAP: 0.7689
# 1286/1286 [==============================] - 325s 253ms/step - loss: 6.3336 - regression_loss: 1.6385 - classification_loss: 0.3323 - semantic_loss: 4.3628 - val_loss: 4.3292 - val_regression_loss: 0.9482 - val_classification_loss: 0.1307 - val_semantic_loss: 3.2503
# Epoch 2/10
# 1285/1286 [============================>.] - ETA: 0s - loss: 4.1423 - regression_loss: 0.9729 - classification_loss: 0.1430 - semantic_loss: 3.0264
# Epoch 00002: val_loss improved from 4.32920 to 3.38540, saving model to /data/models/resnet50_retinanet.h5
# 9989 instances of class 0 with average precision: 0.7908
# mAP: 0.7908
# 1286/1286 [==============================] - 239s 186ms/step - loss: 4.1419 - regression_loss: 0.9728 - classification_loss: 0.1430 - semantic_loss: 3.0261 - val_loss: 3.3854 - val_regression_loss: 0.7186 - val_classification_loss: 0.0938 - val_semantic_loss: 2.5730
# Epoch 3/10
# 1285/1286 [============================>.] - ETA: 0s - loss: 3.5663 - regression_loss: 0.8284 - classification_loss: 0.1189 - semantic_loss: 2.6191
# Epoch 00003: val_loss improved from 3.38540 to 2.99636, saving model to /data/models/resnet50_retinanet.h5
# 9989 instances of class 0 with average precision: 0.8122
# mAP: 0.8122
# 1286/1286 [==============================] - 236s 184ms/step - loss: 3.5659 - regression_loss: 0.8282 - classification_loss: 0.1189 - semantic_loss: 2.6189 - val_loss: 2.9964 - val_regression_loss: 0.6173 - val_classification_loss: 0.0833 - val_semantic_loss: 2.2957
# Epoch 4/10
# 1285/1286 [============================>.] - ETA: 0s - loss: 3.2710 - regression_loss: 0.7536 - classification_loss: 0.1053 - semantic_loss: 2.4120
# Epoch 00004: val_loss improved from 2.99636 to 2.80068, saving model to /data/models/resnet50_retinanet.h5
# 9989 instances of class 0 with average precision: 0.8141
# mAP: 0.8141
# 1286/1286 [==============================] - 234s 182ms/step - loss: 3.2707 - regression_loss: 0.7535 - classification_loss: 0.1053 - semantic_loss: 2.4119 - val_loss: 2.8007 - val_regression_loss: 0.5864 - val_classification_loss: 0.0690 - val_semantic_loss: 2.1452
# Epoch 5/10
# 1285/1286 [============================>.] - ETA: 0s - loss: 3.1073 - regression_loss: 0.7120 - classification_loss: 0.1000 - semantic_loss: 2.2953
# Epoch 00005: val_loss improved from 2.80068 to 2.73017, saving model to /data/models/resnet50_retinanet.h5
# 9989 instances of class 0 with average precision: 0.8149
# mAP: 0.8149
# 1286/1286 [==============================] - 233s 181ms/step - loss: 3.1074 - regression_loss: 0.7119 - classification_loss: 0.1000 - semantic_loss: 2.2955 - val_loss: 2.7302 - val_regression_loss: 0.6148 - val_classification_loss: 0.0711 - val_semantic_loss: 2.0443
# Epoch 6/10
# 1285/1286 [============================>.] - ETA: 0s - loss: 2.9814 - regression_loss: 0.6751 - classification_loss: 0.0955 - semantic_loss: 2.2108
# Epoch 00006: val_loss improved from 2.73017 to 2.55648, saving model to /data/models/resnet50_retinanet.h5
# 9989 instances of class 0 with average precision: 0.8299
# mAP: 0.8299
# 1286/1286 [==============================] - 231s 180ms/step - loss: 2.9819 - regression_loss: 0.6753 - classification_loss: 0.0957 - semantic_loss: 2.2109 - val_loss: 2.5565 - val_regression_loss: 0.5204 - val_classification_loss: 0.0598 - val_semantic_loss: 1.9763
# Epoch 7/10
# 1285/1286 [============================>.] - ETA: 0s - loss: 2.8972 - regression_loss: 0.6485 - classification_loss: 0.0921 - semantic_loss: 2.1566
# Epoch 00007: val_loss improved from 2.55648 to 2.51389, saving model to /data/models/resnet50_retinanet.h5
# 9989 instances of class 0 with average precision: 0.8309
# mAP: 0.8309
# 1286/1286 [==============================] - 233s 181ms/step - loss: 2.8970 - regression_loss: 0.6485 - classification_loss: 0.0921 - semantic_loss: 2.1564 - val_loss: 2.5139 - val_regression_loss: 0.5156 - val_classification_loss: 0.0596 - val_semantic_loss: 1.9387
# Epoch 8/10
# 1285/1286 [============================>.] - ETA: 0s - loss: 2.8113 - regression_loss: 0.6220 - classification_loss: 0.0869 - semantic_loss: 2.1024
# Epoch 00008: val_loss improved from 2.51389 to 2.47857, saving model to /data/models/resnet50_retinanet.h5
# 9989 instances of class 0 with average precision: 0.8294
# mAP: 0.8294
# 1286/1286 [==============================] - 235s 183ms/step - loss: 2.8115 - regression_loss: 0.6220 - classification_loss: 0.0870 - semantic_loss: 2.1025 - val_loss: 2.4786 - val_regression_loss: 0.5070 - val_classification_loss: 0.0725 - val_semantic_loss: 1.8991
# Epoch 9/10
# 1285/1286 [============================>.] - ETA: 0s - loss: 2.7805 - regression_loss: 0.6076 - classification_loss: 0.0877 - semantic_loss: 2.0851
# Epoch 00009: val_loss improved from 2.47857 to 2.40075, saving model to /data/models/resnet50_retinanet.h5
# 9989 instances of class 0 with average precision: 0.8372
# mAP: 0.8372
# 1286/1286 [==============================] - 235s 183ms/step - loss: 2.7801 - regression_loss: 0.6076 - classification_loss: 0.0877 - semantic_loss: 2.0849 - val_loss: 2.4008 - val_regression_loss: 0.4758 - val_classification_loss: 0.0557 - val_semantic_loss: 1.8693
# Epoch 10/10
# 1285/1286 [============================>.] - ETA: 0s - loss: 2.7192 - regression_loss: 0.5906 - classification_loss: 0.0832 - semantic_loss: 2.0454
# Epoch 00010: val_loss did not improve from 2.40075
# 9989 instances of class 0 with average precision: 0.8339
# mAP: 0.8339
# 1286/1286 [==============================] - 220s 171ms/step - loss: 2.7194 - regression_loss: 0.5906 - classification_loss: 0.0832 - semantic_loss: 2.0456 - val_loss: 2.4189 - val_regression_loss: 0.5179 - val_classification_loss: 0.0555 - val_semantic_loss: 1.8455
# 9989 instances of class 0 with average precision: 0.8339
# mAP using the weighted average of precisions among classes: 0.8339
# mAP: 0.8339

# %%
# Set up the prediction model
from deepcell.model_zoo.retinanet import retinanet_bbox

prediction_model = retinanet_bbox(model, panoptic=True)
prediction_model.load_weights(os.path.join(MODEL_DIR, model_name + '.h5'), by_name=True)

# %%
import matplotlib.pyplot as plt
import os
import time

import numpy as np

from deepcell.utils.plot_utils import draw_detections

index = np.random.randint(low=0, high=X_test.shape[0])
print('Image Number:', index)

image, mask = X_test[index:index + 1], y_test[index:index + 1]

boxes, scores, labels, semantic = prediction_model.predict(image)
semantic = np.argmax(semantic[0,:,:,:], axis=-1)

image = 0.01 * np.tile(np.expand_dims(image[0, ..., 0], axis=-1), (1, 1, 3))
mask = np.squeeze(mask)

# copy to draw on
draw = image.copy()

# draw the detections
draw_detections(draw, boxes[0], scores[0], labels[0],
                label_to_name=lambda x: 'cell',
                score_threshold=0.5,)

fig, axes = plt.subplots(ncols=4, nrows=1, figsize=(20, 20), sharex=True, sharey=True)
ax = axes.ravel()

ax[0].imshow(image, cmap='jet')
ax[0].set_title('Source Image')

ax[1].imshow(mask, cmap='jet')
ax[1].set_title('Labeled Data')

ax[2].imshow(draw, cmap='jet')
ax[2].set_title('Detections')

ax[3].imshow(semantic, cmap='jet')
ax[3].set_title('Semantic Segmentation')

fig.tight_layout()
plt.show()
# Out:
# Image Number: 181
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
