# %% [markdown]
# # 2D Nuclear Segmentation with RetinaNet

# %%
import os
import errno

import numpy as np

import deepcell

# %%
# Download the data (saves to ~/.keras/datasets)
filename = 'HeLa_S3.npz'
(X_train, y_train), (X_test, y_test) = deepcell.datasets.hela_s3.load_data(filename)

print('X.shape: {}\ny.shape: {}'.format(X_train.shape, y_train.shape))
# Out:
# X.shape: (5760, 216, 256, 1)
# y.shape: (5760, 216, 256, 1)

# %% [markdown]
# ### Set up filepath constants

# %%
# the path to the data file is currently required for `train_model_()` functions

# NOTE: Change DATA_DIR if you are not using `deepcell.datasets`
DATA_DIR = os.path.expanduser(os.path.join('~', '.keras', 'datasets'))

DATA_FILE = os.path.join(DATA_DIR, filename)

# confirm the data file is available
assert os.path.isfile(DATA_FILE)

# %%
# Set up other required filepaths

# If the data file is in a subdirectory, mirror it in MODEL_DIR and LOG_DIR
PREFIX = os.path.relpath(os.path.dirname(DATA_FILE), DATA_DIR)

ROOT_DIR = '/data'  # TODO: Change this! Usually a mounted volume
MODEL_DIR = os.path.abspath(os.path.join(ROOT_DIR, 'models', PREFIX))
LOG_DIR = os.path.abspath(os.path.join(ROOT_DIR, 'logs', PREFIX))

# create directories if they do not exist
for d in (MODEL_DIR, LOG_DIR):
    try:
        os.makedirs(d)
    except OSError as exc:  # Guard against race condition
        if exc.errno != errno.EEXIST:
            raise

# %% [markdown]
# ### Set up training parameters

# %%
from tensorflow.keras.optimizers import SGD, Adam
from deepcell.utils.train_utils import rate_scheduler

# Supported backbones:
# vgg16, vgg19
# densenet121, densenet169, densenet201
# mobilenet, mobilenetv2
# nasnet_large, nasnet_mobile
# resnet50
backbone = 'featurenet'

model_name = '{}_retinanet'.format(backbone)

n_epoch = 5  # Number of training epochs
test_size = .20  # % of data saved as test
lr = 1e-5

optimizer = Adam(lr=lr, clipnorm=0.001)

lr_sched = rate_scheduler(lr=lr, decay=0.99)

batch_size = 4

num_classes = 1  # "object" is the only class

# %% [markdown]
# ## Create the RetinaNet Model

# %%
from deepcell.utils.retinanet_anchor_utils import generate_anchor_params

# Pick and choose which backbone layers and anchors to use in training
backbone_levels = ['C3', 'C4', 'C5']
pyramid_levels = ['P3', 'P4']
anchor_size_dict = {'P3': 32, 'P4': 64}

anchor_params = generate_anchor_params(pyramid_levels, anchor_size_dict)

# %%
from deepcell import model_zoo

# training model is `retinanet` while prediction model is `retinanet_bbox`
model = model_zoo.RetinaNet(
    backbone=backbone,
    use_imagenet=False,
    panoptic=True,
    num_semantic_heads=2,
    num_semantic_classes=[3, 4],
    input_shape=X_train.shape[1:],
    num_classes=num_classes,
    backbone_levels=backbone_levels,
    pyramid_levels=pyramid_levels)

# %%
from deepcell.training import train_model_retinanet

model = train_model_retinanet(
    model=model,
    backbone=backbone,
    dataset=DATA_FILE,  # full path to npz file
    model_name=model_name,
    anchor_params=anchor_params,
    pyramid_levels=pyramid_levels,
    panoptic=True,
    sigma=3.0,
    alpha=0.25,
    gamma=2.0,
    weighted_average=True,
    transforms=['deepcell', 'watershed'],
    score_threshold=0.01,
    iou_threshold=0.5,
    max_detections=100,
    test_size=test_size,
    optimizer=optimizer,
    batch_size=batch_size,
    n_epoch=n_epoch,
    log_dir=LOG_DIR,
    model_dir=MODEL_DIR,
    lr_sched=lr_sched,
    rotation_range=180,
    flip=True,
    shear=False,
    zoom_range=(0.8, 1.2))
# Out:
# X_train shape: (5760, 216, 256, 1)
# y_train shape: (5760, 216, 256, 1)
# X_test shape: (1440, 216, 256, 1)
# y_test shape: (1440, 216, 256, 1)
# Output Shape: (None, None, None, 4)
# Number of Classes: 4
# Training on 1 GPUs
# WARNING:tensorflow:Removing 587 of 5760 images with fewer than 3 objects.
# WARNING:tensorflow:Removing 161 of 1440 images with fewer than 3 objects.
# Epoch 1/5
# 1292/1293 [============================>.] - ETA: 0s - loss: 2.2373 - regression_loss: 1.3777 - classification_loss: 0.2733 - semantic_0_loss: 0.2232 - semantic_1_loss: 0.3631
# Epoch 00001: val_loss improved from inf to 1.29773, saving model to /data/models/featurenet_retinanet.h5
# 9896 instances of class 0 with average precision: 0.7953
# mAP: 0.7953
# 1293/1293 [==============================] - 241s 187ms/step - loss: 2.2373 - regression_loss: 1.3777 - classification_loss: 0.2732 - semantic_0_loss: 0.2232 - semantic_1_loss: 0.3631 - val_loss: 1.2977 - val_regression_loss: 0.7406 - val_classification_loss: 0.1043 - val_semantic_0_loss: 0.1727 - val_semantic_1_loss: 0.2801
# Epoch 2/5
# 1292/1293 [============================>.] - ETA: 0s - loss: 1.4765 - regression_loss: 0.8918 - classification_loss: 0.1347 - semantic_0_loss: 0.1762 - semantic_1_loss: 0.2738
# Epoch 00002: val_loss improved from 1.29773 to 1.09913, saving model to /data/models/featurenet_retinanet.h5
# 9896 instances of class 0 with average precision: 0.8156
# mAP: 0.8156
# 1293/1293 [==============================] - 213s 165ms/step - loss: 1.4765 - regression_loss: 0.8918 - classification_loss: 0.1347 - semantic_0_loss: 0.1762 - semantic_1_loss: 0.2737 - val_loss: 1.0991 - val_regression_loss: 0.6168 - val_classification_loss: 0.0818 - val_semantic_0_loss: 0.1583 - val_semantic_1_loss: 0.2422
# Epoch 3/5
# 1292/1293 [============================>.] - ETA: 0s - loss: 1.3280 - regression_loss: 0.7951 - classification_loss: 0.1172 - semantic_0_loss: 0.1659 - semantic_1_loss: 0.2498
# Epoch 00003: val_loss improved from 1.09913 to 1.06470, saving model to /data/models/featurenet_retinanet.h5
# 9896 instances of class 0 with average precision: 0.8234
# mAP: 0.8234
# 1293/1293 [==============================] - 213s 165ms/step - loss: 1.3280 - regression_loss: 0.7951 - classification_loss: 0.1172 - semantic_0_loss: 0.1659 - semantic_1_loss: 0.2498 - val_loss: 1.0647 - val_regression_loss: 0.6056 - val_classification_loss: 0.0810 - val_semantic_0_loss: 0.1532 - val_semantic_1_loss: 0.2249
# Epoch 4/5
# 1292/1293 [============================>.] - ETA: 0s - loss: 1.2431 - regression_loss: 0.7367 - classification_loss: 0.1082 - semantic_0_loss: 0.1609 - semantic_1_loss: 0.2373
# Epoch 00004: val_loss improved from 1.06470 to 0.98005, saving model to /data/models/featurenet_retinanet.h5
# 9896 instances of class 0 with average precision: 0.8295
# mAP: 0.8295
# 1293/1293 [==============================] - 209s 162ms/step - loss: 1.2430 - regression_loss: 0.7367 - classification_loss: 0.1081 - semantic_0_loss: 0.1609 - semantic_1_loss: 0.2373 - val_loss: 0.9800 - val_regression_loss: 0.5456 - val_classification_loss: 0.0718 - val_semantic_0_loss: 0.1484 - val_semantic_1_loss: 0.2142
# Epoch 5/5
# 1292/1293 [============================>.] - ETA: 0s - loss: 1.1766 - regression_loss: 0.6909 - classification_loss: 0.1013 - semantic_0_loss: 0.1563 - semantic_1_loss: 0.2282
# Epoch 00005: val_loss improved from 0.98005 to 0.97642, saving model to /data/models/featurenet_retinanet.h5
# 9896 instances of class 0 with average precision: 0.8245
# mAP: 0.8245
# 1293/1293 [==============================] - 209s 161ms/step - loss: 1.1765 - regression_loss: 0.6908 - classification_loss: 0.1013 - semantic_0_loss: 0.1563 - semantic_1_loss: 0.2282 - val_loss: 0.9764 - val_regression_loss: 0.5540 - val_classification_loss: 0.0707 - val_semantic_0_loss: 0.1455 - val_semantic_1_loss: 0.2061
# 9896 instances of class 0 with average precision: 0.8245
# mAP using the weighted average of precisions among classes: 0.8245
# mAP: 0.8245

# %%
# Set up the prediction model
from deepcell.model_zoo.retinanet import retinanet_bbox

prediction_model = retinanet_bbox(model, panoptic=True, num_semantic_heads=2)
prediction_model.load_weights(os.path.join(MODEL_DIR, model_name + '.h5'), by_name=True)

# %%
import matplotlib.pyplot as plt
import os
import time

import numpy as np

from deepcell.utils.plot_utils import draw_detections

index = np.random.randint(low=0, high=X_test.shape[0])
print('Image Number:', index)

image, mask = X_test[index:index + 1], y_test[index:index + 1]

results = prediction_model.predict(image)
boxes, scores, labels = results[0:3]
semantic = results[3:]

semantic = [np.argmax(s[0], axis=-1) for s in semantic]

image = 0.01 * np.tile(np.expand_dims(image[0, ..., 0], axis=-1), (1, 1, 3))
mask = np.squeeze(mask)

# copy to draw on
draw = image.copy()

# draw the detections
draw_detections(draw, boxes[0], scores[0], labels[0],
                label_to_name=lambda x: 'cell',
                score_threshold=0.5,)

fig, axes = plt.subplots(ncols=3, nrows=2, figsize=(10, 10), sharex=True, sharey=True)
ax = axes.ravel()

ax[0].imshow(image, cmap='jet')
ax[0].set_title('Source Image')

ax[1].imshow(mask, cmap='jet')
ax[1].set_title('Labeled Data')

ax[2].imshow(draw, cmap='jet')
ax[2].set_title('Detections')

ax[3].imshow(semantic[0], cmap='jet')
ax[3].set_title('Deepcell Segmentation')

ax[4].imshow(semantic[1], cmap='jet')
ax[4].set_title('Watershed Segmentation')

fig.tight_layout()
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Image Number: 502
