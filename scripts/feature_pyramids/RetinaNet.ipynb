# %% [markdown]
# # 2D Nuclear Segmentation with RetinaNet

# %%
import os
import errno

import numpy as np

import deepcell

# %%
# Download the data (saves to ~/.keras/datasets)
filename = 'HeLa_S3.npz'
test_size = 0.2 # % of data saved as test
seed = 0 # seed for random train-test split

(X_train, y_train), (X_test, y_test) = deepcell.datasets.hela_s3.load_data(filename, test_size=test_size, seed=seed)

print('X.shape: {}\ny.shape: {}'.format(X_train.shape, y_train.shape))
# Out:
# X.shape: (5760, 216, 256, 1)
# y.shape: (5760, 216, 256, 1)

# %% [markdown]
# ### Set up filepath constants

# %%
# the path to the data file is currently required for `train_model_()` functions

# NOTE: Change DATA_DIR if you are not using `deepcell.datasets`
DATA_DIR = os.path.expanduser(os.path.join('~', '.keras', 'datasets'))

DATA_FILE = os.path.join(DATA_DIR, filename)

# confirm the data file is available
assert os.path.isfile(DATA_FILE)

# %%
# Set up other required filepaths

# If the data file is in a subdirectory, mirror it in MODEL_DIR and LOG_DIR
PREFIX = os.path.relpath(os.path.dirname(DATA_FILE), DATA_DIR)

ROOT_DIR = '/data'  # TODO: Change this! Usually a mounted volume
MODEL_DIR = os.path.abspath(os.path.join(ROOT_DIR, 'models', PREFIX))
LOG_DIR = os.path.abspath(os.path.join(ROOT_DIR, 'logs', PREFIX))

# create directories if they do not exist
for d in (MODEL_DIR, LOG_DIR):
    try:
        os.makedirs(d)
    except OSError as exc:  # Guard against race condition
        if exc.errno != errno.EEXIST:
            raise

# %% [markdown]
# ### Set up training parameters

# %%
from tensorflow.keras.optimizers import SGD, Adam
from deepcell.utils.train_utils import rate_scheduler

# Supported backbones:
# vgg16, vgg19
# densenet121, densenet169, densenet201
# mobilenet, mobilenetv2
# nasnet_large, nasnet_mobile
# resnet50
backbone = 'densenet121'

model_name = '{}_retinanet'.format(backbone)

n_epoch = 20  # Number of training epochs
lr = 1e-5

optimizer = Adam(lr=lr, clipnorm=0.001)

lr_sched = rate_scheduler(lr=lr, decay=0.99)

batch_size = 32

num_classes = 1  # "object" is the only class

# %% [markdown]
# ## Create the RetinaNet Model

# %%
from deepcell.utils.retinanet_anchor_utils import generate_anchor_params
from tensorflow.python.keras import backend as K

# Pick and choose which backbone layers and anchors to use in training
backbone_levels = ['C3', 'C4', 'C5'] # possible levels: C1, C2, C3, C4, C5
pyramid_levels = ['P3', 'P4', 'P5', 'P6', 'P7'] # possible levels: P1, ... , P7
anchor_size_dict = {'P1': 8, 'P2': 16, 'P3': 32, 'P4': 64, 'P5': 128, 'P6': 256, 'P7': 512}

# choose anchor scales and ratios
ratios=np.array([0.5, 1, 2], K.floatx())
scales=np.array([2 ** 0, 2 ** (1.0 / 3.0), 2 ** (2.0 / 3.0)], K.floatx())

anchor_params = generate_anchor_params(pyramid_levels, anchor_size_dict, ratios=ratios, scales=scales)

# %%
from deepcell import model_zoo

# training model is `retinanet` while prediction model is `retinanet_bbox`
model = model_zoo.RetinaNet(
    backbone=backbone,
    use_imagenet=False,
    panoptic=False,
    input_shape=X_train.shape[1:],
    num_classes=num_classes,
    backbone_levels=backbone_levels,
    pyramid_levels=pyramid_levels,
    num_anchors=anchor_params.num_anchors())

# %%
from deepcell.training import train_model_retinanet

model = train_model_retinanet(
    model=model,
    backbone=backbone,
    dataset=DATA_FILE,  # full path to npz file
    model_name=model_name,
    anchor_params=anchor_params,
    pyramid_levels=pyramid_levels,
    panoptic=False,
    sigma=3.0,
    alpha=0.25,
    gamma=2.0,
    weighted_average=True,
    score_threshold=0.01,
    iou_threshold=0.5,
    max_detections=100,
    test_size=test_size,
    seed=seed,
    optimizer=optimizer,
    batch_size=batch_size,
    n_epoch=n_epoch,
    log_dir=LOG_DIR,
    model_dir=MODEL_DIR,
    lr_sched=lr_sched,
    rotation_range=180,
    flip=True,
    shear=False,
    zoom_range=(0.8, 1.2))
# Out:
# X_train shape: (5760, 216, 256, 1)
# y_train shape: (5760, 216, 256, 1)
# X_test shape: (1440, 216, 256, 1)
# y_test shape: (1440, 216, 256, 1)
# Output Shape: (None, None, 1)
# Number of Classes: 1
# Training on 1 GPUs
# WARNING:tensorflow:Removing 609 of 5760 images with fewer than 3 objects.
# WARNING:tensorflow:Removing 139 of 1440 images with fewer than 3 objects.
# Epoch 1/20
# 159/160 [============================>.] - ETA: 0s - loss: 2.7341 - regression_loss: 2.1000 - classification_loss: 0.6341
# Epoch 00001: val_loss improved from inf to 2.72526, saving model to /data/models/densenet121_retinanet.h5
# 9978 instances of class 0 with average precision: 0.2977
# mAP: 0.2977
# 160/160 [==============================] - 254s 2s/step - loss: 2.7271 - regression_loss: 2.0955 - classification_loss: 0.6315 - val_loss: 2.7253 - val_regression_loss: 2.0365 - val_classification_loss: 0.6888
# Epoch 2/20
# 159/160 [============================>.] - ETA: 0s - loss: 1.4482 - regression_loss: 1.2606 - classification_loss: 0.1876
# Epoch 00002: val_loss improved from 2.72526 to 1.43283, saving model to /data/models/densenet121_retinanet.h5
# 9978 instances of class 0 with average precision: 0.6831
# mAP: 0.6831
# 160/160 [==============================] - 134s 837ms/step - loss: 1.4459 - regression_loss: 1.2588 - classification_loss: 0.1871 - val_loss: 1.4328 - val_regression_loss: 1.2358 - val_classification_loss: 0.1971
# Epoch 3/20
# 159/160 [============================>.] - ETA: 0s - loss: 1.1412 - regression_loss: 0.9957 - classification_loss: 0.1454
# Epoch 00003: val_loss improved from 1.43283 to 1.21243, saving model to /data/models/densenet121_retinanet.h5
# 9978 instances of class 0 with average precision: 0.7585
# mAP: 0.7585
# 160/160 [==============================] - 137s 853ms/step - loss: 1.1410 - regression_loss: 0.9955 - classification_loss: 0.1455 - val_loss: 1.2124 - val_regression_loss: 1.0738 - val_classification_loss: 0.1386
# Epoch 4/20
# 159/160 [============================>.] - ETA: 0s - loss: 1.0248 - regression_loss: 0.8933 - classification_loss: 0.1315
# Epoch 00004: val_loss improved from 1.21243 to 0.90057, saving model to /data/models/densenet121_retinanet.h5
# 9978 instances of class 0 with average precision: 0.7854
# mAP: 0.7854
# 160/160 [==============================] - 132s 824ms/step - loss: 1.0235 - regression_loss: 0.8922 - classification_loss: 0.1313 - val_loss: 0.9006 - val_regression_loss: 0.7976 - val_classification_loss: 0.1029
# Epoch 5/20
# 159/160 [============================>.] - ETA: 0s - loss: 0.9672 - regression_loss: 0.8447 - classification_loss: 0.1226
# Epoch 00005: val_loss improved from 0.90057 to 0.76787, saving model to /data/models/densenet121_retinanet.h5
# 9978 instances of class 0 with average precision: 0.7951
# mAP: 0.7951
# 160/160 [==============================] - 128s 802ms/step - loss: 0.9675 - regression_loss: 0.8449 - classification_loss: 0.1226 - val_loss: 0.7679 - val_regression_loss: 0.6739 - val_classification_loss: 0.0939
# Epoch 6/20
# 159/160 [============================>.] - ETA: 0s - loss: 0.9283 - regression_loss: 0.8085 - classification_loss: 0.1198
# Epoch 00006: val_loss improved from 0.76787 to 0.76364, saving model to /data/models/densenet121_retinanet.h5
# 9978 instances of class 0 with average precision: 0.7960
# mAP: 0.7960
# 160/160 [==============================] - 131s 816ms/step - loss: 0.9284 - regression_loss: 0.8084 - classification_loss: 0.1200 - val_loss: 0.7636 - val_regression_loss: 0.6761 - val_classification_loss: 0.0876
# Epoch 7/20
# 159/160 [============================>.] - ETA: 0s - loss: 0.8862 - regression_loss: 0.7731 - classification_loss: 0.1131
# Epoch 00007: val_loss improved from 0.76364 to 0.69803, saving model to /data/models/densenet121_retinanet.h5
# 9978 instances of class 0 with average precision: 0.8040
# mAP: 0.8040
# 160/160 [==============================] - 125s 782ms/step - loss: 0.8863 - regression_loss: 0.7733 - classification_loss: 0.1130 - val_loss: 0.6980 - val_regression_loss: 0.6144 - val_classification_loss: 0.0836
# Epoch 8/20
# 159/160 [============================>.] - ETA: 0s - loss: 0.8610 - regression_loss: 0.7519 - classification_loss: 0.1092
# Epoch 00008: val_loss improved from 0.69803 to 0.66135, saving model to /data/models/densenet121_retinanet.h5
# 9978 instances of class 0 with average precision: 0.8082
# mAP: 0.8082
# 160/160 [==============================] - 131s 821ms/step - loss: 0.8611 - regression_loss: 0.7518 - classification_loss: 0.1093 - val_loss: 0.6613 - val_regression_loss: 0.5837 - val_classification_loss: 0.0777
# Epoch 9/20
# 159/160 [============================>.] - ETA: 0s - loss: 0.8355 - regression_loss: 0.7290 - classification_loss: 0.1065
# Epoch 00009: val_loss improved from 0.66135 to 0.64690, saving model to /data/models/densenet121_retinanet.h5
# 9978 instances of class 0 with average precision: 0.8135
# mAP: 0.8135
# 160/160 [==============================] - 131s 817ms/step - loss: 0.8361 - regression_loss: 0.7295 - classification_loss: 0.1065 - val_loss: 0.6469 - val_regression_loss: 0.5735 - val_classification_loss: 0.0734
# Epoch 10/20
# 159/160 [============================>.] - ETA: 0s - loss: 0.8096 - regression_loss: 0.7074 - classification_loss: 0.1022
# Epoch 00010: val_loss improved from 0.64690 to 0.63038, saving model to /data/models/densenet121_retinanet.h5
# 9978 instances of class 0 with average precision: 0.8147
# mAP: 0.8147
# 160/160 [==============================] - 129s 804ms/step - loss: 0.8095 - regression_loss: 0.7074 - classification_loss: 0.1021 - val_loss: 0.6304 - val_regression_loss: 0.5584 - val_classification_loss: 0.0720
# Epoch 11/20
# 159/160 [============================>.] - ETA: 0s - loss: 0.8015 - regression_loss: 0.6998 - classification_loss: 0.1017
# Epoch 00011: val_loss improved from 0.63038 to 0.61639, saving model to /data/models/densenet121_retinanet.h5
# 9978 instances of class 0 with average precision: 0.8176
# mAP: 0.8176
# 160/160 [==============================] - 126s 785ms/step - loss: 0.8014 - regression_loss: 0.6997 - classification_loss: 0.1017 - val_loss: 0.6164 - val_regression_loss: 0.5464 - val_classification_loss: 0.0700
# Epoch 12/20
# 159/160 [============================>.] - ETA: 0s - loss: 0.7944 - regression_loss: 0.6936 - classification_loss: 0.1009
# Epoch 00012: val_loss did not improve from 0.61639
# 9978 instances of class 0 with average precision: 0.8172
# mAP: 0.8172
# 160/160 [==============================] - 123s 770ms/step - loss: 0.7948 - regression_loss: 0.6940 - classification_loss: 0.1008 - val_loss: 0.6204 - val_regression_loss: 0.5497 - val_classification_loss: 0.0707
# Epoch 13/20
# 159/160 [============================>.] - ETA: 0s - loss: 0.7664 - regression_loss: 0.6711 - classification_loss: 0.0953
# Epoch 00013: val_loss improved from 0.61639 to 0.60959, saving model to /data/models/densenet121_retinanet.h5
# 9978 instances of class 0 with average precision: 0.8200
# mAP: 0.8200
# 160/160 [==============================] - 125s 783ms/step - loss: 0.7663 - regression_loss: 0.6710 - classification_loss: 0.0953 - val_loss: 0.6096 - val_regression_loss: 0.5427 - val_classification_loss: 0.0669
# Epoch 14/20
# 159/160 [============================>.] - ETA: 0s - loss: 0.7533 - regression_loss: 0.6580 - classification_loss: 0.0953
# Epoch 00014: val_loss improved from 0.60959 to 0.59388, saving model to /data/models/densenet121_retinanet.h5
# 9978 instances of class 0 with average precision: 0.8214
# mAP: 0.8214
# 160/160 [==============================] - 125s 781ms/step - loss: 0.7538 - regression_loss: 0.6583 - classification_loss: 0.0955 - val_loss: 0.5939 - val_regression_loss: 0.5268 - val_classification_loss: 0.0671
# Epoch 15/20
# 159/160 [============================>.] - ETA: 0s - loss: 0.7434 - regression_loss: 0.6491 - classification_loss: 0.0943
# Epoch 00015: val_loss improved from 0.59388 to 0.59190, saving model to /data/models/densenet121_retinanet.h5
# 9978 instances of class 0 with average precision: 0.8226
# mAP: 0.8226
# 160/160 [==============================] - 125s 781ms/step - loss: 0.7435 - regression_loss: 0.6493 - classification_loss: 0.0942 - val_loss: 0.5919 - val_regression_loss: 0.5273 - val_classification_loss: 0.0646
# Epoch 16/20
# 159/160 [============================>.] - ETA: 0s - loss: 0.7279 - regression_loss: 0.6376 - classification_loss: 0.0902
# Epoch 00016: val_loss did not improve from 0.59190
# 9978 instances of class 0 with average precision: 0.8234
# mAP: 0.8234
# 160/160 [==============================] - 124s 772ms/step - loss: 0.7279 - regression_loss: 0.6376 - classification_loss: 0.0904 - val_loss: 0.6037 - val_regression_loss: 0.5400 - val_classification_loss: 0.0637
# Epoch 17/20
# 159/160 [============================>.] - ETA: 0s - loss: 0.7383 - regression_loss: 0.6450 - classification_loss: 0.0933
# Epoch 00017: val_loss improved from 0.59190 to 0.57276, saving model to /data/models/densenet121_retinanet.h5
# 9978 instances of class 0 with average precision: 0.8252
# mAP: 0.8252
# 160/160 [==============================] - 126s 788ms/step - loss: 0.7381 - regression_loss: 0.6449 - classification_loss: 0.0932 - val_loss: 0.5728 - val_regression_loss: 0.5093 - val_classification_loss: 0.0635
# Epoch 18/20
# 159/160 [============================>.] - ETA: 0s - loss: 0.7232 - regression_loss: 0.6312 - classification_loss: 0.0920
# Epoch 00018: val_loss improved from 0.57276 to 0.57080, saving model to /data/models/densenet121_retinanet.h5
# 9978 instances of class 0 with average precision: 0.8240
# mAP: 0.8240
# 160/160 [==============================] - 127s 795ms/step - loss: 0.7237 - regression_loss: 0.6317 - classification_loss: 0.0920 - val_loss: 0.5708 - val_regression_loss: 0.5079 - val_classification_loss: 0.0629
# Epoch 19/20
# 159/160 [============================>.] - ETA: 0s - loss: 0.7110 - regression_loss: 0.6204 - classification_loss: 0.0906
# Epoch 00019: val_loss improved from 0.57080 to 0.55330, saving model to /data/models/densenet121_retinanet.h5
# 9978 instances of class 0 with average precision: 0.8274
# mAP: 0.8274
# 160/160 [==============================] - 127s 795ms/step - loss: 0.7117 - regression_loss: 0.6209 - classification_loss: 0.0908 - val_loss: 0.5533 - val_regression_loss: 0.4922 - val_classification_loss: 0.0611
# Epoch 20/20
# 159/160 [============================>.] - ETA: 0s - loss: 0.7048 - regression_loss: 0.6139 - classification_loss: 0.0910
# Epoch 00020: val_loss did not improve from 0.55330
# 9978 instances of class 0 with average precision: 0.8268
# mAP: 0.8268
# 160/160 [==============================] - 124s 775ms/step - loss: 0.7047 - regression_loss: 0.6138 - classification_loss: 0.0909 - val_loss: 0.5614 - val_regression_loss: 0.4992 - val_classification_loss: 0.0621
# 9978 instances of class 0 with average precision: 0.8268
# mAP using the weighted average of precisions among classes: 0.8268
# mAP: 0.8268

# %%
# Set up the prediction model
from deepcell.model_zoo.retinanet import retinanet_bbox

prediction_model = retinanet_bbox(model, panoptic=False, anchor_params=anchor_params)
prediction_model.load_weights(os.path.join(MODEL_DIR, model_name + '.h5'), by_name=True)

# %%
import matplotlib.pyplot as plt
import os
import time

import numpy as np

from deepcell.utils.plot_utils import draw_detections

index = np.random.randint(low=0, high=X_test.shape[0])
print('Image Number:', index)

image, mask = X_test[index:index + 1], y_test[index:index + 1]

boxes, scores, labels = prediction_model.predict(image)

image = 0.01 * np.tile(np.expand_dims(image[0, ..., 0], axis=-1), (1, 1, 3))
mask = np.squeeze(mask)

# copy to draw on
draw = image.copy()

# draw the detections
draw_detections(draw, boxes[0], scores[0], labels[0],
                label_to_name=lambda x: 'cell',
                score_threshold=0.5,)

fig, axes = plt.subplots(ncols=3, nrows=1, figsize=(15, 15), sharex=True, sharey=True)
ax = axes.ravel()

ax[0].imshow(image, cmap='jet')
ax[0].set_title('Source Image')

ax[1].imshow(mask, cmap='jet')
ax[1].set_title('Labeled Data')

ax[2].imshow(draw, cmap='jet')
ax[2].set_title('Detections')

fig.tight_layout()
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Image Number: 1018
