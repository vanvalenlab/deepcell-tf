# %% [markdown]
# # 2D Nuclear Segmentation with RetinaNet

# %%
import os
import errno

import numpy as np

import deepcell
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %%
# Download the data (saves to ~/.keras/datasets)
filename = 'HeLa_S3.npz'
test_size = 0.2 # % of data saved as test
seed = 0 # seed for random train-test split

(X_train, y_train), (X_test, y_test) = deepcell.datasets.hela_s3.load_data(filename, test_size=test_size, seed=seed)

print('X.shape: {}\ny.shape: {}'.format(X_train.shape, y_train.shape))
# Out:
# Downloading data from https://deepcell-data.s3.amazonaws.com/nuclei/HeLa_S3.npz
# 6370107392/6370099814 [==============================] - 707s 0us/step
# X.shape: (5760, 216, 256, 1)
# y.shape: (5760, 216, 256, 1)

# %% [markdown]
# ### Set up filepath constants

# %%
# the path to the data file is currently required for `train_model_()` functions

# NOTE: Change DATA_DIR if you are not using `deepcell.datasets`
DATA_DIR = os.path.expanduser(os.path.join('~', '.keras', 'datasets'))

DATA_FILE = os.path.join(DATA_DIR, filename)

# confirm the data file is available
assert os.path.isfile(DATA_FILE)

# %%
# Set up other required filepaths

# If the data file is in a subdirectory, mirror it in MODEL_DIR and LOG_DIR
PREFIX = os.path.relpath(os.path.dirname(DATA_FILE), DATA_DIR)

ROOT_DIR = '/data'  # TODO: Change this! Usually a mounted volume
MODEL_DIR = os.path.abspath(os.path.join(ROOT_DIR, 'models', PREFIX))
LOG_DIR = os.path.abspath(os.path.join(ROOT_DIR, 'logs', PREFIX))

# create directories if they do not exist
for d in (MODEL_DIR, LOG_DIR):
    try:
        os.makedirs(d)
    except OSError as exc:  # Guard against race condition
        if exc.errno != errno.EEXIST:
            raise

# %% [markdown]
# ### Set up training parameters

# %%
from tensorflow.keras.optimizers import SGD, Adam
from deepcell.utils.train_utils import rate_scheduler

# Supported backbones:
# vgg16, vgg19
# densenet121, densenet169, densenet201
# mobilenet, mobilenetv2
# nasnet_large, nasnet_mobile
# resnet50
backbone = 'resnet50'

model_name = '{}_retinanet'.format(backbone)

n_epoch = 20  # Number of training epochs
lr = 1e-5

optimizer = Adam(lr=lr, clipnorm=0.001)

lr_sched = rate_scheduler(lr=lr, decay=0.99)

batch_size = 32

num_classes = 1  # "object" is the only class

# %% [markdown]
# ## Create the RetinaNet Model

# %%
from deepcell.utils.retinanet_anchor_utils import get_anchor_parameters

# Generate backbone information from the data
backbone_levels, pyramid_levels, anchor_params = get_anchor_parameters(y_train.astype('int'))

# %%
from deepcell import model_zoo

# training model is `retinanet` while prediction model is `retinanet_bbox`
model = model_zoo.RetinaNet(
    backbone=backbone,
    use_imagenet=False,
    panoptic=False,
    input_shape=X_train.shape[1:],
    num_classes=num_classes,
    backbone_levels=backbone_levels,
    pyramid_levels=pyramid_levels,
    num_anchors=anchor_params.num_anchors())
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/initializers.py:143: calling RandomNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.image.resize_images is deprecated. Please use tf.image.resize instead.

# %%
from deepcell.training import train_model_retinanet

model = train_model_retinanet(
    model=model,
    backbone=backbone,
    dataset=DATA_FILE,  # full path to npz file
    model_name=model_name,
    anchor_params=anchor_params,
    pyramid_levels=pyramid_levels,
    panoptic=False,
    sigma=3.0,
    alpha=0.25,
    gamma=2.0,
    weighted_average=True,
    score_threshold=0.01,
    iou_threshold=0.5,
    max_detections=100,
    test_size=test_size,
    seed=seed,
    optimizer=optimizer,
    batch_size=batch_size,
    n_epoch=n_epoch,
    log_dir=LOG_DIR,
    model_dir=MODEL_DIR,
    lr_sched=lr_sched,
    rotation_range=180,
    flip=True,
    shear=False,
    zoom_range=(0.8, 1.2))
# Out:
# X_train shape: (5760, 216, 256, 1)
# y_train shape: (5760, 216, 256, 1)
# X_test shape: (1440, 216, 256, 1)
# y_test shape: (1440, 216, 256, 1)
# Output Shape: (None, None, 1)
# Number of Classes: 1
# Training on 1 GPUs
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/deepcell/layers/filter_detections.py:77: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:Removing 598 of 5760 images with fewer than 3 objects.
# WARNING:tensorflow:Removing 150 of 1440 images with fewer than 3 objects.
# Epoch 1/20
# 160/161 [============================>.] - ETA: 1s - loss: 3.0741 - regression_loss: 2.3898 - classification_loss: 0.6843Epoch 1/20
#  40/161 [======>.......................] - ETA: 3:19 - loss: 3.5033 - regression_loss: 2.6234 - classification_loss: 0.8799
# Epoch 00001: val_loss improved from inf to 3.50330, saving model to /data/models/resnet50_retinanet.h5
# 9853 instances of class 0 with average precision: 0.2383
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/deepcell/callbacks.py:158: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
# mAP: 0.2383
# 161/161 [==============================] - 418s 3s/step - loss: 3.0669 - regression_loss: 2.3851 - classification_loss: 0.6818 - val_loss: 3.5033 - val_regression_loss: 2.6234 - val_classification_loss: 0.8799
# Epoch 2/20
# 160/161 [============================>.] - ETA: 1s - loss: 1.7009 - regression_loss: 1.4746 - classification_loss: 0.2263Epoch 1/20
#  40/161 [======>.......................] - ETA: 3:24 - loss: 1.9088 - regression_loss: 1.6095 - classification_loss: 0.2993
# Epoch 00002: val_loss improved from 3.50330 to 1.90880, saving model to /data/models/resnet50_retinanet.h5
# 9853 instances of class 0 with average precision: 0.8182
# mAP: 0.8182
# 161/161 [==============================] - 432s 3s/step - loss: 1.6999 - regression_loss: 1.4737 - classification_loss: 0.2262 - val_loss: 1.9088 - val_regression_loss: 1.6095 - val_classification_loss: 0.2993
# Epoch 3/20
# 160/161 [============================>.] - ETA: 1s - loss: 1.4475 - regression_loss: 1.2644 - classification_loss: 0.1832Epoch 1/20
#  40/161 [======>.......................] - ETA: 3:26 - loss: 1.3886 - regression_loss: 1.2016 - classification_loss: 0.1870
# Epoch 00003: val_loss improved from 1.90880 to 1.38862, saving model to /data/models/resnet50_retinanet.h5
# 9853 instances of class 0 with average precision: 0.8585
# mAP: 0.8585
# 161/161 [==============================] - 431s 3s/step - loss: 1.4471 - regression_loss: 1.2639 - classification_loss: 0.1832 - val_loss: 1.3886 - val_regression_loss: 1.2016 - val_classification_loss: 0.1870
# Epoch 4/20
# 160/161 [============================>.] - ETA: 1s - loss: 1.3041 - regression_loss: 1.1394 - classification_loss: 0.1647Epoch 1/20
#  40/161 [======>.......................] - ETA: 3:32 - loss: 1.1977 - regression_loss: 1.0541 - classification_loss: 0.1435
# Epoch 00004: val_loss improved from 1.38862 to 1.19767, saving model to /data/models/resnet50_retinanet.h5
# 9853 instances of class 0 with average precision: 0.8634
# mAP: 0.8634
# 161/161 [==============================] - 435s 3s/step - loss: 1.3037 - regression_loss: 1.1390 - classification_loss: 0.1646 - val_loss: 1.1977 - val_regression_loss: 1.0541 - val_classification_loss: 0.1435
# Epoch 5/20
# 160/161 [============================>.] - ETA: 1s - loss: 1.2274 - regression_loss: 1.0735 - classification_loss: 0.1539Epoch 1/20
#  40/161 [======>.......................] - ETA: 3:42 - loss: 1.1122 - regression_loss: 0.9833 - classification_loss: 0.1289
# Epoch 00005: val_loss improved from 1.19767 to 1.11219, saving model to /data/models/resnet50_retinanet.h5
# 9853 instances of class 0 with average precision: 0.8753
# mAP: 0.8753
# 161/161 [==============================] - 436s 3s/step - loss: 1.2271 - regression_loss: 1.0733 - classification_loss: 0.1538 - val_loss: 1.1122 - val_regression_loss: 0.9833 - val_classification_loss: 0.1289
# Epoch 6/20
# 160/161 [============================>.] - ETA: 1s - loss: 1.1755 - regression_loss: 1.0299 - classification_loss: 0.1456Epoch 1/20
#  40/161 [======>.......................] - ETA: 3:39 - loss: 1.0655 - regression_loss: 0.9411 - classification_loss: 0.1245
# Epoch 00006: val_loss improved from 1.11219 to 1.06552, saving model to /data/models/resnet50_retinanet.h5
# 9853 instances of class 0 with average precision: 0.8846
# mAP: 0.8846
# 161/161 [==============================] - 438s 3s/step - loss: 1.1751 - regression_loss: 1.0295 - classification_loss: 0.1456 - val_loss: 1.0655 - val_regression_loss: 0.9411 - val_classification_loss: 0.1245
# Epoch 7/20
# 160/161 [============================>.] - ETA: 1s - loss: 1.1227 - regression_loss: 0.9845 - classification_loss: 0.1383Epoch 1/20
#  40/161 [======>.......................] - ETA: 3:40 - loss: 1.0108 - regression_loss: 0.8974 - classification_loss: 0.1135
# Epoch 00007: val_loss improved from 1.06552 to 1.01082, saving model to /data/models/resnet50_retinanet.h5
# 9853 instances of class 0 with average precision: 0.8990
# mAP: 0.8990
# 161/161 [==============================] - 434s 3s/step - loss: 1.1224 - regression_loss: 0.9841 - classification_loss: 0.1382 - val_loss: 1.0108 - val_regression_loss: 0.8974 - val_classification_loss: 0.1135
# Epoch 8/20
# 160/161 [============================>.] - ETA: 1s - loss: 1.0882 - regression_loss: 0.9546 - classification_loss: 0.1336Epoch 1/20
#  40/161 [======>.......................] - ETA: 3:45 - loss: 0.9862 - regression_loss: 0.8772 - classification_loss: 0.1090
# Epoch 00008: val_loss improved from 1.01082 to 0.98615, saving model to /data/models/resnet50_retinanet.h5
# 9853 instances of class 0 with average precision: 0.9058
# mAP: 0.9058
# 161/161 [==============================] - 437s 3s/step - loss: 1.0879 - regression_loss: 0.9544 - classification_loss: 0.1336 - val_loss: 0.9862 - val_regression_loss: 0.8772 - val_classification_loss: 0.1090
# Epoch 9/20
# 160/161 [============================>.] - ETA: 1s - loss: 1.0600 - regression_loss: 0.9320 - classification_loss: 0.1280Epoch 1/20
#  40/161 [======>.......................] - ETA: 3:59 - loss: 0.9579 - regression_loss: 0.8509 - classification_loss: 0.1069
# Epoch 00009: val_loss improved from 0.98615 to 0.95786, saving model to /data/models/resnet50_retinanet.h5
# 9853 instances of class 0 with average precision: 0.9103
# mAP: 0.9103
# 161/161 [==============================] - 436s 3s/step - loss: 1.0602 - regression_loss: 0.9321 - classification_loss: 0.1281 - val_loss: 0.9579 - val_regression_loss: 0.8509 - val_classification_loss: 0.1069
# Epoch 10/20
# 160/161 [============================>.] - ETA: 1s - loss: 1.0300 - regression_loss: 0.9051 - classification_loss: 0.1250Epoch 1/20
#  40/161 [======>.......................] - ETA: 3:54 - loss: 0.9355 - regression_loss: 0.8330 - classification_loss: 0.1025
# Epoch 00010: val_loss improved from 0.95786 to 0.93553, saving model to /data/models/resnet50_retinanet.h5
# 9853 instances of class 0 with average precision: 0.9189
# mAP: 0.9189
# 161/161 [==============================] - 432s 3s/step - loss: 1.0308 - regression_loss: 0.9057 - classification_loss: 0.1251 - val_loss: 0.9355 - val_regression_loss: 0.8330 - val_classification_loss: 0.1025
# Epoch 11/20
# 160/161 [============================>.] - ETA: 1s - loss: 1.0138 - regression_loss: 0.8905 - classification_loss: 0.1233Epoch 1/20
#  40/161 [======>.......................] - ETA: 3:55 - loss: 0.9428 - regression_loss: 0.8451 - classification_loss: 0.0977
# Epoch 00011: val_loss did not improve from 0.93553
# 9853 instances of class 0 with average precision: 0.9208
# mAP: 0.9208
# 161/161 [==============================] - 429s 3s/step - loss: 1.0139 - regression_loss: 0.8907 - classification_loss: 0.1232 - val_loss: 0.9428 - val_regression_loss: 0.8451 - val_classification_loss: 0.0977
# Epoch 12/20
# 160/161 [============================>.] - ETA: 1s - loss: 0.9877 - regression_loss: 0.8677 - classification_loss: 0.1200Epoch 1/20
#  40/161 [======>.......................] - ETA: 3:58 - loss: 0.8957 - regression_loss: 0.8000 - classification_loss: 0.0956
# Epoch 00012: val_loss improved from 0.93553 to 0.89567, saving model to /data/models/resnet50_retinanet.h5
# 9853 instances of class 0 with average precision: 0.9240
# mAP: 0.9240
# 161/161 [==============================] - 433s 3s/step - loss: 0.9877 - regression_loss: 0.8677 - classification_loss: 0.1200 - val_loss: 0.8957 - val_regression_loss: 0.8000 - val_classification_loss: 0.0956
# Epoch 13/20
# 160/161 [============================>.] - ETA: 1s - loss: 0.9831 - regression_loss: 0.8648 - classification_loss: 0.1183Epoch 1/20
#  40/161 [======>.......................] - ETA: 4:07 - loss: 0.8858 - regression_loss: 0.7917 - classification_loss: 0.0941
# Epoch 00013: val_loss improved from 0.89567 to 0.88578, saving model to /data/models/resnet50_retinanet.h5
# 9853 instances of class 0 with average precision: 0.9233
# mAP: 0.9233
# 161/161 [==============================] - 437s 3s/step - loss: 0.9830 - regression_loss: 0.8647 - classification_loss: 0.1183 - val_loss: 0.8858 - val_regression_loss: 0.7917 - val_classification_loss: 0.0941
# Epoch 14/20
# 160/161 [============================>.] - ETA: 1s - loss: 0.9665 - regression_loss: 0.8486 - classification_loss: 0.1179Epoch 1/20
#  40/161 [======>.......................] - ETA: 3:52 - loss: 0.8745 - regression_loss: 0.7817 - classification_loss: 0.0927
# Epoch 00014: val_loss improved from 0.88578 to 0.87449, saving model to /data/models/resnet50_retinanet.h5
# 9853 instances of class 0 with average precision: 0.9263
# mAP: 0.9263
# 161/161 [==============================] - 434s 3s/step - loss: 0.9666 - regression_loss: 0.8487 - classification_loss: 0.1179 - val_loss: 0.8745 - val_regression_loss: 0.7817 - val_classification_loss: 0.0927
# Epoch 15/20
# 160/161 [============================>.] - ETA: 1s - loss: 0.9467 - regression_loss: 0.8329 - classification_loss: 0.1138Epoch 1/20
#  40/161 [======>.......................] - ETA: 3:54 - loss: 0.8972 - regression_loss: 0.8066 - classification_loss: 0.0907
# Epoch 00015: val_loss did not improve from 0.87449
# 9853 instances of class 0 with average precision: 0.9292
# mAP: 0.9292
# 161/161 [==============================] - 426s 3s/step - loss: 0.9463 - regression_loss: 0.8325 - classification_loss: 0.1137 - val_loss: 0.8972 - val_regression_loss: 0.8066 - val_classification_loss: 0.0907
# Epoch 16/20
# 160/161 [============================>.] - ETA: 1s - loss: 0.9415 - regression_loss: 0.8279 - classification_loss: 0.1136Epoch 1/20
#  40/161 [======>.......................] - ETA: 3:56 - loss: 0.8607 - regression_loss: 0.7694 - classification_loss: 0.0912
# Epoch 00016: val_loss improved from 0.87449 to 0.86069, saving model to /data/models/resnet50_retinanet.h5
# 9853 instances of class 0 with average precision: 0.9251
# mAP: 0.9251
# 161/161 [==============================] - 426s 3s/step - loss: 0.9414 - regression_loss: 0.8278 - classification_loss: 0.1136 - val_loss: 0.8607 - val_regression_loss: 0.7694 - val_classification_loss: 0.0912
# Epoch 17/20
# 160/161 [============================>.] - ETA: 1s - loss: 0.9285 - regression_loss: 0.8171 - classification_loss: 0.1114Epoch 1/20
#  40/161 [======>.......................] - ETA: 3:55 - loss: 0.8497 - regression_loss: 0.7563 - classification_loss: 0.0933
# Epoch 00017: val_loss improved from 0.86069 to 0.84967, saving model to /data/models/resnet50_retinanet.h5
# 9853 instances of class 0 with average precision: 0.9309
# mAP: 0.9309
# 161/161 [==============================] - 425s 3s/step - loss: 0.9285 - regression_loss: 0.8171 - classification_loss: 0.1114 - val_loss: 0.8497 - val_regression_loss: 0.7563 - val_classification_loss: 0.0933
# Epoch 18/20
# 160/161 [============================>.] - ETA: 1s - loss: 0.9219 - regression_loss: 0.8111 - classification_loss: 0.1108Epoch 1/20
#  40/161 [======>.......................] - ETA: 3:55 - loss: 0.8554 - regression_loss: 0.7655 - classification_loss: 0.0899
# Epoch 00018: val_loss did not improve from 0.84967
# 9853 instances of class 0 with average precision: 0.9285
# mAP: 0.9285
# 161/161 [==============================] - 421s 3s/step - loss: 0.9218 - regression_loss: 0.8111 - classification_loss: 0.1107 - val_loss: 0.8554 - val_regression_loss: 0.7655 - val_classification_loss: 0.0899
# Epoch 19/20
# 160/161 [============================>.] - ETA: 1s - loss: 0.9056 - regression_loss: 0.7959 - classification_loss: 0.1097Epoch 1/20
#  40/161 [======>.......................] - ETA: 3:53 - loss: 0.8466 - regression_loss: 0.7577 - classification_loss: 0.0889
# Epoch 00019: val_loss improved from 0.84967 to 0.84657, saving model to /data/models/resnet50_retinanet.h5
# 9853 instances of class 0 with average precision: 0.9336
# mAP: 0.9336
# 161/161 [==============================] - 411s 3s/step - loss: 0.9057 - regression_loss: 0.7959 - classification_loss: 0.1097 - val_loss: 0.8466 - val_regression_loss: 0.7577 - val_classification_loss: 0.0889
# Epoch 20/20
# 160/161 [============================>.] - ETA: 1s - loss: 0.9069 - regression_loss: 0.7979 - classification_loss: 0.1090Epoch 1/20
#  40/161 [======>.......................] - ETA: 3:57 - loss: 0.8487 - regression_loss: 0.7631 - classification_loss: 0.0856
# Epoch 00020: val_loss did not improve from 0.84657
# 9853 instances of class 0 with average precision: 0.9323
# mAP: 0.9323
# 161/161 [==============================] - 419s 3s/step - loss: 0.9072 - regression_loss: 0.7982 - classification_loss: 0.1090 - val_loss: 0.8487 - val_regression_loss: 0.7631 - val_classification_loss: 0.0856
# 9853 instances of class 0 with average precision: 0.9323
# mAP using the weighted average of precisions among classes: 0.9323
# mAP: 0.9323

# %%
# Set up the prediction model
from deepcell.model_zoo.retinanet import retinanet_bbox

prediction_model = retinanet_bbox(model, panoptic=False, anchor_params=anchor_params)
prediction_model.load_weights(os.path.join(MODEL_DIR, model_name + '.h5'), by_name=True)

# %%
import matplotlib.pyplot as plt
import os
import time

import numpy as np

from deepcell.utils.plot_utils import draw_detections

index = np.random.randint(low=0, high=X_test.shape[0])
print('Image Number:', index)

image, mask = X_test[index:index + 1], y_test[index:index + 1]

boxes, scores, labels = prediction_model.predict(image)

image = 0.01 * np.tile(np.expand_dims(image[0, ..., 0], axis=-1), (1, 1, 3))
mask = np.squeeze(mask)

# copy to draw on
draw = image.copy()

# draw the detections
draw_detections(draw, boxes[0], scores[0], labels[0],
                label_to_name=lambda x: 'cell',
                score_threshold=0.5,)

fig, axes = plt.subplots(ncols=3, nrows=1, figsize=(15, 15), sharex=True, sharey=True)
ax = axes.ravel()

ax[0].imshow(image, cmap='jet')
ax[0].set_title('Source Image')

ax[1].imshow(mask, cmap='jet')
ax[1].set_title('Labeled Data')

ax[2].imshow(draw, cmap='jet')
ax[2].set_title('Detections')

fig.tight_layout()
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Image Number: 1235
